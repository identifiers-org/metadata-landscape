# %% [markdown]
# # Identifiers.org resource metadata exploration

# %% [markdown]
# ## Step 1
#
# Get dataset.

# %%
import requests

get_all_dataset_url = "https://registry.api.identifiers.org/restApi/namespaces?size=1000"
dataset_request = requests.get(get_all_dataset_url)
dataset = dataset_request.json()
dataset = dataset["_embedded"]["namespaces"]

print(f"Found {len(dataset)} namespaces")
# Out:
# Found 684 namespaces

# %% [markdown]
# ## Step 2
# Iterate namespaces in dataset and get metadata from them.

# %%
import aiohttp
import asyncio

metadata_service_url = 'http://127.0.0.1:8082' # https://metadata.api.identifiers.org/


# Async request
async def fetch(url, session):
    async with session.get(url) as response:
        if response.status == 200:
            return await response.json()
        else:
            return {}

# Async semaphore fetch
metadata_results = {}

empty_metadata_resource_urls = []

async def bound_fetch(sem, url, session, namespace):
    async with sem:
        metadata = await fetch(url, session)
        # print(f"got metadata for {url}")
        
        payload = metadata.get("payload")
        print(f'\nMetadata for {url}: {payload}')
        
        if payload is not None:
            new_metadata_result = payload.get("metadata")
            namespace["metadata"] = new_metadata_result
            if len(payload["metadata"]) == 0:
                empty_metadata_resource_urls.append(url.split('/', 3)[3])
        else:
            namespace["metadata"] = []


async with aiohttp.ClientSession() as session:
    metadata_requests = []
    sem = asyncio.Semaphore(5)
    
    for namespace in dataset:
        # print(f"getting metadata for {namespace['prefix']}")

        if namespace['namespaceEmbeddedInLui']:
            print(f"* [{namespace['prefix']}] has a special LUI.")
            prefix = namespace['pattern'][1:].split(':')[0]
        else:
            prefix = namespace['prefix']

        get_metadata_url = f"{metadata_service_url}/{prefix}:{namespace['sampleId']}"

        task = asyncio.ensure_future(bound_fetch(sem, get_metadata_url, session, namespace))
        metadata_requests.append(task)

    await asyncio.gather(*metadata_requests)
# Out:
# * [chebi] has a special LUI.
# * [go] has a special LUI.
# * [sbo] has a special LUI.
# * [mgi] has a special LUI.
# * [eco] has a special LUI.
# * [mod] has a special LUI.
# * [mge] has a special LUI.
# * [fma] has a special LUI.
# * [so] has a special LUI.
# * [psimi] has a special LUI.
# * [cl] has a special LUI.
# * [bto] has a special LUI.
# * [pato] has a special LUI.
# * [uo] has a special LUI.
# * [pr] has a special LUI.
# * [doid] has a special LUI.
# * [cco] has a special LUI.
# * [pw] has a special LUI.
# * [po] has a special LUI.
# * [vario] has a special LUI.
# * [ma] has a special LUI.
# * [uberon] has a special LUI.
# * [gramene.growthstage] has a special LUI.
# * [eo] has a special LUI.
# * [swisslipid] has a special LUI.
# * [hp] has a special LUI.
# * [mp] has a special LUI.
# * [ms] has a special LUI.
# * [envo] has a special LUI.
# * [ark] has a special LUI.
# * [mir] has a special LUI.
# * [mzspec] has a special LUI.
# * [nmr] has a special LUI.
# * [swh] has a special LUI.
# * [foodon] has a special LUI.
# * [did] has a special LUI.
# * [ocid] has a special LUI.
# * [rrid] has a special LUI.
#
# Metadata for http://127.0.0.1:8082/CHEBI:36927: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/uniprot:P0DP23: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ec-code:1.1.1.1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ensembl:ENSG00000139618: {'metadata': [{'identifier': 'ENSG00000139618', '@context': 'http://schema.org', '@type': 'DataRecord', 'mainEntity': {'description': 'BRCA2 DNA repair associated [Source:HGNC Symbol;Acc:HGNC:1101]', 'identifier': 'ENSG00000139618', '@type': 'Gene', 'isPartOfBioChemEntity': {'@type': 'BioChemEntity', 'name': 'Chromosome 13'}, 'isPartOf': {'name': 'Homo sapiens', 'codeCategory': {'url': 'http://purl.bioontology.org/ontology/NCBITAXON/9606', 'codeValue': '9606', 'sameAs': 'http://purl.uniprot.org/taxonomy/9606', '@type': 'CategoryCode', 'inCodeSet': {'@type': 'CategoryCodeSet', 'name': 'NCBI taxon'}}, '@type': 'BioChemEntity', 'alternateName': 'Human'}, 'name': 'BRCA2'}, 'isPartOf': 'Ensembl Human Gene Set'}]}
#
# Metadata for http://127.0.0.1:8082/miriam.collection:MIR:00000008: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/taxonomy:9606: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biomodels.db:BIOMD0000000048: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/intact:EBI-2307691: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/interpro:IPR000100: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/kegg.pathway:hsa00620: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/icd:C34: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pirsf:PIRSF000100: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pubmed:16333295: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mim:603903: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/kegg.compound:C12345: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/kegg.reaction:R00100: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/doi:10.1038/nbt1156: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/reactome:R-HSA-201451: {'metadata': [{'@context': 'http://schema.org', '@type': 'WebSite', 'url': 'https://reactome.org/', 'potentialAction': {'@type': 'SearchAction', 'target': 'https://reactome.org/content/query?q={term}', 'query-input': 'required name=term'}}, {'@context': 'http://schema.org', '@type': 'Organization', 'url': 'https://reactome.org', 'logo': 'https://reactome.org/templates/favourite/images/logo/logo.png', 'email': 'help@reactome.org'}, {'name': 'Signaling by BMP', 'description': 'Bone morphogenetic proteins (BMPs) have many biological activities in various tissues, including bone, cartilage, blood vessels, heart, kidney, neurons, liver and lung. They are members of the Transforming growth factor-Beta (TGFB) family. They bind to type II and type I serine-threonine kinase receptors, which transduce signals through SMAD and non-SMAD signalling pathways. BMP signalling is linked to a wide variety of clinical disorders, including vascular diseases, skeletal diseases and cancer. BMPs typically activate BMP type I receptors and signal via SMAD1, 5 and 8. They can be classified into several subgroups, including the BMP2/4 group, the BMP5-8 osteogenic protein-1 (OP1) group, the growth and differentiation factor (GDF) 5-7 group and the BMP9/10 group. Most of the proteins of the BMP2/4, OP1 and BMP9/10 groups induce formation of bone and cartilage tissues in vivo, while the GDF5-7 group induce cartilage and tendon-like, but not bone-like, tissues (Miyazono et al. 2010). Members of the TGFB family bind to two types of serine-threonine kinase receptors, type I and type II (Massagué 2012). BMPs can bind type I receptors in the absence of type II receptors, but both types are required for signal transduction. The presence of both types dramatically increases binding affinity (Rozenweig et al. 1995). The type II receptor kinase transphosphorylates the type I receptor, which transmits specific intracellular signals. Type I and type II receptors share similar structural properties, comprised of a relatively short extracellular domain, a single membrane-spanning domain and an intracellular domain containing a serine-threonine kinase domain. Seven receptors, collectively referred to as the Activin receptor-like kinases (ALK), have been identified as type I receptors for the TGFB family in mammals. ALKs are classified into three groups based on their structure and function, the BMPRI group (Bone morphogenetic protein receptor type-1A, ALK3, BMPR1A and Bone morphogenetic protein receptor type-1B, ALK6, BMPR1B), the ALK1 group (Serine/threonine-protein kinase receptor R3, ALK1, ACVRL1 and Activin receptor type-1, ALK2, ACVR1) and the TBetaR1 group (Activin receptor type-1B, ALK4, ACVR1B and  TGF-beta receptor type-1, ALK5, TGFBR1 and Activin receptor type-1C, ALK7, ACVR1C) (Kawabata et al. 1998). ALK1 group and BMPRI group activate SMAD1/5/8 and transduce similar intracellular signals. The TBetaR1 group activate SMAD2/3. BMPR1A and ACVR1 are widely expressed. BMPR1B shows a more restricted expression profile. ACVRL1 is limited to endothelial cells and a few other cell types. The binding specificities of BMPs to type I receptors is affected by the type II receptors that are present (Yu et al. 2005). Typically, BMP2 and BMP4 bind to BMPR1A and BMPR1B (ten Dijke et al. 1994). BMP6 and BMP7 bind strongly to ACVR1 and weakly to BMPR1B. Growth/differentiation factor 5 (BMP14, GDF5) preferentially binds to BMPR1B, but not to other type I receptors (Nishitoh et al. 1995). BMP9 and BMP10 bind to ACVRL1 and ACVRL (Scharpfenecker et al. 2007). BMP type I receptors are shared by other members of the TGFB family. Three receptors, Bone morphogenetic protein receptor type-2 (BMPR2), Activin receptor type-2A (ACVR2A) and Activin receptor type-2B (ACVR2B) are the type II receptors for mammalian BMPs. They are widely expressed in various tissues. BMPR2 is specific for BMPs, whereas ACVR2A and ACVR2B are shared with ...
#
# Metadata for http://127.0.0.1:8082/pdb:2gc4: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/GO:0006915: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/kegg.drug:D00123: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sgd:S000003909: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/SBO:0000262: {'metadata': []}
# Metadata for http://127.0.0.1:8082/kegg.glycan:G00123: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/wb:WBGene00000001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pfam:PF01234: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/insdc:X58356: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/fb:FBgn0011293: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pubchem.compound:100101: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/prosite:PS00001: {'metadata': [{'@context': ['https://schema.org/'], '@type': 'Organization', 'url': 'https://prosite.expasy.org', 'name': 'PROSITE', 'logo': 'https://prosite.expasy.org//images/prosite/prosite.gif', 'memberof': {'@type': 'NGO', 'name': 'SIB Swiss Institute of Bioinformatics', 'url': 'https://sib.swiss/'}, 'parentOrganization': {'@type': 'Organization', 'name': 'ExPASy', 'url': 'https://www.expasy.org/'}}]}
#
# Metadata for http://127.0.0.1:8082/arxiv:0807.4956v1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/wormpep:CE28239: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pubchem.substance:100101: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sabiork.reaction:75: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/arrayexpress:E-MEXP-1712: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/MGI:2442292: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/refseq:NP_012345: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/tcdb:5.A.1.1.1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/uniparc:UPI000000000A: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mint:MINT-10000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/signaling-gateway:A001094: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dip:DIP-743N: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/resid:AA0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/tair.protein:AASequence:1009107926: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/tair.locus:2200950: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/tair.gene:Gene:2200934: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/rgd:2018: {'metadata': [{'@context': 'http://schema.org', '@type': 'Dataset', 'name': 'Acly', 'description': "ENCODES a protein that exhibits ATP citrate synthase activity; INVOLVED IN acetyl-CoA metabolic process; citrate metabolic process; fatty acid biosynthetic process; PARTICIPATES IN fatty acid biosynthetic pathway; citric acid cycle pathway; ASSOCIATED WITH congestive heart failure (ortholog); hepatocellular carcinoma (ortholog); obesity (ortholog); FOUND IN cytosol (ortholog); nucleoplasm (ortholog); plasma membrane (ortholog); INTERACTS WITH 1-naphthyl isothiocyanate; 17alpha-ethynylestradiol; 2,2',4,4'-Tetrabromodiphenyl ether", 'url': 'https://rgd.mcw.edu/rgdweb/report/gene/main.html?id=2018', 'keywords': 'Rat Gene RGD Genome', 'includedInDataCatalog': 'https://rgd.mcw.edu', 'creator': {'@type': 'Organization', 'name': 'Rat Genome Database'}, 'version': '1', 'license': 'Creative Commons CC BY 4.0'}]}
#
# Metadata for http://127.0.0.1:8082/CO:0000006: None
#
# Metadata for http://127.0.0.1:8082/peptideatlas:PAp00000009: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/lipidmaps:LMPR0102010012: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/geo:GDS1234: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hmdb:HMDB00001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sgd.pathways:PWY3O-214: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biogrid:31623: {'metadata': [{'@context': 'https://schema.org/', '@type': 'Dataset', 'name': 'BIOGRID CURATED DATA FOR STE11 (Saccharomyces cerevisiae (S288c))', 'description': 'Protein-Protein, Genetic, and Chemical Interactions for STE11 (Saccharomyces cerevisiae (S288c)) curated by BioGRID (https://thebiogrid.org); DEFINITION: Signal transducing MEK kinase; involved in pheromone response and pseudohyphal/invasive growth pathways where it phosphorylates Ste7p, and the high osmolarity response pathway, via phosphorylation of Pbs2p; regulated by Ste20p and Ste50p; protein abundance increases in response to DNA replication stress', 'url': 'https://thebiogrid.org/31623/summary/saccharomyces-cerevisiae/ste11.html', 'keywords': ['BIOLOGY', 'GENE', 'PROTEIN', 'BIOGRID', 'SACCHAROMYCES CEREVISIAE (S288C)', 'STE11', 'PROTEIN-PROTEIN INTERACTION', 'GENETIC INTERACTION', 'CHEMICAL INTERACTION', 'POST-TRANSLATIONAL MODIFICATION', 'GENE ONTOLOGY', 'CHEMICAL-GENETIC INTERACTION', 'PROTEIN SEQUENCE'], 'creator': {'@type': 'Organization', 'url': 'https://thebiogrid.org', 'name': 'BioGRID Project', 'contactPoint': {'@type': 'ContactPoint', 'contactType': 'Customer Service', 'email': 'biogridadmin@gmail.com', 'url': 'https://wiki.thebiogrid.org/doku.php/aboutus'}}, 'citation': 'https://identifiers.org/biogrid:31623', 'distribution': [{'@type': 'DataDownload', 'encodingFormat': 'ZIP', 'contentURL': 'https://thebiogrid.org/downloadgenerator.php?geneID=31623'}], 'license': {'@type': 'CreativeWork', 'name': 'MIT License', 'url': 'https://en.wikipedia.org/wiki/MIT_License'}}]}
#
# Metadata for http://127.0.0.1:8082/MOD:00001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/merops:S01.001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/panther.family:PTHR12345: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/prints:PR00001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ligandexpo:ABC: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mge:2: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pride:1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/3dmet:B00162: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/isbn:9781584885658: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/kegg.genes:syn:ssr3451: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/brenda:1.1.1.1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/FMA:67112: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/matrixdb.association:P00747__P07355: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ncbigene:100010: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pubchem.bioassay:1018: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/bao:0002989: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mmmp:biomaps:37: None
#
# Metadata for http://127.0.0.1:8082/pathwaycommons:485991: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hovergen:HBG004341: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/wikipathways:WP100: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/macie:M0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mirbase:MI0000001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hgnc:2674: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/zfin:ZDB-GENE-041118-11: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/rhea:12345: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/SO:0000704: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/chembl.compound:CHEMBL308052: {'metadata': [{'identifier': 'CHEMBL308052', 'inChIKey': 'BEWLPDVTVIFJAJ-ZPGRZCPFSA-N', '@context': 'http://schema.org', 'biochemicalInteraction': [{'identifier': 'CHEMBL3879801', 'url': 'www.ebi.ac.uk/chembl/target_report_card/CHEMBL3879801/', '@type': 'BioChemEntity'}, {'identifier': 'CHEMBL3974', 'url': 'www.ebi.ac.uk/chembl/target_report_card/CHEMBL3974/', '@type': 'BioChemEntity'}], 'inChI': 'InChI=1S/C40H42Cl2F2N8O3/c41-31-7-5-8-32(42)30(31)24-52-23-26(22-51-16-3-4-17-51)29-11-10-27(20-37(29)52)48-40(55)50-36(19-25-9-12-33(43)34(44)18-25)39(54)49-35(13-14-45)38(53)47-21-28-6-1-2-15-46-28/h1-2,5-12,15,18,20,23,35-36H,3-4,13-14,16-17,19,21-22,24,45H2,(H,47,53)(H,49,54)(H2,48,50,55)/t35-,36-/m0/s1', 'canonical_smiles': ['NCC[C@H](NC(=O)[C@H](Cc1ccc(F)c(F)c1)NC(=O)Nc2ccc3c(CN4CCCC4)cn(Cc5c(Cl)cccc5Cl)c3c2)C(=O)NCc6ccccn6'], '@type': 'MolecularEntity', 'image': 'https://www.ebi.ac.uk/chembl/api/data/image/CHEMBL308052.svg?engine=indigo', 'molecularWeight': 791.73, 'url': 'https://www.ebi.ac.uk/chembl/compound_report_card/CHEMBL308052/', 'molecularFormula': 'C40H42Cl2F2N8O3', 'monoisotopicMolecularWeight': 790.2725}]}
#
# Metadata for http://127.0.0.1:8082/chembl.target:CHEMBL3467: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sabiork.kineticrecord:5046: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/atc:A10BA02: {'metadata': []}
# Metadata for http://127.0.0.1:8082/pharmgkb.pathways:PA146123006: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pharmgkb.drug:PA448710: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pharmgkb.disease:PA447218: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ttd.target:TTDS00056: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ttd.drug:DAP000773: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/lgic:5HT3Arano: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/neuromorpho:Rosa2: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/chemidplus:57-27-2: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ctd.chemical:D001151: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biosystems:001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/neurondb:265: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ctd.gene:101: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ctd.disease:D053716: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/bionumbers:104674: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/drugbank:DB00001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/t3db:T3D0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/smpdb:SMP00001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/MI:0308: None
#
# Metadata for http://127.0.0.1:8082/genedb:LinJ.20.0070: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biomodels.teddy:TEDDY_0000066: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/phosphosite.protein:12300: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/CL:0000232: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/BTO:0000146: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biomodels.kisao:KISAO_0000057: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pdb-ccd:AB0: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/PATO:0001998: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/glycomedb:G77500AY: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/lipidbank:BBA0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/smart:SM00015: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cdd:cd00400: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/prodom:PD10000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/kegg.orthology:K00001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mmdb:50885: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/imex:IM-19210-3: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ro:RO_0002533: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/irefweb:617102: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mpid:172: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/phosphosite.residue:2842: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/neurolex:Birnlex_721: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/asap:ABE-0009634: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sabiork.ec:2.7.1.1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/opb:OPB_00573: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/obi:OBI_0000070: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/jws:curien: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/modeldb:45539: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/subtiwiki:BSU29180: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/doqcs.pathway:131: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/doqcs.model:57: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/UO:0000080: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pid.pathway:pi3kcipathway: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/PR\:000000024: None
#
# Metadata for http://127.0.0.1:8082/clinicaltrials:NCT00222573: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/chemspider:56586: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/omia:1000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cgd:CAL0003079: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/csa:1a05: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ncit:C80519: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/antweb:casent0106247: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biocatalogue.service:614: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pmc:PMC3084216: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/amoebadb:EDI_244000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/atcc:11303: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/microsporidia:ECU03_0820i: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/plasmodb:PF11_0344: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cryptodb:cgd7_230: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/giardiadb:GL50803_102438: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/trichdb:TVAG_386080: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/beetlebase:TC010103: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/bdgp.insertion:KG09531: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/tritrypdb:Tb927.8.620: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/toxoplasma:TGME49_053730: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/bold.taxonomy:27267: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dbprobe:1000000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/unists:456789: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dbest:BP100000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dbsnp:rs121909098: {'metadata': [{'@context': 'http://schema.org', '@type': 'Dataset', 'name': 'rs121909098', 'description': 'SNV-Single Nucleotide Variation', 'version': 'Build 153', 'license': 'Open Access', 'distribution': {'@type': 'DataDownload', 'encodingFormat': 'JSON', 'contentUrl': 'https://api.ncbi.nlm.nih.gov/variation/v0/beta/refsnp/121909098'}, 'about': {'@type': 'Thing', 'description': 'Alleles: C>T'}, 'sourceOrganization': 'dbSNP', 'datePublished': 'July 9, 2019'}]}
#
# Metadata for http://127.0.0.1:8082/ecogene:EG10173: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/greengenes:100000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/bdgp.est:EY223054.1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/grin.taxonomy:19333: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gabi:2679240: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hinv.locus:HIX0004394: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hinv.transcript:HIT000195363: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/homd.seq:SEQF1003: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hinv.protein:HIP000030660: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/homd.taxon:811: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/isfinder:ISA1083-2: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ird.segment:CY077097: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/jcm:17254: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/img.taxon:648028003: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mycobank:349124: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/maizegdb.locus:25011: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/img.gene:638309541: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pseudomonas:PSEEN0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/nbrc:00001234: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gramene.protein:78073: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gramene.gene:GR:0080039: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gramene.taxonomy:GR_tax:013681: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gramene.qtl:CQG5: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/xenbase:922462: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sgn:0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/edam:data_1664: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/bioportal:1046: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/miriam.resource:MIR:00100005: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/arachnoserver:AS000060: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pmdb:PM0012345: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biocyc:ECOLI:CYT-D-UBIOX-CPLX: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/paleodb:83088: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cazy:GT10: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/goa:P12345: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/compulyeast:O08709: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/eggnog:veNOG12876: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/echobase:EB0170: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ensembl.bacteria:MU9_3181: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ensembl.protist:PF3D7_1328700: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/disprot:DP00003: {'metadata': [{'@context': 'http://schema.org/', '@type': 'DataCatalog', '@id': 'https://disprot.org', 'name': 'DisProt', 'description': 'Database of manually annotated intrisically disordered proteins', 'url': 'https://disprot.org', 'publication': {'@type': 'PublicationEvent', 'name': '', 'url': 'https://doi.org/10.1093/nar/gkz975', 'sameAs': ['https://academic.oup.com/nar/advance-article/doi/10.1093/nar/gkz975/5622715']}, 'keywords': ['IDP', 'IDPs', 'DisProt', 'intrinsic protein disorder', 'protein annotation', 'protein disorder'], 'sourceOrganization': [{'@type': 'Organization', 'name': 'University of Padua, Department of Biomedical Sciences, BioComputing UP', 'url': 'http://protein.bio.unipd.it'}], 'provider': [{'@type': 'Person', 'name': 'Silvio Tosatto', 'email': 'silvio.tosatto@unipd.it'}], 'datePublished': '2019-09', 'dateModified': '2019-09', 'encodingFormat': 'text/html', 'license': {'@type': 'CreativeWork', 'name': 'Creative Commons CC4 Attribution', 'url': 'https://creativecommons.org/licenses/by/4.0/'}, 'identifier': 'https://www.ebi.ac.uk/miriam/main/datatypes/MIR:00000199', 'dataset': {'@context': 'http://schema.org', '@type': 'Dataset', 'name': 'DisProt', 'description': 'Database of manually annotated intrisically disordered proteins', 'url': 'https://disprot.org', 'identifier': 'https://www.ebi.ac.uk/miriam/main/datatypes/MIR:00000199', 'keywords': ['IDP', 'IDPs', 'DisProt', 'intrinsic protein disorder', 'protein annotation', 'protein disorder'], 'includedInDataCatalog': 'http://disprot.org', 'creator': {'@type': 'Organization', 'name': 'University of Padua, Department of Biomedical Sciences, BioComputing UP', 'url': 'http://protein.bio.unipd.it'}, 'version': '2019-09', 'license': {'@type': 'CreativeWork', 'name': 'Creative Commons CC4 Attribution', 'url': 'https://creativecommons.org/licenses/by/4.0/'}}}]}
#
# Metadata for http://127.0.0.1:8082/ensembl.metazoa:FBtr0084214: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hcvdb:M58335: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ensembl.plant:AT1G73965: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ensembl.fungi:CADAFLAT00006211: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/genatlas:HBB: {'metadata': []}
# Metadata for http://127.0.0.1:8082/cath.domain:1cukA01: {'metadata': [{'@context': 'http://schema.org', '@type': 'WebSite', 'url': 'http://www.cathdb.info//version/v4_2_0/domain/1cukA01', 'mainEntityOfPage': {'@type': ['DataRecord'], 'identifier': 'cath.domain:1cukA01', 'isPartOf': {'@type': 'Dataset', '@id': 'CATH release v4_2_0'}, 'mainEntity': {'@type': ['StructuredValue', 'BioChemEntity'], 'additionalType': 'http://semanticscience.org/resource/SIO_001379', 'identifier': 'cathdomain:1cukA01', 'name': 'CATH Domain - 1cukA01 (PDB: 1cuk, chain A, domain domain.domain_number', 'isContainedIn': [{'@type': ['StructuredValue', 'BioChemEntity'], 'additionalType': 'http://semanticscience.org/resource/SIO_001379', 'additionalProperty': {'@type': 'BioChemEntity', '@id': 'http://identifiers.org/cath.superfamily:1.10.8.10', 'identifier': '1.10.8.10', 'name': '"winged helix" repressor DNA binding domain'}}, {'@type': 'DataRecord', 'identifier': '1cuk', 'isPartOf': {'@type': 'Dataset', '@id': 'http://pdb.org'}, 'name': '1cuk', 'additionalType': 'http://semanticscience.org/resource/SIO_011119', 'additionalProperty': [{'@type': 'StructuredValue', 'additionalType': 'http://semanticscience.org/resource/SIO_010000', 'name': 'organism', 'value': 'http://identifiers.org/taxonomy:9606'}, {'@type': 'StructuredValue', 'name': 'method', 'value': 'xray crystallography'}, {'@type': 'StructuredValue', 'name': 'resolution', 'value': '2.2Ã\x85'}]}], 'additionalProperty': [{'@type': 'http://semanticscience.org/resource/SIO_001379', 'name': 'domain annotation', 'value': {'@type': ['StructuredValue', 'BioChemEntity'], 'additionalType': 'http://semanticscience.org/resource/SIO_001379', 'identifier': 'cath.domain:1cukA01', 'name': 'CATH Domain - 1cukA01 (PDB: 1cuk, chain A, domain domain.domain_number', 'location': [{'@type': 'PropertyValue', 'minValue': 2, 'maxValue': 123}, {'@type': 'PropertyValue', 'minValue': 234, 'maxValue': 431}]}}]}}}]}
#
# Metadata for http://127.0.0.1:8082/cath.superfamily:1.10.10.200: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/genefarm:4892: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hogenom:HBG284870: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gpcrdb:RL3R1_HUMAN: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hssp:102l: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/genetree:ENSGT00550000074763: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/myco.tuber:Rv1908c: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/myco.marinum:MMAR_2462: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/myco.smeg:MSMEG_3769: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/orthodb:Q9P0K8: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/myco.lepra:ML0224: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/orphanet:85163: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/peroxibase:5282: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pmap.substratedb:1915: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/phylomedb:Phy000CLXM_RAT: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pmap.cutdb:25782: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/protclustdb:O80725: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pmp:Q0VCA6: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/protonet.cluster:4349895: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/DOID\:11337: None
#
# Metadata for http://127.0.0.1:8082/protonet.proteincard:16941567: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/swiss-model:P23298: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/CCO\:0000003: None
#
# Metadata for http://127.0.0.1:8082/rebase:101: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/vectorbase:ISCW007415: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mirbase.mature:MIMAT0000001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cas:50-00-0: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/nextprot:NX_O00165: {'metadata': [{'@context': 'http://schema.org', '@graph': [{'@type': 'DataCatalog', '@id': 'http://identifiers.org/nextprot/', 'name': '{{nm.title}}', 'description': '{{nm.description}}', 'url': 'https://www.nextprot.org/', 'keywords': 'nextprot,UniProt,Human,Proteins,Proteome,Proteomics,protein database,protein knowledgebase,protein resource,human protein,human proteome,cancer variants portal,ion channels variants portal,function,medical,disease,expression,interactions,sequence,isoform,mutation,variant,phenotypes,proteomics,peptide,structure,3D,unicity checker,peptide uniqueness checker,annotation,biocuration,chromosomes,protein validation,protein-coding genes,post-translational modifications,ptm,data integration,systems biology,genetic variations,RDF data model,SPARQL endpoint,api,rest', 'thumbnailUrl': 'https://www.nextprot.org/img/np-x.png', 'sourceOrganization': {'@type': 'Organization', 'name': 'SIB Swiss Institute of Bioinformatics', 'url': 'https://www.sib.swiss/', 'logo': 'https://www.nextprot.org/img/sib.png'}, 'citation': {'@type': 'ScholarlyArticle', 'headline': 'The neXtProt knowledgebase on human proteins: 2017 update.', 'author': [{'@type': 'Person', 'name': 'Gaudet P'}, {'@type': 'Person', 'name': 'Michel PA'}, {'@type': 'Person', 'name': 'Zahn-Zabal M'}, {'@type': 'Person', 'name': 'Britan A'}, {'@type': 'Person', 'name': 'Cusin I'}, {'@type': 'Person', 'name': 'Domagalski M'}, {'@type': 'Person', 'name': 'Duek PD'}, {'@type': 'Person', 'name': 'Gateau A'}, {'@type': 'Person', 'name': 'Gleizes A'}, {'@type': 'Person', 'name': 'Hinard V'}, {'@type': 'Person', 'name': 'Rech de Laval V'}, {'@type': 'Person', 'name': 'Lin JJ'}, {'@type': 'Person', 'name': 'Nikitin F'}, {'@type': 'Person', 'name': 'Schaeffer M'}, {'@type': 'Person', 'name': 'Teixeira D'}, {'@type': 'Person', 'name': 'Lane L'}, {'@type': 'Person', 'name': 'Bairoch A'}], 'isPartOf': [{'@type': 'Periodical', 'name': 'Nucleic acids research'}, {'@type': 'PublicationVolume', 'volumeNumber': '45'}, {'@type': 'PublicationIssue', 'datePublished': '2017', 'issueNumber': 'D1'}], 'sameAs': ['https://doi.org/10.1093/nar/gkw1062', 'http://europepmc.org/abstract/MED/27899619', 'https://www.ncbi.nlm.nih.gov/pubmed/27899619', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5210547']}, 'dataset': [{'@type': 'Dataset', 'name': 'neXtProt entries', 'description': 'The collection of neXtProt entries for human proteins', 'url': 'https://www.nextprot.org', 'keywords': 'nextprot,Human,Proteins,Proteome,Proteomics,protein database,protein knowledgebase,protein resource,human protein,human proteome,function,medical,disease,expression,interactions,sequence,isoform,mutation,variant,phenotypes,proteomics,peptide,structure,3D,annotation,biocuration,chromosomes,protein validation,protein-coding genes,post-translational modifications,ptm,data integration,systems biology,genetic variations,UniProt', 'distribution': [{'@type': 'DataDownload', 'contentUrl': 'ftp://ftp.nextprot.org/pub/current_release/xml/nextprot_all.xml.gz', 'fileFormat': 'XML'}, {'@type': 'DataDownload', 'fileFormat': 'RDF'}, {'@type': 'DataDownload', 'contentUrl': 'ftp://ftp.nextprot.org/pub/current_release/peff/nextprot_all.peff.gz', 'fileFormat': 'PEFF'}, {'@type': 'DataDownload', 'contentUrl': 'ftp://ftp.nextprot.org/pub/current_release/md5/nextprot_sequence_md5.txt', 'fileFormat': 'TXT'}, {'@type': 'DataDownload', 'contentUrl': 'https://api.nextprot.org/export/entries/all.fasta', 'fileFormat': 'FASTA'}], 'potentialAction': {'@type': 'SearchAction', 'target': 'https://www.nextprot.org/proteins/search?query={query}', 'query-input': 'required name=query'}, 'license': {'@type': 'CreativeWork', 'name': 'Creative Commons CC BY 4.0 Attribution', 'url': 'https://creativecommons.org/licenses/by/4.0/'}}, {'@type': 'Dataset', 'name': 'Caloha', 'description': 'An ontology of human anatomy and human cell types.', 'url': 'ftp://ftp.nextprot.org/pub/current_release/contro ...
#
# Metadata for http://127.0.0.1:8082/kegg.metagenome:T30002: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/narcis:oai:cwi.nl:4725: {'metadata': [{'@context': 'http://schema.org/', '@type': 'CreativeWork', '@id': 'https://www.persistent-identifier.nl/urn:nbn:nl:ui:18-4725', 'additionalType': 'other', 'name': 'Mathematical modelling in blood coagulation : simulation and parameter estimation', 'headline': 'Mathematical modelling in blood coagulation : simulation and parameter estimation', 'datePublished': '1997-01-01', 'description': "textabstractThis paper describes the mathematical modelling of a part of the blood coagulation mechanism. The model includes the activation of factor X by a purified enzyme from Russel's Viper Venom (RVV), factor V and prothrombin, and also comprises the inactivation of the products formed. In this study we assume that in principle the mechanism of the process is known. However, the exact structure of the mechanism is unknown, and the process still can be described by different mathematical models. These models are put to test by measuring their capacity to explain the course of thrombin generation as observed in plasma after recalcification in presence of RVV. The mechanism studied is mathematically modelled as a system of differential-algebraic equations (DAEs). Each candidate model contains some freedom, which is expressed in the model equations by the presence of unknown parameters. For example, reaction constants or initial concentrations are unknown. The goal of parameter estimation is to determine these unknown parameters in such a way that the theoretical (i.e., computed) results fit the experimental data within measurement accuracy and to judge which modifications of the chemical reaction scheme allow the best fit. We present results on model discrimination and estimation of reaction constants, which are hard to obtain in another way.", 'inLanguage': 'en', 'publisher': 'CWI', 'mainEntityOfPage': 'https://www.narcis.nl/publication/RecordID/oai%3Acwi.nl%3A4725', 'url': 'https://ir.cwi.nl/pub/4725', 'identifier': {'@type': 'PropertyValue', 'name': 'nbn', 'value': 'urn:NBN:nl:ui:18-4725'}, 'author': [{'@context': 'http://schema.org/', '@type': 'Person', 'name': 'W.J.H. Stortelder (Walter)'}, {'@context': 'http://schema.org/', '@type': 'Person', '@id': 'http://isni.org/isni/0000000108922067', 'name': 'P.W. Hemker (Piet)', 'identifier': {'@type': 'PropertyValue', 'name': 'isni', 'value': '0000000108922067'}}, {'@context': 'http://schema.org/', '@type': 'Person', 'name': 'H.C. Hemker'}]}]}
#
# Metadata for http://127.0.0.1:8082/kegg.genome:eco: {'metadata': []}
# Metadata for http://127.0.0.1:8082/jcsd:J55.713G: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pharmgkb.gene:PA131: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/scretf:RSC3: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/insdc.sra:SRX000007: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/PW:0000208: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/napp:351: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mirnest:MNEST029358: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/noncodev3:377550: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/virsirna:virsi1909: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/elm:CLV_MEL_PAP_1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mimodb:1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/bykdb:A0A009E7X8: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sitex:1000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/topfind:Q9UKQ2: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/combine.specifications:sbgn.er.level-1.version-1.2: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cellimage:24801: {'metadata': [{'@context': 'http://schema.org', '@type': 'Dataset', 'name': 'Tatyana M. Svitkina, Gary G. Borisy (2011) CIL:24801, Xenopus laevis, fibroblast. CIL. Dataset', 'description': 'Structural differentiation of actin network in lamellipodium. Electron micrograph of Xenopus fibroblasts after regular extraction in the presence of polyethelene glycol (PEG) and phalloidin. While the actin network in the front zone of these cels remains dense, the actin network at the lamellipodial rear disassembled in the course of unprotected extraction (CIL 24800).  Image corresponds to Figure 6c from J Cell Biol. 1999 May 31;145(5):1009-26.', 'identifier': 'doi:10.7295/W9CIL24801', 'license': 'http://creativecommons.org/licenses/by-nc-sa/3.0', 'distribution': {'@type': 'DataDownload', 'contentUrl': 'https://cildata.crbs.ucsd.edu/media/images/24801/24801.zip'}, 'sourceOrganization': 'CIL', 'datePublished': '2011-06-02'}]}
#
# Metadata for http://127.0.0.1:8082/mipmod:HOSAPI0399: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/conoserver:2639: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/huge:KIAA0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cabri:dsmz_mutz-id:ACC 291: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dictybase.gene:DDB_G0267522: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/string:P53350: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/bindingdb:e999: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/phenolexplorer:75: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/stitch:BQJCRHHNABKAKU: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/atcvet:QJ51RV02: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/snomedct:284196006: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mesh.2012:17186: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/knapsack:C00000001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/massbank:PB000166: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cdpd:63250: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gmd:68513255-fc44-4041-bc4b-4fd2fae7541d: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/homologene:1000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/abs:A0014: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/umbbd.compound:c0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dpv:100: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/apd:01001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/chemdb:3966782: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/aceview.worm:aap-1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/imgt.ligm:M94112: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/iuphar.receptor:101: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/worfdb:T01B6.1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/soybase:BARC-013845-01256: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/nextdb:6b1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/hamap:MF_01400: {'metadata': [{'@context': ['https://schema.org/'], '@type': 'Organization', 'url': 'https://hamap.expasy.org', 'name': 'HAMAP', 'logo': 'https://hamap.expasy.org//images/hamap/HAMAP_Red_Logo.png', 'memberof': {'@type': 'NGO', 'name': 'SIB Swiss Institute of Bioinformatics', 'url': 'https://sib.swiss/'}, 'parentOrganization': {'@type': 'Organization', 'name': 'ExPASy', 'url': 'https://www.expasy.org/'}}]}
#
# Metadata for http://127.0.0.1:8082/cgsc:74: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/arrayexpress.platform:A-GEOD-50: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dragondb.dna:3hB06: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/rouge:mKIAA4200: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/merops.family:S1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dragondb.locus:DEF: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dragondb.allele:cho: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dragondb.protein:AMDEFA: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/issn:0745-4570: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/niaest:J0705A10: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/nasc:N1899: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/pazar:TF0001053: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mo:ArrayGroup: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/rnamods:101: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/PO:0009089: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/tgd:TTHERM_00648910: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/treebase:TB2:S1000: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cst.ab:3305: {'metadata': [{'@context': 'http://schema.org/', '@type': 'Product', 'name': 'GCN5L2 (C26A10) Rabbit mAb', 'Category': ' Primary Antibodies', 'additionalProperty': [{'@type': 'PropertyValue', 'name': 'APPLICATIONS', 'value': 'W,IP,IF'}, {'@type': 'PropertyValue', 'name': 'REACTIVITY', 'value': 'H,M,R,Mk'}, {'@type': 'PropertyValue', 'name': 'SENSITIVITY', 'value': 'Endogenous'}, {'@type': 'PropertyValue', 'name': 'MW(kDa)', 'value': '94'}, {'@type': 'PropertyValue', 'name': 'SOURCE', 'value': 'Rabbit'}, {'@type': 'PropertyValue', 'name': 'Product Citations', 'value': '29'}], 'image': '', 'description': '', 'brand': 'Cell Signaling Technology'}]}
#
# Metadata for http://127.0.0.1:8082/tigrfam:TIGR00010: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/atfdb.family:CUT: {'metadata': [{'@context': 'https://schema.org', '@graph': [{'@type': 'WebSite', '@id': 'https://www.bioguo.org/#website', 'url': 'https://www.bioguo.org/', 'name': 'Les produits bio', 'potentialAction': {'@type': 'SearchAction', 'target': 'https://www.bioguo.org/?s={search_term_string}', 'query-input': 'required name=search_term_string'}}]}]}
#
# Metadata for http://127.0.0.1:8082/sdbs:4544: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dbg2introns:Cu.me.I1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/iuphar.family:78: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/vbase2:humIGHV025: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/genecards:ABL1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/spike.map:spike00001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/metlin:1455: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/umbbd.enzyme:e0333: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mmrrc:70: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/umbbd.reaction:r0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/umbbd.pathway:ala: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dictybase.est:DDB0016567: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/umbbd.rule:bt0001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mirex:165a: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/imgt.hla:A*01:01:01:01: {'metadata': []}
#
# ...
#
# Metadata for http://127.0.0.1:8082/aop:98: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biotools:uniprotkb: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ngl:GLDS-141: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/arraymap:icdom:8500_3: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/begdb:4214: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/erv:THE1B: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/napdi:28: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/crisprdb:551115: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mzspec:PXD002255::ES_XP_Ubi_97H_HCD_349:scan:9617:LAEIYVNSSFYK/2: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sugarbind:lectins/172: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sisu:17:41223048: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/licebase:EMLSAT00000003403: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gnpis:AY109603: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/rnacentral:URS0000759CF4: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/microscope:5601141: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/swissregulon:AHR: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/validatordb:ByStructure/2h6o: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biominder:aef4c195-9cf9-46db-a12a-7cfd1ff3eec3: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/neurovault.collection:3304: {'metadata': [{'@context': 'https://schema.org', '@type': 'Organization', 'name': 'NeuroVault', 'url': 'https://neurovault.org', 'logo': 'https://neurovault.org/static/images/neurovault-logo.png', 'sameAs': ['https://en.wikipedia.org/wiki/NeuroVault', 'https://twitter.com/vaultneuro']}, {'@context': 'https://schema.org', '@type': 'WebSite', 'url': 'https://neurovault.org/', 'potentialAction': {'@type': 'SearchAction', 'target': 'https://neurovault.org/search?q={search_term_string}', 'query-input': 'required name=search_term_string'}}]}
#
# Metadata for http://127.0.0.1:8082/vmhmetabolite:h2o: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/NMR:1000003: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/vmhreaction:HEX1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ascl:1801.012: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/facebase:FB00000917: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/eu89h:jrc-eurl-ecvam-chemagora: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gudmap:Q-2958: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/minid:b97957: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mex:36: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mw.study:ST000900: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gpmdb:GPM32310002988: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mw.project:PR000001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/massive:MSV000082131: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/fplx:RAS: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/aop.events:3: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/aop.stressor:9: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/aop.relationships:5: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/swh:1:rev:309cf2674ee7a0749978cf8265ab91a60aea0f7d: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dev.ga4ghdos:23fa7b4b-9d68-429b-aece-658b11124bb3#2017-03-24T18:43:16.886826-05:00: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/comptox:DTXSID2021028: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/complexportal:CPX-2158: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ligandbook:785: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/rbk:Q-2958: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/kaggle:nasa/kepler-exoplanet-search-results: {'metadata': [{'@context': 'http://schema.org/', '@type': 'Dataset', 'name': 'Kepler Exoplanet Search Results', 'description': '### Context\n\nThe Kepler Space Observatory is a NASA-build satellite that was launched in 2009. The telescope is dedicated to searching for exoplanets in star systems besides our own, with the ultimate goal of possibly finding other habitable planets besides our own. The original mission ended in 2013 due to mechanical failures, but the telescope has nevertheless been functional since 2014 on a "K2" extended mission.\n\nKepler had verified 1284 new exoplanets as of May 2016. As of October 2017 there are over 3000 confirmed exoplanets total (using all detection methods, including ground-based ones). The telescope is still active and continues to collect new data on its extended mission.\n\n### Content\n\nThis dataset is a cumulative record of all observed Kepler "objects of interest" — basically, all of the approximately 10,000 exoplanet candidates Kepler has taken observations on.\n\nThis dataset has an extensive data dictionary, which can be accessed [here](https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html). Highlightable columns of note are:\n\n* `kepoi_name`: A KOI is a target identified by the Kepler Project that displays at least one transit-like sequence within Kepler time-series photometry that appears to be of astrophysical origin and initially consistent with a planetary transit hypothesis\n* `kepler_name`: [These names] are intended to clearly indicate a class of objects that have been confirmed or validated as planets—a step up from the planet candidate designation.\n* `koi_disposition`: The disposition in the literature towards this exoplanet candidate. One of CANDIDATE, FALSE POSITIVE, NOT DISPOSITIONED or CONFIRMED.\n* `koi_pdisposition`: The disposition Kepler data analysis has towards this exoplanet candidate. One of FALSE POSITIVE, NOT DISPOSITIONED, and CANDIDATE.\n* `koi_score `: A value between 0 and 1 that indicates the confidence in the KOI disposition. For CANDIDATEs, a higher value indicates more confidence in its disposition, while for FALSE POSITIVEs, a higher value indicates less confidence in that disposition.\n\n### Acknowledgements\n\nThis dataset was published as-is by NASA. You can access the original table [here](https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&amp;config=koi). More data from the Kepler mission is available from the same source [here](https://exoplanetarchive.ipac.caltech.edu/docs/data.html).\n\n### Inspiration\n\n* How often are exoplanets confirmed in the existing literature disconfirmed by measurements from Kepler? How about the other way round?\n* What general characteristics about exoplanets (that we can find) can you derive from this dataset?\n* What exoplanets get assigned names in the literature? What is the distribution of confidence scores?\n\nSee also: the [Kepler Labeled Time Series](https://www.kaggle.com/keplersmachines/kepler-labelled-time-series-data) and [Open Exoplanets Catalogue](https://www.kaggle.com/mrisdal/open-exoplanet-catalogue) datasets.', 'url': 'https://www.kaggle.com/nasa/kepler-exoplanet-search-results', 'sameAs': '', 'version': 2, 'keywords': ['society and social sciences &gt; society &gt; business', 'natural and physical sciences', 'technology and applied sciences', 'natural and physical sciences &gt; physical sciences &gt; astronomy', 'natural and physical sciences &gt; physical sciences &gt; space'], 'license': {'@type': 'CreativeWork', 'name': 'CC0: Public Domain', 'url': 'https://creativecommons.org/publicdomain/zero/1.0/'}, 'identifier': '2894', 'includedInDataCatalog': {'@type': 'DataCatalog', 'name': 'Kaggle', 'url': 'https://www.kaggle.com'}, 'creator': {'@type': 'Organization', 'name': 'NASA', 'url': 'https://www.kaggle.com/nasa', 'image': 'https://storage.googleapis.com/k ...
#
# Metadata for http://127.0.0.1:8082/idoo:DataCollection: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/oci:1-18: {'metadata': []}
# Metadata for http://127.0.0.1:8082/FOODON:03307879: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ricenetdb.gene:LOC_Os01g49190.1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ricenetdb.protein:LOC_Os01g49190: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gtex:BRIP1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ricenetdb.compound:OSC1416: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ricenetdb.reaction:OSR0818: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ricenetdb.mirna:osa-miR446: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/encode:ENCSR163RYW: {'metadata': [{'documents': ['/documents/0994a79b-44ae-49ef-a44c-6b2ebf85a230/', '/documents/7047cb04-68a7-48be-b58b-6991f41ffbb6/'], 'hub': '/experiments/ENCSR163RYW/@@hub/hub.txt', 'replication_type': 'isogenic', 'revoked_files': [], 'related_series': [], 'aliases': ['michael-snyder:HEK_eGFP-ZNF189_FRT_ChIP'], 'assembly': ['GRCh38', 'hg19'], 'category_slims': [], 'assay_slims': ['DNA binding'], 'supersedes': [], 'dbxrefs': ['GEO:GSE127450'], 'biosample_ontology': {'classification': 'cell line', 'aliases': [], 'dbxrefs': ['Cellosaurus:CVCL_0045'], 'status': 'released', 'organ_slims': ['epithelium', 'kidney'], 'developmental_slims': ['mesoderm'], '@id': '/biosample-types/cell_line_EFO_0001182/', 'name': 'cell_line_EFO_0001182', 'synonyms': ['human embryonic kidney cell'], 'term_name': 'HEK293', 'references': [], 'system_slims': ['excretory system'], 'uuid': '014c9be0-20d4-4df5-b816-b0dca4cfee9d', 'cell_slims': ['epithelial cell'], '@type': ['BiosampleType', 'Item'], 'schema_version': '1', 'term_id': 'EFO:0001182'}, '@type': ['Experiment', 'Dataset', 'Item'], 'schema_version': '28', 'assay_term_name': 'ChIP-seq', 'audit': {'WARNING': [{'level': 40, 'level_name': 'WARNING', 'name': 'audit_experiment', 'category': 'mild to moderate bottlenecking', 'detail': 'PBC1 (PCR Bottlenecking Coefficient 1, M1/M_distinct) is the ratio of the number of genomic locations where exactly one read maps uniquely (M1) to the number of genomic locations where some reads map (M_distinct). A PBC1 value in the range 0 - 0.5 is severe bottlenecking, 0.5 - 0.8 is moderate bottlenecking, 0.8 - 0.9 is mild bottlenecking, and > 0.9 is no bottlenecking. PBC1 value > 0.9 is recommended, but > 0.8 is acceptable.  ENCODE processed alignments file {ENCFF634VOX|/files/ENCFF634VOX/} was generated from a library with PBC1 value of 0.82.', 'path': '/experiments/ENCSR163RYW/'}, {'level': 40, 'level_name': 'WARNING', 'name': 'audit_experiment', 'category': 'mild to moderate bottlenecking', 'detail': 'PBC2 (PCR Bottlenecking Coefficient 2, M1/M2) is the ratio of the number of genomic locations where exactly one read maps uniquely (M1) to the number of genomic locations where two reads map uniquely (M2). A PBC2 value in the range 0 - 1 is severe bottlenecking, 1 - 3 is moderate bottlenecking, 3 - 10 is mild bottlenecking, > 10 is no bottlenecking. PBC2 value > 10 is recommended, but > 3 is acceptable.  ENCODE processed alignments file {ENCFF634VOX|/files/ENCFF634VOX/} was generated from a library with PBC2 value of 5.54.', 'path': '/experiments/ENCSR163RYW/'}, {'level': 40, 'level_name': 'WARNING', 'name': 'audit_experiment', 'category': 'mild to moderate bottlenecking', 'detail': 'PBC1 (PCR Bottlenecking Coefficient 1, M1/M_distinct) is the ratio of the number of genomic locations where exactly one read maps uniquely (M1) to the number of genomic locations where some reads map (M_distinct). A PBC1 value in the range 0 - 0.5 is severe bottlenecking, 0.5 - 0.8 is moderate bottlenecking, 0.8 - 0.9 is mild bottlenecking, and > 0.9 is no bottlenecking. PBC1 value > 0.9 is recommended, but > 0.8 is acceptable.  ENCODE processed alignments file {ENCFF431LTO|/files/ENCFF431LTO/} was generated from a library with PBC1 value of 0.84.', 'path': '/experiments/ENCSR163RYW/'}, {'level': 40, 'level_name': 'WARNING', 'name': 'audit_experiment', 'category': 'mild to moderate bottlenecking', 'detail': 'PBC2 (PCR Bottlenecking Coefficient 2, M1/M2) is the ratio of the number of genomic locations where exactly one read maps uniquely (M1) to the number of genomic locations where two reads map uniquely (M2). A PBC2 value in the range 0 - 1 is severe bottlenecking, 1 - 3 is moderate bottlenecking, 3 - 10 is mild bottlenecking, > 10 is no bottlenecking. PBC2 value > 10 is recommended, but > 3 is acceptable.  ENCODE processed alignments file {ENCFF431LTO|/files/ENCFF431LTO/} was generated from a library with PBC2 value of 6.09.', 'path': ' ...
#
# Metadata for http://127.0.0.1:8082/asin:0471491039: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/oclc:634515043: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ga4ghdos:dg.4503/01b048d0-e128-4cb0-94e9-b2d2cab7563d: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/oid:2.16.840: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/flowrepository:FR-FCM-ZYGW: {'metadata': []}
# Metadata for http://127.0.0.1:8082/hpscreg:BCRTi001-A: {'metadata': [{'@context': 'http://schema.org', '@type': 'WebSite', 'url': 'http://hpscreg.eu/', 'potentialAction': {'@type': 'SearchAction', 'target': 'http://hpscreg.eu/search?q={search_term_string}', 'query-input': 'required name=search_term_string'}}]}
#
# Metadata for http://127.0.0.1:8082/addgene:50943: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gdsc:1242: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/bacdive:131392: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ido:0000504: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/isni:000000012281955X: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/lei:HWUPKR0MPOU8FGXBT394: {'metadata': [{'@context': 'http://schema.org', '@type': 'WebSite', 'name': 'Global Legal Entity Identifier Foundation', 'alternateName': 'GLEIF', 'url': 'http://gleif.org', 'potentialAction': {'@type': 'SearchAction', 'target': 'https://www.gleif.org/en/lei/search#query={search_term_string}', 'query-input': 'required name=search_term_string', 'description': 'Search LEI Records'}}, {'@context': 'http://schema.org', '@type': 'WebSite', 'name': 'Global Legal Entity Identifier Foundation', 'alternateName': 'GLEIF', 'url': 'http://gleif.org', 'potentialAction': {'@type': 'SearchAction', 'target': 'https://www.gleif.org/en/lei/search#query={search_term_string}', 'query-input': 'required name=search_term_string', 'description': 'Search LEI Records'}}]}
#
# Metadata for http://127.0.0.1:8082/viaf:75121530: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/sabiork.compound:75: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/spdx:CC-BY-1.0: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/peptideatlas.dataset:PASS01237: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/did:sov:WRfXPg8dantKVubE3HX8pw: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/oryzabase.reference:42840: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/biostudies:S-EPMC6266652: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/seed.reaction:rxn00001: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/occ:br/1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cadsr:3771992: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/erm:ERM00000044: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cid:190000021540: None
#
# Metadata for http://127.0.0.1:8082/classyfire:C0004828: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/gcst:GCST000035: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/mmp.fun:MMP3888430: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/ecyano.experiment:18: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dlxb:6VDC956: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/dlxc:M77F7JM: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/cameo:2019-08-03_00000089_1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/[a-zA-Z]+.+$:AB_262044: None
#
# Metadata for http://127.0.0.1:8082/nemo:smp-m3w9hbe: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/insdc.gca:GCA_000155495.1: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/spp:10.1621/vwN2g2HaX3: {'metadata': []}
#
# Metadata for http://127.0.0.1:8082/worms:146421: None

# %%
print(dataset)
# Out:
# [{'prefix': 'chebi', 'mirId': 'MIR:00000002', 'name': 'ChEBI', 'pattern': '^CHEBI:\\d+$', 'description': "Chemical Entities of Biological Interest (ChEBI) is a freely available dictionary of molecular entities focused on 'small' chemical compounds.", 'created': '2019-06-11T14:15:26.925+0000', 'modified': '2019-06-11T14:15:26.925+0000', 'deprecated': False, 'deprecationDate': None, 'sampleId': '36927', 'namespaceEmbeddedInLui': True, '_links': {'self': {'href': 'https://registry.api.identifiers.org/restApi/namespaces/1'}, 'namespace': {'href': 'https://registry.api.identifiers.org/restApi/namespaces/1'}, 'contactPerson': {'href': 'https://registry.api.identifiers.org/restApi/namespaces/1/contactPerson'}}, 'metadata': []}, {'prefix': 'ensembl', 'mirId': 'MIR:00000003', 'name': 'Ensembl', 'pattern': '^((ENS[FPTG]\\\\d{11}(\\\\.\\\\d+)?)|(FB\\\\w{2}\\\\d{7})|(Y[A-Z]{2}\\\\d{3}[a-zA-Z](\\\\-[A-Z])?)|([A-Z_a-z0-9]+(\\\\.)?(t)?(\\\\d+)?([a-z])?))$', 'description': 'Ensembl is a joint project between EMBL - EBI and the Sanger Institute  to develop a software system which produces and maintains automatic annotation on selected eukaryotic genomes. This collections also references outgroup organisms.', 'created': '2019-06-11T14:15:27.869+0000', 'modified': '2019-06-11T14:15:27.869+0000', 'deprecated': False, 'deprecationDate': None, 'sampleId': 'ENSG00000139618', 'namespaceEmbeddedInLui': False, '_links': {'self': {'href': 'https://registry.api.identifiers.org/restApi/namespaces/7'}, 'namespace': {'href': 'https://registry.api.identifiers.org/restApi/namespaces/7'}, 'contactPerson': {'href': 'https://registry.api.identifiers.org/restApi/namespaces/7/contactPerson'}}, 'metadata': [{'identifier': 'ENSG00000139618', '@context': 'http://schema.org', '@type': 'DataRecord', 'mainEntity': {'description': 'BRCA2 DNA repair associated [Source:HGNC Symbol;Acc:HGNC:1101]', 'identifier': 'ENSG00000139618', '@type': 'Gene', 'isPartOfBioChemEntity': {'@type': 'BioChemEntity', 'name': 'Chromosome 13'}, 'isPartOf': {'name': 'Homo sapiens', 'codeCategory': {'url': 'http://purl.bioontology.org/ontology/NCBITAXON/9606', 'codeValue': '9606', 'sameAs': 'http://purl.uniprot.org/taxonomy/9606', '@type': 'CategoryCode', 'inCodeSet': {'@type': 'CategoryCodeSet', 'name': 'NCBI taxon'}}, '@type': 'BioChemEntity', 'alternateName': 'Human'}, 'name': 'BRCA2'}, 'isPartOf': 'Ensembl Human Gene Set'}]}, {'prefix': 'ec-code', 'mirId': 'MIR:00000004', 'name': 'Enzyme Nomenclature', 'pattern': '^\\d+\\.-\\.-\\.-|\\d+\\.\\d+\\.-\\.-|\\d+\\.\\d+\\.\\d+\\.-|\\d+\\.\\d+\\.\\d+\\.(n)?\\d+$', 'description': 'The Enzyme Classification contains the recommendations of the Nomenclature Committee of the International Union of Biochemistry and Molecular Biology on the nomenclature and classification of enzyme-catalysed reactions.', 'created': '2019-06-11T14:15:28.483+0000', 'modified': '2019-06-11T14:15:28.483+0000', 'deprecated': False, 'deprecationDate': None, 'sampleId': '1.1.1.1', 'namespaceEmbeddedInLui': False, '_links': {'self': {'href': 'https://registry.api.identifiers.org/restApi/namespaces/13'}, 'namespace': {'href': 'https://registry.api.identifiers.org/restApi/namespaces/13'}, 'contactPerson': {'href': 'https://registry.api.identifiers.org/restApi/namespaces/13/contactPerson'}}, 'metadata': []}, {'prefix': 'uniprot', 'mirId': 'MIR:00000005', 'name': 'UniProt Knowledgebase', 'pattern': '^([A-N,R-Z][0-9]([A-Z][A-Z, 0-9][A-Z, 0-9][0-9]){1,2})|([O,P,Q][0-9][A-Z, 0-9][A-Z, 0-9][A-Z, 0-9][0-9])(\\.\\d+)?$', 'description': 'The UniProt Knowledgebase (UniProtKB) is a comprehensive resource for protein sequence and functional information with extensive cross-references to more than 120 external databases. Besides amino acid sequence and a description, it also provides taxonomic data and citation information.', 'created': '2019-06-11T14:15:29.457+0000', 'modified': '2019-06-11T14:15:29.457+0000', 'deprecated': False, 'deprecationDate': None, 'sampleId': 'P0DP23', 'namespaceEmbedded ...

# %%
import pandas as pd


dataset_keys_to_keep = ["prefix", "metadata"]
final_dataset = [{ key: namespace[key] for key in dataset_keys_to_keep } for namespace in dataset]

df = pd.DataFrame.from_dict(final_dataset)

bad_metadata_count = df[df.metadata == 'ERROR'].shape[0]
no_metadata_count = df[df.metadata.map(len) == 0].shape[0]
total_metadata = df.shape[0] - bad_metadata_count - no_metadata_count

print(f"Bad metadata: {bad_metadata_count}")
print(f"No metadata: {no_metadata_count}")
print(f"Contains metadata: {total_metadata}")
# Out:
# Bad metadata: 0
# No metadata: 651
# Contains metadata: 33

# %%
namespaces_with_metadata = df[df.metadata.map(len) != 0]
namespaces_with_metadata
# Out:
#                     prefix                                           metadata
# 1                  ensembl  [{'identifier': 'ENSG00000139618', '@context':...
# 16                reactome  [{'@context': 'http://schema.org', '@type': 'W...
# 29                 prosite  [{'@context': ['https://schema.org/'], '@type'...
# 43                     rgd  [{'@context': 'http://schema.org', '@type': 'D...
# 54                 biogrid  [{'@context': 'https://schema.org/', '@type': ...
# 80         chembl.compound  [{'identifier': 'CHEMBL308052', 'inChIKey': 'B...
# 158                  dbsnp  [{'@context': 'http://schema.org', '@type': 'D...
# 195                disprot  [{'@context': 'http://schema.org/', '@type': '...
# 206            cath.domain  [{'@context': 'http://schema.org', '@type': 'W...
# 232               nextprot  [{'@context': 'http://schema.org', '@graph': [...
# 236                 narcis  [{'@context': 'http://schema.org/', '@type': '...
# 253              cellimage  [{'@context': 'http://schema.org', '@type': 'D...
# 281                  hamap  [{'@context': ['https://schema.org/'], '@type'...
# 298                 cst.ab  [{'@context': 'http://schema.org/', '@type': '...
# 301           atfdb.family  [{'@context': 'https://schema.org', '@graph': ...
# 316                 mobidb  [{'@context': 'http://schema.org', '@type': 'D...
# 336              biosample  [{'@context': ['http://schema.org', {'OBI': 'h...
# 350            fairsharing  [{'@context': 'http://schema.org', '@id': 'htt...
# 352       neurovault.image  [{'@context': 'https://schema.org', '@type': '...
# 435                rgd.qtl  [{'@context': 'http://schema.org', '@type': 'D...
# 436             rgd.strain  [{'@context': 'http://schema.org', '@type': 'D...
# 441          iuphar.ligand  [{'@context': 'http://schema.org', '@id': 'htt...
# 472               genewiki  [{'@context': 'https://schema.org', '@type': '...
# 549      metanetx.chemical  [{'@context': 'https://schema.org', '@type': '...
# 550      metanetx.reaction  [{'@context': 'https://schema.org', '@type': '...
# 551   metanetx.compartment  [{'@context': 'https://schema.org', '@type': '...
# 579            cellosaurus  [{'@context': ['https://schema.org/'], '@type'...
# 582                 cosmic  [{'@context': 'http://schema.org', '@type': 'D...
# 614  neurovault.collection  [{'@context': 'https://schema.org', '@type': '...
# 638                 kaggle  [{'@context': 'http://schema.org/', '@type': '...
# 642                 encode  [{'documents': ['/documents/0994a79b-44ae-49ef...
# 654                hpscreg  [{'@context': 'http://schema.org', '@type': 'W...
# 661                    lei  [{'@context': 'http://schema.org', '@type': 'W...

# %%
# Pie chart style
custom_style = Style(
    opacity='0.8',
    opacity_hover='0.5',
    title_font_size=36,
    tooltip_font_size=10,
    inner_radius=0.75,
    plot_background="rgba(249, 249, 249, 1)"
)

# %%
import pygal
from pygal.style import Style
from IPython.display import SVG, display

metadata_contents_pie = pygal.Pie(height=400, tooltip_border_radius=1, style=custom_style)

metadata_contents_pie.add("Bad metadata", bad_metadata_count)
metadata_contents_pie.add("No metadata", no_metadata_count)
metadata_contents_pie.add("Contains metadata", total_metadata)

display_interactive_pygal(metadata_contents_pie)
# Out:
#     <!DOCTYPE html>
#     <html>
#       <head>
#       <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#       <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#       </head>
#       <body>
#         <figure>
#           <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-c12009ed-8655-443a-99b8-681999f12a67" viewBox="0 0 800 400" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2019-11-20--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-c12009ed-8655-443a-99b8-681999f12a67{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-c12009ed-8655-443a-99b8-681999f12a67 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:36px}#chart-c12009ed-8655-443a-99b8-681999f12a67 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c12009ed-8655-443a-99b8-681999f12a67 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-c12009ed-8655-443a-99b8-681999f12a67 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c12009ed-8655-443a-99b8-681999f12a67 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c12009ed-8655-443a-99b8-681999f12a67 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-c12009ed-8655-443a-99b8-681999f12a67{background-color:rgba(249,249,249,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 path,#chart-c12009ed-8655-443a-99b8-681999f12a67 line,#chart-c12009ed-8655-443a-99b8-681999f12a67 rect,#chart-c12009ed-8655-443a-99b8-681999f12a67 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-c12009ed-8655-443a-99b8-681999f12a67 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .plot &gt; .background{fill:rgba(249,249,249,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .graph{fill:rgba(0,0,0,.87)}#chart-c12009ed-8655-443a-99b8-681999f12a67 text.no_data{fill:rgba(0,0,0,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .title{fill:rgba(0,0,0,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis .line{stroke:rgba(0,0,0,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis text.major{fill:rgba(0,0,0,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.y .guides:hover .guide.line,#chart-c12009ed-8655-443a-99b8-681999f12a67 .line-graph .axis.x .guides:hover .guide.line,#chart-c12009ed-8655-443a-99b8-681999f12a67 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-c12009ed-8655-443a-99b8-681999f12a67 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .reactive{fill-opacity:0.8;stroke-opacity:.8}#chart-c12009ed-8655-443a-99b8-681999f12a67 .ci{stroke:rgba(0,0,0,.87)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .reactive.active,#chart-c12009ed-8655-443a-99b8-681999f12a67 .active .reactive{fill-opacity:0.5;stroke-opacity:.9;stroke-width:4}#chart-c12009ed-8655-443a-99b8-681999f12a67 .ci .reactive.active{stroke-width:1.5}#chart-c12009ed-8655-443a-99b8-681999f12a67 .series text{fill:rgba(0,0,0,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .tooltip rect{fill:rgba(249,249,249,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-c12009ed-8655-443a-99b8-681999f12a67 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-c12009ed-8655-443a-99b8-681999f12a67 .tooltip .value{font-size:1.5em}#chart-c12009ed-8655-443a-99b8-681999f12a67 .bound{font-size:.5em}#chart-c12009ed-8655-443a-99b8-681999f12a67 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-c12009ed-8655-443a-99b8-681999f12a67 .map-element{fill:rgba(249,249,249,1);stroke:rgba(0,0,0,.54) !important}#chart-c12009ed-8655-443a-99b8-681999f12a67 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-c12009ed-8655-443a-99b8-681999f12a67 .color-0,#chart-c12009ed-8655-443a-99b8-681999f12a67 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-c12009ed-8655-443a-99b8-681999f12a67 .color-1,#chart-c12009ed-8655-443a-99b8-681999f12a67 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-c12009ed-8655-443a-99b8-681999f12a67 .color-2,#chart-c12009ed-8655-443a-99b8-681999f12a67 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-c12009ed-8655-443a-99b8-681999f12a67 .text-overlay .color-0 text{fill:black}#chart-c12009ed-8655-443a-99b8-681999f12a67 .text-overlay .color-1 text{fill:black}#chart-c12009ed-8655-443a-99b8-681999f12a67 .text-overlay .color-2 text{fill:black}
# #chart-c12009ed-8655-443a-99b8-681999f12a67 text.no_data{text-anchor:middle}#chart-c12009ed-8655-443a-99b8-681999f12a67 .guide.line{fill:none}#chart-c12009ed-8655-443a-99b8-681999f12a67 .centered{text-anchor:middle}#chart-c12009ed-8655-443a-99b8-681999f12a67 .title{text-anchor:middle}#chart-c12009ed-8655-443a-99b8-681999f12a67 .legends .legend text{fill-opacity:1}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.x text{text-anchor:middle}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.y text{text-anchor:end}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.y text[transform].backwards{text-anchor:start}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.y2 text{text-anchor:start}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.y2 text[transform].backwards{text-anchor:end}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis .guide.line{stroke-dasharray:4,4}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis .major.guide.line{stroke-dasharray:6,6}#chart-c12009ed-8655-443a-99b8-681999f12a67 .horizontal .axis.y .guide.line,#chart-c12009ed-8655-443a-99b8-681999f12a67 .horizontal .axis.y2 .guide.line,#chart-c12009ed-8655-443a-99b8-681999f12a67 .vertical .axis.x .guide.line{opacity:0}#chart-c12009ed-8655-443a-99b8-681999f12a67 .horizontal .axis.always_show .guide.line,#chart-c12009ed-8655-443a-99b8-681999f12a67 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.y .guides:hover .guide.line,#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.y2 .guides:hover .guide.line,#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis.x .guides:hover .guide.line{opacity:1}#chart-c12009ed-8655-443a-99b8-681999f12a67 .axis .guides:hover text{opacity:1}#chart-c12009ed-8655-443a-99b8-681999f12a67 .nofill{fill:none}#chart-c12009ed-8655-443a-99b8-681999f12a67 .subtle-fill{fill-opac

# %%
def get_schema_type(metadata):
    if len(metadata) == 0:
        return None

    # flatten lists of lists... :(
    if isinstance(metadata[0], list):
        metadata[0] = metadata[0][0]
    
    result = metadata[0].get("@type", None)
    if isinstance(result, list):
        result = result[0]
        
    return result

df["metadata_type"] = df["metadata"].map(lambda x: get_schema_type(x))

df[df["metadata"].map(len) != 0]
# Out:
#                     prefix                                           metadata  \
# 1                  ensembl  [{'identifier': 'ENSG00000139618', '@context':...
# 16                reactome  [{'@context': 'http://schema.org', '@type': 'W...
# 29                 prosite  [{'@context': ['https://schema.org/'], '@type'...
# 43                     rgd  [{'@context': 'http://schema.org', '@type': 'D...
# 54                 biogrid  [{'@context': 'https://schema.org/', '@type': ...
# 80         chembl.compound  [{'identifier': 'CHEMBL308052', 'inChIKey': 'B...
# 158                  dbsnp  [{'@context': 'http://schema.org', '@type': 'D...
# 195                disprot  [{'@context': 'http://schema.org/', '@type': '...
# 206            cath.domain  [{'@context': 'http://schema.org', '@type': 'W...
# 232               nextprot  [{'@context': 'http://schema.org', '@graph': [...
# 236                 narcis  [{'@context': 'http://schema.org/', '@type': '...
# 253              cellimage  [{'@context': 'http://schema.org', '@type': 'D...
# 281                  hamap  [{'@context': ['https://schema.org/'], '@type'...
# 298                 cst.ab  [{'@context': 'http://schema.org/', '@type': '...
# 301           atfdb.family  [{'@context': 'https://schema.org', '@graph': ...
# 316                 mobidb  [{'@context': 'http://schema.org', '@type': 'D...
# 336              biosample  [{'@context': ['http://schema.org', {'OBI': 'h...
# 350            fairsharing  [{'@context': 'http://schema.org', '@id': 'htt...
# 352       neurovault.image  [{'@context': 'https://schema.org', '@type': '...
# 435                rgd.qtl  [{'@context': 'http://schema.org', '@type': 'D...
# 436             rgd.strain  [{'@context': 'http://schema.org', '@type': 'D...
# 441          iuphar.ligand  [{'@context': 'http://schema.org', '@id': 'htt...
# 472               genewiki  [{'@context': 'https://schema.org', '@type': '...
# 549      metanetx.chemical  [{'@context': 'https://schema.org', '@type': '...
# 550      metanetx.reaction  [{'@context': 'https://schema.org', '@type': '...
# 551   metanetx.compartment  [{'@context': 'https://schema.org', '@type': '...
# 579            cellosaurus  [{'@context': ['https://schema.org/'], '@type'...
# 582                 cosmic  [{'@context': 'http://schema.org', '@type': 'D...
# 614  neurovault.collection  [{'@context': 'https://schema.org', '@type': '...
# 638                 kaggle  [{'@context': 'http://schema.org/', '@type': '...
# 642                 encode  [{'documents': ['/documents/0994a79b-44ae-49ef...
# 654                hpscreg  [{'@context': 'http://schema.org', '@type': 'W...
# 661                    lei  [{'@context': 'http://schema.org', '@type': 'W...
#
#        metadata_type
# 1         DataRecord
# 16           WebSite
# 29      Organization
# 43           Dataset
# 54           Dataset
# 80   MolecularEntity
# 158          Dataset
# 195      DataCatalog
# 206          WebSite
# 232             None
# 236     CreativeWork
# 253          Dataset
# 281     Organization
# 298          Product
# 301             None
# 316      DataCatalog
# 336       DataRecord
# 350          Dataset
# 352     Organization
# 435          Dataset
# 436          Dataset
# 441       DataRecord
# 472          Article
# 549      DataCatalog
# 550      DataCatalog
# 551      DataCatalog
# 579     Organization
# 582          Dataset
# 614     Organization
# 638          Dataset
# 642       Experiment
# 654          WebSite
# 661          WebSite

# %%
from IPython.display import HTML
import pygal

def display_interactive_pygal(pygal_chart):
    base_html = """
    <!DOCTYPE html>
    <html>
      <head>
      <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
      <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
      </head>
      <body>
        <figure>
          {rendered_chart}
        </figure>
      </body>
    </html>
    """

    return HTML(base_html.format(rendered_chart=pygal_chart.render(is_unicode=True)))

# %%
metadata_type_counts = df.metadata_type.value_counts()
metadata_type_counts
# Out:
# Dataset            9
# Organization       5
# DataCatalog        5
# WebSite            4
# DataRecord         3
# CreativeWork       1
# Article            1
# MolecularEntity    1
# Product            1
# Experiment         1
# Name: metadata_type, dtype: int64

# %%
import pygal
from pygal.style import Style
from IPython.display import SVG, display

metadata_type_counts_list = [{"label": x, "value": y} for x, y in metadata_type_counts.items()]
metadata_type_counts_list

metadata_contents_pie_exploded = pygal.Pie(height=400, tooltip_border_radius=1, style=custom_style, print_values=False)

for metadata_type_count in metadata_type_counts_list:
    metadata_contents_pie_exploded.add(metadata_type_count["label"], metadata_type_count["value"])

display_interactive_pygal(metadata_contents_pie_exploded)
# Out:
#     <!DOCTYPE html>
#     <html>
#       <head>
#       <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#       <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#       </head>
#       <body>
#         <figure>
#           <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5" viewBox="0 0 800 400" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2019-11-20--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:36px}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5{background-color:rgba(249,249,249,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 path,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 line,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 rect,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .plot &gt; .background{fill:rgba(249,249,249,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .graph{fill:rgba(0,0,0,.87)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 text.no_data{fill:rgba(0,0,0,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .title{fill:rgba(0,0,0,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .axis .line{stroke:rgba(0,0,0,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .axis text.major{fill:rgba(0,0,0,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .axis.y .guides:hover .guide.line,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .line-graph .axis.x .guides:hover .guide.line,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .reactive{fill-opacity:0.8;stroke-opacity:.8}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .ci{stroke:rgba(0,0,0,.87)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .reactive.active,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .active .reactive{fill-opacity:0.5;stroke-opacity:.9;stroke-width:4}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .ci .reactive.active{stroke-width:1.5}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .series text{fill:rgba(0,0,0,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .tooltip rect{fill:rgba(249,249,249,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .tooltip .value{font-size:1.5em}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .bound{font-size:.5em}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .map-element{fill:rgba(249,249,249,1);stroke:rgba(0,0,0,.54) !important}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-0,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-1,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-2,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-3,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-4,#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .color-4 a:vis ...
# #chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 text.no_data{text-anchor:middle}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .guide.line{fill:none}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .centered{text-anchor:middle}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .title{text-anchor:middle}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .legends .legend text{fill-opacity:1}#chart-d757d6d4-1de2-4648-a8b7-4e8a93302bc5 .axis.x text{text-anchor:middle}#ch

# %%
def get_metadata_properties(metadata):
    if len(metadata) == 0:
        return [None]

    # flatten lists of lists... :(
    if isinstance(metadata[0], list):
        metadata[0] = metadata[0][0]
    
    result = [x[0] for x in metadata[0].items()]

    return result

df["properties"] = df["metadata"].map(lambda x: get_metadata_properties(x))
df[df["metadata"].map(len) != 0]
# Out:
#                     prefix                                           metadata  \
# 1                  ensembl  [{'identifier': 'ENSG00000139618', '@context':...
# 16                reactome  [{'@context': 'http://schema.org', '@type': 'W...
# 29                 prosite  [{'@context': ['https://schema.org/'], '@type'...
# 43                     rgd  [{'@context': 'http://schema.org', '@type': 'D...
# 54                 biogrid  [{'@context': 'https://schema.org/', '@type': ...
# 80         chembl.compound  [{'identifier': 'CHEMBL308052', 'inChIKey': 'B...
# 158                  dbsnp  [{'@context': 'http://schema.org', '@type': 'D...
# 195                disprot  [{'@context': 'http://schema.org/', '@type': '...
# 206            cath.domain  [{'@context': 'http://schema.org', '@type': 'W...
# 232               nextprot  [{'@context': 'http://schema.org', '@graph': [...
# 236                 narcis  [{'@context': 'http://schema.org/', '@type': '...
# 253              cellimage  [{'@context': 'http://schema.org', '@type': 'D...
# 281                  hamap  [{'@context': ['https://schema.org/'], '@type'...
# 298                 cst.ab  [{'@context': 'http://schema.org/', '@type': '...
# 301           atfdb.family  [{'@context': 'https://schema.org', '@graph': ...
# 316                 mobidb  [{'@context': 'http://schema.org', '@type': 'D...
# 336              biosample  [{'@context': ['http://schema.org', {'OBI': 'h...
# 350            fairsharing  [{'@context': 'http://schema.org', '@id': 'htt...
# 352       neurovault.image  [{'@context': 'https://schema.org', '@type': '...
# 435                rgd.qtl  [{'@context': 'http://schema.org', '@type': 'D...
# 436             rgd.strain  [{'@context': 'http://schema.org', '@type': 'D...
# 441          iuphar.ligand  [{'@context': 'http://schema.org', '@id': 'htt...
# 472               genewiki  [{'@context': 'https://schema.org', '@type': '...
# 549      metanetx.chemical  [{'@context': 'https://schema.org', '@type': '...
# 550      metanetx.reaction  [{'@context': 'https://schema.org', '@type': '...
# 551   metanetx.compartment  [{'@context': 'https://schema.org', '@type': '...
# 579            cellosaurus  [{'@context': ['https://schema.org/'], '@type'...
# 582                 cosmic  [{'@context': 'http://schema.org', '@type': 'D...
# 614  neurovault.collection  [{'@context': 'https://schema.org', '@type': '...
# 638                 kaggle  [{'@context': 'http://schema.org/', '@type': '...
# 642                 encode  [{'documents': ['/documents/0994a79b-44ae-49ef...
# 654                hpscreg  [{'@context': 'http://schema.org', '@type': 'W...
# 661                    lei  [{'@context': 'http://schema.org', '@type': 'W...
#
#        metadata_type                                         properties
# 1         DataRecord  [identifier, @context, @type, mainEntity, isPa...
# 16           WebSite            [@context, @type, url, potentialAction]
# 29      Organization  [@context, @type, url, name, logo, memberof, p...
# 43           Dataset  [@context, @type, name, description, url, keyw...
# 54           Dataset  [@context, @type, name, description, url, keyw...
# 80   MolecularEntity  [identifier, inChIKey, @context, biochemicalIn...
# 158          Dataset  [@context, @type, name, description, version, ...
# 195      DataCatalog  [@context, @type, @id, name, description, url,...
# 206          WebSite           [@context, @type, url, mainEntityOfPage]
# 232             None                                 [@context, @graph]
# 236     CreativeWork  [@context, @type, @id, additionalType, name, h...
# 253          Dataset  [@context, @type, name, description, identifie...
# 281     Organization  [@context, @type, url, name, logo, memberof, p...
# 298          Product  [@context, @type, name, Category, additionalPr...
# 301             None                                 [@context, @graph]
# 316      DataCatalog  [@context, @type, @id, name, description, url,...
# 336       DataRecord  [@context, @type, @id, identifier, dateCreated...
# 350          Dataset  [@context, @id, @type, alternateName, citation...
# 352     Organization         [@context, @type, name, url, logo, sameAs]
# 435          Dataset  [@context, @type, name, description, url, keyw...
# 436          Dataset  [@context, @type, name, description, url, keyw...
# 441       DataRecord  [@context, @id, @type, dct:conformsTo, include...
# 472          Article  [@context, @type, name, url, sameAs, mainEntit...
# 549      DataCatalog  [@context, @type, description, keywords, name,...
# 550      DataCatalog  [@context, @type, description, keywords, name,...
# 551      DataCatalog  [@context, @type, description, keywords, name,...
# 579     Organization  [@context, @type, url, name, memberof, parentO...
# 582          Dataset  [@context, @type, name, description, version, ...
# 614     Organization         [@context, @type, name, url, logo, sameAs]
# 638          Dataset  [@context, @type, name, description, url, same...
# 642       Experiment  [documents, hub, replication_type, revoked_fil...
# 654          WebSite            [@context, @type, url, potentialAction]
# 661          WebSite  [@context, @type, name, alternateName, url, po...

# %%
import pandas as pd

def unnest(df, col, reset_index=False):
    col_flat = pd.DataFrame([[i, x] for i, y in df[col].apply(list).iteritems() for x in y], columns=['I', col])
    col_flat = col_flat.set_index('I')
    df = df.drop(col, 1)
    df = df.merge(col_flat, left_index=True, right_index=True)
    if reset_index:
        df = df.reset_index(drop=True)
    return df

unnested_df = unnest(df, "properties")
unnested_df
# Out:
#         prefix                                           metadata  \
# 0        chebi                                                 []
# 1      ensembl  [{'identifier': 'ENSG00000139618', '@context':...
# 1      ensembl  [{'identifier': 'ENSG00000139618', '@context':...
# 1      ensembl  [{'identifier': 'ENSG00000139618', '@context':...
# 1      ensembl  [{'identifier': 'ENSG00000139618', '@context':...
# ..         ...                                                ...
# 679      cameo                                                 []
# 680       nemo                                                 []
# 681  insdc.gca                                                 []
# 682       rrid                                                 []
# 683        spp                                                 []
#
#     metadata_type  properties
# 0            None        None
# 1      DataRecord  identifier
# 1      DataRecord    @context
# 1      DataRecord       @type
# 1      DataRecord  mainEntity
# ..            ...         ...
# 679          None        None
# 680          None        None
# 681          None        None
# 682          None        None
# 683          None        None
#
# [985 rows x 4 columns]

# %%
df_grouped_by_metadata_type = [x for _, x in unnested_df.groupby('metadata_type')]

for group_df in df_grouped_by_metadata_type:
    print(f"Properties for schema type {group_df['metadata_type'].values[0]}")
    print(group_df["properties"].value_counts())
    print('\n\n')
# Out:
# Properties for schema type Article
# publisher        1
# url              1
# author           1
# headline         1
# @context         1
# datePublished    1
# image            1
# sameAs           1
# @type            1
# dateModified     1
# mainEntity       1
# name             1
# Name: properties, dtype: int64
#
#
#
# Properties for schema type CreativeWork
# publisher           1
# url                 1
# @context            1
# inLanguage          1
# name                1
# mainEntityOfPage    1
# identifier          1
# headline            1
# author              1
# description         1
# datePublished       1
# additionalType      1
# @type               1
# @id                 1
# Name: properties, dtype: int64
#
#
#
# Properties for schema type DataCatalog
# @context              5
# dataset               5
# name                  5
# @type                 5
# description           5
# license               5
# provider              5
# url                   5
# keywords              5
# citation              3
# fileFormat            3
# dateCreated           3
# publication           2
# encodingFormat        2
# datePublished         2
# sourceOrganization    2
# dateModified          2
# identifier            2
# @id                   2
# Name: properties, dtype: int64
#
#
#
# Properties for schema type DataRecord
# @context             3
# @type                3
# mainEntity           3
# isPartOf             2
# identifier           2
# @id                  2
# dateCreated          1
# dct:conformsTo       1
# dateModified         1
# includedInDataset    1
# Name: properties, dtype: int64
#
#
#
# Properties for schema type Dataset
# @context                 9
# name                     9
# @type                    9
# description              9
# license                  8
# version                  6
# url                      6
# creator                  5
# distribution             5
# keywords                 5
# datePublished            4
# identifier               4
# includedInDataCatalog    4
# sourceOrganization       3
# citation                 2
# alternateName            2
# thumbnailUrl             1
# about                    1
# interactionStatistic     1
# dateModified             1
# isAccessibleForFree      1
# @id                      1
# commentCount             1
# sameAs                   1
# discussionUrl            1
# Name: properties, dtype: int64
#
#
#
# Properties for schema type Experiment
# dbxrefs                 1
# original_files          1
# date_released           1
# lab                     1
# date_created            1
# schema_version          1
# alternate_accessions    1
# @type                   1
# description             1
# assay_term_id           1
# date_submitted          1
# biosample_summary       1
# assay_slims             1
# uuid                    1
# biosample_ontology      1
# possible_controls       1
# category_slims          1
# replication_type        1
# internal_tags           1
# assay_term_name         1
# related_series          1
# award                   1
# superseded_by           1
# @id                     1
# contributing_files      1
# type_slims              1
# objective_slims         1
# references              1
# revoked_files           1
# aliases                 1
# @context                1
# replicates              1
# related_files           1
# visualize               1
# target                  1
# hub                     1
# assay_title             1
# internal_status         1
# supersedes              1
# documents               1
# audit                   1
# assembly                1
# status                  1
# files                   1
# submitter_comment       1
# accession               1
# submitted_by            1
# month_released          1
# Name: properties, dtype: int64
#
#
#
# Properties for schema type MolecularEntity
# biochemicalInteraction         1
# image                          1
# url                            1
# molecularFormula               1
# @context                       1
# inChI                          1
# monoisotopicMolecularWeight    1
# @type                          1
# inChIKey                       1
# canonical_smiles               1
# identifier                     1
# molecularWeight                1
# Name: properties, dtype: int64
#
#
#
# Properties for schema type Organization
# url                   5
# @context              5
# name                  5
# @type                 5
# logo                  4
# memberof              3
# parentOrganization    3
# sameAs                2
# Name: properties, dtype: int64
#
#
#
# Properties for schema type Product
# image                 1
# Category              1
# description           1
# @context              1
# name                  1
# @type                 1
# additionalProperty    1
# brand                 1
# Name: properties, dtype: int64
#
#
#
# Properties for schema type WebSite
# url                 4
# @context            4
# @type               4
# potentialAction     3
# name                1
# mainEntityOfPage    1
# alternateName       1
# Name: properties, dtype: int64

# %%
pd.set_option('display.max_rows', None)

print(unnested_df.properties.value_counts())
# Out:
# @context                       33
# @type                          31
# name                           23
# url                            23
# description                    17
# license                        13
# identifier                     10
# keywords                       10
# datePublished                   8
# @id                             7
# version                         6
# creator                         5
# dataset                         5
# sourceOrganization              5
# dateModified                    5
# citation                        5
# provider                        5
# distribution                    5
# includedInDataCatalog           4
# dateCreated                     4
# mainEntity                      4
# sameAs                          4
# logo                            4
# fileFormat                      3
# alternateName                   3
# potentialAction                 3
# parentOrganization              3
# image                           3
# memberof                        3
# mainEntityOfPage                2
# publisher                       2
# @graph                          2
# encodingFormat                  2
# author                          2
# isPartOf                        2
# publication                     2
# headline                        2
# Category                        1
# category_slims                  1
# supersedes                      1
# lab                             1
# contributing_files              1
# isAccessibleForFree             1
# target                          1
# includedInDataset               1
# additionalProperty              1
# canonical_smiles                1
# accession                       1
# related_series                  1
# additionalType                  1
# date_released                   1
# assembly                        1
# audit                           1
# internal_status                 1
# uuid                            1
# dct:conformsTo                  1
# brand                           1
# hub                             1
# schema_version                  1
# visualize                       1
# revoked_files                   1
# thumbnailUrl                    1
# biosample_ontology              1
# molecularFormula                1
# assay_title                     1
# monoisotopicMolecularWeight     1
# award                           1
# references                      1
# date_created                    1
# assay_slims                     1
# inChIKey                        1
# assay_term_name                 1
# assay_term_id                   1
# inChI                           1
# interactionStatistic            1
# type_slims                      1
# possible_controls               1
# dbxrefs                         1
# aliases                         1
# original_files                  1
# month_released                  1
# inLanguage                      1
# discussionUrl                   1
# superseded_by                   1
# alternate_accessions            1
# replicates                      1
# date_submitted                  1
# related_files                   1
# about                           1
# objective_slims                 1
# biosample_summary               1
# submitted_by                    1
# status                          1
# commentCount                    1
# submitter_comment               1
# internal_tags                   1
# documents                       1
# biochemicalInteraction          1
# files                           1
# replication_type                1
# molecularWeight                 1
# Name: properties, dtype: int64

# %% [markdown]
# # Metadata service accuracy
#
# Cannot check. Google pagespeed insights do not show if metadata is valid.

# %%
resolver_service_url = "http://resolver.api.identifiers.org"
pagespeed_apikey = "" # input api key for google pagespeed

for namespace in dataset[16:17]:
    if namespace['namespaceEmbeddedInLui']:
        prefix = namespace['pattern'][1:].split(':')[0]
    else:
        prefix = namespace['prefix']

    response = requests.get(f"{resolver_service_url}/{prefix}:{namespace['sampleId']}").json()
    
    namespace_provider_urls = []
    
    if response["payload"] is not None and response["payload"]["resolvedResources"] is not None:
        for resolvedResource in response["payload"]["resolvedResources"]:
            namespace_provider_urls.append(resolvedResource["compactIdentifierResolvedUrl"])
    
    print(namespace_provider_urls)
    
    for url in namespace_provider_urls:
        pagespeed_url = f"https://www.googleapis.com/pagespeedonline/v5/runPagespeed?url={url}&{pagespeed_apikey}"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-275-b8669ccce400> in <module>
#       3
#       4 for namespace in empty_metadata_resource_urls[16:17]:
# ----> 5     if namespace['namespaceEmbeddedInLui']:
#       6         prefix = namespace['pattern'][1:].split(':')[0]
#       7     else:
#
# TypeError: string indices must be integers

# %%
empty_metadata_resource_urls
# Out:
# ['CHEBI:36927',
#  'uniprot:P0DP23',
#  'ec-code:1.1.1.1',
#  'miriam.collection:MIR:00000008',
#  'taxonomy:9606',
#  'biomodels.db:BIOMD0000000048',
#  'intact:EBI-2307691',
#  'interpro:IPR000100',
#  'kegg.pathway:hsa00620',
#  'icd:C34',
#  'pirsf:PIRSF000100',
#  'pubmed:16333295',
#  'mim:603903',
#  'kegg.compound:C12345',
#  'kegg.reaction:R00100',
#  'doi:10.1038/nbt1156',
#  'pdb:2gc4',
#  'GO:0006915',
#  'kegg.drug:D00123',
#  'sgd:S000003909',
#  'SBO:0000262',
#  'kegg.glycan:G00123',
#  'wb:WBGene00000001',
#  'pfam:PF01234',
#  'insdc:X58356',
#  'fb:FBgn0011293',
#  'pubchem.compound:100101',
#  'arxiv:0807.4956v1',
#  'wormpep:CE28239',
#  'pubchem.substance:100101',
#  'sabiork.reaction:75',
#  'arrayexpress:E-MEXP-1712',
#  'MGI:2442292',
#  'refseq:NP_012345',
#  'tcdb:5.A.1.1.1',
#  'uniparc:UPI000000000A',
#  'mint:MINT-10000',
#  'signaling-gateway:A001094',
#  'dip:DIP-743N',
#  'resid:AA0001',
#  'tair.protein:AASequence:1009107926',
#  'tair.locus:2200950',
#  'tair.gene:Gene:2200934',
#  'peptideatlas:PAp00000009',
#  'lipidmaps:LMPR0102010012',
#  'geo:GDS1234',
#  'hmdb:HMDB00001',
#  'sgd.pathways:PWY3O-214',
#  'MOD:00001',
#  'merops:S01.001',
#  'panther.family:PTHR12345',
#  'prints:PR00001',
#  'ligandexpo:ABC',
#  'mge:2',
#  'pride:1',
#  '3dmet:B00162',
#  'isbn:9781584885658',
#  'kegg.genes:syn:ssr3451',
#  'brenda:1.1.1.1',
#  'FMA:67112',
#  'matrixdb.association:P00747__P07355',
#  'ncbigene:100010',
#  'pubchem.bioassay:1018',
#  'bao:0002989',
#  'pathwaycommons:485991',
#  'hovergen:HBG004341',
#  'wikipathways:WP100',
#  'macie:M0001',
#  'mirbase:MI0000001',
#  'hgnc:2674',
#  'zfin:ZDB-GENE-041118-11',
#  'rhea:12345',
#  'SO:0000704',
#  'chembl.target:CHEMBL3467',
#  'sabiork.kineticrecord:5046',
#  'atc:A10BA02',
#  'pharmgkb.pathways:PA146123006',
#  'pharmgkb.drug:PA448710',
#  'pharmgkb.disease:PA447218',
#  'ttd.target:TTDS00056',
#  'ttd.drug:DAP000773',
#  'lgic:5HT3Arano',
#  'neuromorpho:Rosa2',
#  'chemidplus:57-27-2',
#  'ctd.chemical:D001151',
#  'biosystems:001',
#  'neurondb:265',
#  'ctd.gene:101',
#  'ctd.disease:D053716',
#  'bionumbers:104674',
#  'drugbank:DB00001',
#  't3db:T3D0001',
#  'smpdb:SMP00001',
#  'genedb:LinJ.20.0070',
#  'biomodels.teddy:TEDDY_0000066',
#  'phosphosite.protein:12300',
#  'CL:0000232',
#  'BTO:0000146',
#  'biomodels.kisao:KISAO_0000057',
#  'pdb-ccd:AB0',
#  'PATO:0001998',
#  'glycomedb:G77500AY',
#  'lipidbank:BBA0001',
#  'smart:SM00015',
#  'cdd:cd00400',
#  'prodom:PD10000',
#  'kegg.orthology:K00001',
#  'mmdb:50885',
#  'imex:IM-19210-3',
#  'ro:RO_0002533',
#  'irefweb:617102',
#  'mpid:172',
#  'phosphosite.residue:2842',
#  'neurolex:Birnlex_721',
#  'asap:ABE-0009634',
#  'sabiork.ec:2.7.1.1',
#  'opb:OPB_00573',
#  'obi:OBI_0000070',
#  'jws:curien',
#  'modeldb:45539',
#  'subtiwiki:BSU29180',
#  'doqcs.pathway:131',
#  'doqcs.model:57',
#  'UO:0000080',
#  'pid.pathway:pi3kcipathway',
#  'clinicaltrials:NCT00222573',
#  'chemspider:56586',
#  'omia:1000',
#  'cgd:CAL0003079',
#  'csa:1a05',
#  'ncit:C80519',
#  'antweb:casent0106247',
#  'biocatalogue.service:614',
#  'pmc:PMC3084216',
#  'amoebadb:EDI_244000',
#  'atcc:11303',
#  'microsporidia:ECU03_0820i',
#  'plasmodb:PF11_0344',
#  'cryptodb:cgd7_230',
#  'giardiadb:GL50803_102438',
#  'trichdb:TVAG_386080',
#  'beetlebase:TC010103',
#  'bdgp.insertion:KG09531',
#  'tritrypdb:Tb927.8.620',
#  'toxoplasma:TGME49_053730',
#  'bold.taxonomy:27267',
#  'dbprobe:1000000',
#  'unists:456789',
#  'dbest:BP100000',
#  'ecogene:EG10173',
#  'greengenes:100000',
#  'bdgp.est:EY223054.1',
#  'grin.taxonomy:19333',
#  'gabi:2679240',
#  'hinv.locus:HIX0004394',
#  'hinv.transcript:HIT000195363',
#  'homd.seq:SEQF1003',
#  'hinv.protein:HIP000030660',
#  'homd.taxon:811',
#  'isfinder:ISA1083-2',
#  'ird.segment:CY077097',
#  'jcm:17254',
#  'img.taxon:648028003',
#  'mycobank:349124',
#  'maizegdb.locus:25011',
#  'img.gene:638309541',
#  'pseudomonas:PSEEN0001',
#  'nbrc:00001234',
#  'gramene.protein:78073',
#  'gramene.gene:GR:0080039',
#  'gramene.taxonomy:GR_tax:013681',
#  'gramene.qtl:CQG5',
#  'xenbase:922462',
#  'sgn:0001',
#  'edam:data_1664',
#  'bioportal:1046',
#  'miriam.resource:MIR:00100005',
#  'arachnoserver:AS000060',
#  'pmdb:PM0012345',
#  'biocyc:ECOLI:CYT-D-UBIOX-CPLX',
#  'paleodb:83088',
#  'cazy:GT10',
#  'goa:P12345',
#  'compulyeast:O08709',
#  'eggnog:veNOG12876',
#  'echobase:EB0170',
#  'ensembl.bacteria:MU9_3181',
#  'ensembl.protist:PF3D7_1328700',
#  'ensembl.metazoa:FBtr0084214',
#  'hcvdb:M58335',
#  'ensembl.plant:AT1G73965',
#  'ensembl.fungi:CADAFLAT00006211',
#  'genatlas:HBB',
#  'cath.superfamily:1.10.10.200',
#  'genefarm:4892',
#  'hogenom:HBG284870',
#  'gpcrdb:RL3R1_HUMAN',
#  'hssp:102l',
#  'genetree:ENSGT00550000074763',
#  'myco.tuber:Rv1908c',
#  'myco.marinum:MMAR_2462',
#  'myco.smeg:MSMEG_3769',
#  'orthodb:Q9P0K8',
#  'myco.lepra:ML0224',
#  'orphanet:85163',
#  'peroxibase:5282',
#  'pmap.substratedb:1915',
#  'phylomedb:Phy000CLXM_RAT',
#  'pmap.cutdb:25782',
#  'protclustdb:O80725',
#  'pmp:Q0VCA6',
#  'protonet.cluster:4349895',
#  'protonet.proteincard:16941567',
#  'swiss-model:P23298',
#  'rebase:101',
#  'vectorbase:ISCW007415',
#  'mirbase.mature:MIMAT0000001',
#  'cas:50-00-0',
#  'kegg.metagenome:T30002',
#  'kegg.genome:eco',
#  'jcsd:J55.713G',
#  'pharmgkb.gene:PA131',
#  'scretf:RSC3',
#  'insdc.sra:SRX000007',
#  'PW:0000208',
#  'napp:351',
#  'mirnest:MNEST029358',
#  'noncodev3:377550',
#  'virsirna:virsi1909',
#  'elm:CLV_MEL_PAP_1',
#  'mimodb:1',
#  'bykdb:A0A009E7X8',
#  'sitex:1000',
#  'topfind:Q9UKQ2',
#  'combine.specifications:sbgn.er.level-1.version-1.2',
#  'mipmod:HOSAPI0399',
#  'conoserver:2639',
#  'huge:KIAA0001',
#  'cabri:dsmz_mutz-id:ACC 291',
#  'dictybase.gene:DDB_G0267522',
#  'string:P53350',
#  'bindingdb:e999',
#  'phenolexplorer:75',
#  'stitch:BQJCRHHNABKAKU',
#  'atcvet:QJ51RV02',
#  'snomedct:284196006',
#  'mesh.2012:17186',
#  'knapsack:C00000001',
#  'massbank:PB000166',
#  'cdpd:63250',
#  'gmd:68513255-fc44-4041-bc4b-4fd2fae7541d',
#  'homologene:1000',
#  'abs:A0014',
#  'umbbd.compound:c0001',
#  'dpv:100',
#  'apd:01001',
#  'chemdb:3966782',
#  'aceview.worm:aap-1',
#  'imgt.ligm:M94112',
#  'iuphar.receptor:101',
#  'worfdb:T01B6.1',
#  'soybase:BARC-013845-01256',
#  'nextdb:6b1',
#  'cgsc:74',
#  'arrayexpress.platform:A-GEOD-50',
#  'dragondb.dna:3hB06',
#  'rouge:mKIAA4200',
#  'merops.family:S1',
#  'dragondb.locus:DEF',
#  'dragondb.allele:cho',
#  'dragondb.protein:AMDEFA',
#  'issn:0745-4570',
#  'niaest:J0705A10',
#  'nasc:N1899',
#  'pazar:TF0001053',
#  'mo:ArrayGroup',
#  'rnamods:101',
#  'PO:0009089',
#  'tgd:TTHERM_00648910',
#  'treebase:TB2:S1000',
#  'tigrfam:TIGR00010',
#  'sdbs:4544',
#  'dbg2introns:Cu.me.I1',
#  'iuphar.family:78',
#  'vbase2:humIGHV025',
#  'genecards:ABL1',
#  'spike.map:spike00001',
#  'metlin:1455',
#  'umbbd.enzyme:e0333',
#  'mmrrc:70',
#  'umbbd.reaction:r0001',
#  'umbbd.pathway:ala',
#  'dictybase.est:DDB0016567',
#  'umbbd.rule:bt0001',
#  'mirex:165a',
#  'imgt.hla:A*01:01:01:01',
#  'bdsc:33607',
#  'opm:1h68',
#  'allergome:1948',
#  'pombase:SPCC13B11.01',
#  'hpa:ENSG00000026508',
#  'jaxmice:005012',
#  'ubio.namebank:2555646',
#  'yetfasco:YOR172W_571.0',
#  'tarbase:hsa-let-7a-2-3p',
#  'charprot:CH_001923',
#  'oma.protein:HUMAN16963',
#  'genpept:CAA71118.1',
#  'oma.grp:LCSCCPN',
#  'unigene:4900',
#  'ncbiprotein:CAA71118.1',
#  'bitterdb.rec:1',
#  'bitterdb.cpd:46',
#  'bioproject:PRJDB3',
#  'piroplasma:TA14985',
#  'unite:UDB000691',
#  'ncim:C0026339',
#  'proglyc:AC119',
#  'polbase:19-T4',
#  'nuclearbd:prgr_human',
#  'supfam:SSF57615',
#  'pina:Q13485',
#  'bacmap.biog:1050',
#  'ricegap:LOC_Os02g13300',
#  'tissuelist:TS-0285',
#  'hgnc.symbol:DAPK1',
#  'panther.pathway:P00024',
#  'fungidb:CNBG_0001',
#  'drsc:DRSC05221',
#  'darc:1250',
#  'oridb.sacch:1',
#  'oridb.schizo:1',
#  'scop:47419',
#  'ena.embl:BN000065',
#  'pscdb:051',
#  'panther.node:PTN000000026',
#  'dommino:2GC4',
#  'ccds:CCDS13573.1',
#  'gxa.gene:AT4G01080',
#  'gxa.expt:E-MTAB-2037',
#  'hprd:00001',
#  'lrg:LRG_1',
#  'metabolights:MTBLS1',
#  'orcid:0000-0002-5355-2576',
#  'nbn:urn:nbn:fi:tkk-004781',
#  'phosphopoint.kinase:AURKA',
#  'uniprot.isoform:Q5BJF6-3',
#  'phosphopoint.protein:AURKA',
#  'inchikey:RYYVLZVUVIJVGH-UHFFFAOYSA-N',
#  'inchi:InChI=1S/C2H6O/c1-2-3/h3H,2H2,1H3',
#  'wikipedia.en:SM_UB-81',
#  'cldb:cl3603',
#  'kegg.environ:ev:E00032',
#  'aphidbase.transcript:ACYPI000159',
#  'efo:0004859',
#  'hgmd:CALM1',
#  'affy.probeset:243002_at',
#  'treefam:TF101014',
#  'caps:434',
#  'cubedb:AKR',
#  'ideal:IID00001',
#  'pocketome:1433C_TOBAC_1_252',
#  'stap:1a24',
#  'gold.meta:Gm00047',
#  'bugbase.expt:288',
#  'bugbase.protocol:67',
#  'VariO:0294',
#  'tol:98034',
#  'vipr:BeAn 70563',
#  'fbol:2224',
#  'rfam:RF00230',
#  'epd:TA_H3',
#  'aftol.taxonomy:959',
#  'aspgd.locus:ASPL0000349247',
#  'aspgd.protein:ASPL0000349247',
#  'autdb:ADA',
#  'bacmap.map:AP011135',
#  'ndc:0002-1975-61',
#  'bgee.gene:FBgn0000015',
#  'bgee.stage:HsapDO:0000004',
#  'bgee.family:ENSFM00500000270089',
#  'bgee.organ:EHDAA:2185',
#  'biocarta.pathway:h_aktPathway',
#  'gmd.gcms:53d583d8-40c6-40e1-9296-23f821cd77a5',
#  'gmd.profile:10b38aaf-b977-4950-85b8-f4775f66658d',
#  'gmd.ref:8cf84adb-b4db-4807-ac98-0004247c35df',
#  'gmd.analyte:4f0fa9b6-514f-4ff4-98cc-0009bc08eb80',
#  'intact.molecule:EBI-366083',
#  'dailymed:973a9333-fec7-46dd-8eb5-25738f06ee54',
#  'depod:PTPN1',
#  'phytozome.locus:Glyma0021s00410',
#  'cst:Akt_PKB',
#  'subtilist:BG11523',
#  'sider.effect:C0017565',
#  'sider.drug:2244',
#  'broad:S7000002168151102',
#  'coriell:GM17027',
#  'wikigenes:3771877',
#  'corum:100',
#  'ecoliwiki:aaeA',
#  'MA:0002502',
#  'jstor:3075966',
#  'genprop:GenProp0699',
#  'unimod:1200',
#  'vbrc:35742',
#  'viralzone:992',
#  'door:1398574',
#  'degradome:Ax1',
#  'datf:AT1G01030.1',
#  'dbd:0045310',
#  'molbase:128796-39-4',
#  'yrcpdr:2673500',
#  'funcbase.fly:10194',
#  'funcbase.human:119514',
#  'yid:SNR17A',
#  'funcbase.mouse:1351341',
#  'cbioportal:laml_tcga_pub',
#  'funcbase.yeast:2701',
#  'ydpm:YAL001C',
#  'wb.rnai:WBRNAi00086878',
#  'pass2:46977',
#  'iceberg.element:100',
#  'iceberg.family:1',
#  'vfdb.gene:VFG2154',
#  'vfdb.genus:Chlamydia',
#  'mesh.2013:17165',
#  'kegg.module:M00002',
#  'kegg.disease:H00076',
#  'ligandbox:D00001',
#  'glycoepitope:EP0311',
#  'medlineplus:002804',
#  'jcggdb:JCGG-STR008690',
#  'noncodev4.rna:NONHSAT000001',
#  'vfb:00000001',
#  'noncodev4.gene:NONHSAG00001',
#  'oryzabase.gene:117',
#  'oryzabase.mutant:21393',
#  'otl:AADB12',
#  'oryzabase.strain:1',
#  'oryzabase.stage:34',
#  'paxdb.protein:977869',
#  'pdb.ligand:TRQ',
#  'merops.inhibitor:I31.952',
#  'paxdb.organism:9606',
#  'glida.gpcr:ACM1_HUMAN',
#  'adw:Lycalopex_vetulus',
#  'grsdb:10142',
#  'glida.ligand:L000001',
#  'fsnp:rs17852708',
#  'px:PXD000500',
#  'hdr:63',
#  'biomodels.vocabulary:rateRule',
#  'norine:NOR00681',
#  'ordb:8497',
#  'p3db.site:65',
#  'odor:74',
#  'cattleqtldb:4685',
#  'p3db.protein:70',
#  'topdb:AP00378',
#  'chickenqtldb:14362',
#  'mgnify.samp:SRS086444',
#  'sheepqtldb:19803',
#  'ega.study:EGAS00000000001',
#  'pigqtldb:14',
#  'ega.dataset:EGAD00000000001',
#  'idot:identifierPattern',
#  'antibodyregistry:493771',
#  'mamo:MAMO_0000026',
#  'pride.project:PXD000440',
#  'yeastintron:SNR17A',
#  'hgnc.family:PADI',
#  'ardb:CAE46076',
#  'proteomicsdb.protein:53504',
#  'hpm.protein:1968',
#  'proteomicsdb.peptide:53504',
#  'drugbankv4.target:BE0000048',
#  'foodb.compound:FDB002100',
#  'hpm.peptide:9606117',
#  'zinc:ZINC1084',
#  'unii:3G6A5W338E',
#  'orphanet.ordo:Orphanet_C023',
#  'psipar:PAR:0116',
#  'mgnify.proj:ERP004492',
#  'clinvar.record:RCV000033555.3',
#  'euclinicaltrials:2008-005144-16',
#  'google.patent:US4145692',
#  'uspto:4145692',
#  'exac.variant:22-46615880-T-C',
#  'cpc:A01M1/026',
#  'gwascentral.study:HGVST1828',
#  'gwascentral.marker:HGVM15354',
#  'bigg.metabolite:12dgr161',
#  'lincs.cell:LCL-2085',
#  'lincs.protein:200282',
#  'lincs.smallmolecule:LSM-6306',
#  'exac.transcript:ENST00000407236',
#  'exac.gene:ENSG00000169174',
#  'wikidata:Q2207226',
#  'unipathway.compound:UPC04349',
#  'bigg.model:iECABU_c1320',
#  'seed:Biotin_biosynthesis',
#  'seed.compound:cpd15380',
#  'bigg.compartment:c',
#  'bigg.reaction:13GS',
#  'umls:C0021390',
#  'emdb:EMD-1001',
#  'mesh:C000100',
#  'mirtarbase:MIRT000002',
#  'meddra:10015919',
#  'dashr:hsa-mir-200a',
#  'splash:splash10-0zq2000000-77302b0326a418630a84',
#  'dashr.expression:hsa-mir-200a',
#  'unipathway.reaction:UCR00226',
#  'sasbdb:SASDAX8',
#  'HP:0000118',
#  'hgnc.genefamily:141',
#  'mdm:4776',
#  'apid.interactions:P01116',
#  'probonto:PROB_c0000005',
#  'storedb:STOREDB:STUDY1040',
#  'kegg:hsa00190',
#  'MP:0005452',
#  'planttfdb:Ath_AT1G01030.1',
#  'multicellds.collection:MCDS_C_0000000001',
#  'multicellds.cell_line:MCDS_L_0000000001',
#  'multicellds.snapshot:MCDS_S_0000000001',
#  'ecyano.entity:23',
#  'lincs.data:LDS-1110',
#  'ecyano.model:26',
#  'ecyano.rule:56',
#  'agricola:50018',
#  'MS:1000001',
#  'ENVO:09200010',
#  'grid:grid.225360.0',
#  'medgen:760050',
#  'clinvar:12345',
#  'clinvar.submission:SCV000151292',
#  'MIR:00100037',
#  'pgx:icdom:8500_3',
#  'iao:0000030',
#  'dbgap:phs000768.v2.p1',
#  'omit:0005506',
#  'insdc.cds:AAA35559',
#  'gdc:ae8c77fe-e6c8-44d5-8265-4a38c637bbef',
#  'metacyc.reaction:RXN-14904',
#  'glytoucan:G00054MO',
#  'metacyc.compound:CPD-10330',
#  'd1id:00030692-0FE1-4A1B-955E-A2E55D659267',
#  'mmp.ref:MMP3312982.2',
#  'cath:1.10.8.10',
#  'mmp.cat:MMP743597.11',
#  'mmp.db:MMP02954345.1',
#  'aop:98',
#  'biotools:uniprotkb',
#  'ngl:GLDS-141',
#  'arraymap:icdom:8500_3',
#  'begdb:4214',
#  'erv:THE1B',
#  'napdi:28',
#  'crisprdb:551115',
#  'mzspec:PXD002255::ES_XP_Ubi_97H_HCD_349:scan:9617:LAEIYVNSSFYK/2',
#  'sugarbind:lectins/172',
#  'sisu:17:41223048',
#  'licebase:EMLSAT00000003403',
#  'gnpis:AY109603',
#  'rnacentral:URS0000759CF4',
#  'microscope:5601141',
#  'swissregulon:AHR',
#  'validatordb:ByStructure/2h6o',
#  'biominder:aef4c195-9cf9-46db-a12a-7cfd1ff3eec3',
#  'vmhmetabolite:h2o',
#  'NMR:1000003',
#  'vmhreaction:HEX1',
#  'ascl:1801.012',
#  'facebase:FB00000917',
#  'eu89h:jrc-eurl-ecvam-chemagora',
#  'gudmap:Q-2958',
#  'minid:b97957',
#  'mex:36',
#  'mw.study:ST000900',
#  'gpmdb:GPM32310002988',
#  'mw.project:PR000001',
#  'massive:MSV000082131',
#  'fplx:RAS',
#  'aop.events:3',
#  'aop.stressor:9',
#  'aop.relationships:5',
#  'swh:1:rev:309cf2674ee7a0749978cf8265ab91a60aea0f7d',
#  'dev.ga4ghdos:23fa7b4b-9d68-429b-aece-658b11124bb3#2017-03-24T18:43:16.886826-05:00',
#  'comptox:DTXSID2021028',
#  'complexportal:CPX-2158',
#  'ligandbook:785',
#  'rbk:Q-2958',
#  'idoo:DataCollection',
#  'oci:1-18',
#  'FOODON:03307879',
#  'ricenetdb.gene:LOC_Os01g49190.1',
#  'ricenetdb.protein:LOC_Os01g49190',
#  'gtex:BRIP1',
#  'ricenetdb.compound:OSC1416',
#  'ricenetdb.reaction:OSR0818',
#  'ricenetdb.mirna:osa-miR446',
#  'asin:0471491039',
#  'oclc:634515043',
#  'ga4ghdos:dg.4503/01b048d0-e128-4cb0-94e9-b2d2cab7563d',
#  'oid:2.16.840',
#  'flowrepository:FR-FCM-ZYGW',
#  'addgene:50943',
#  'gdsc:1242',
#  'bacdive:131392',
#  'ido:0000504',
#  'isni:000000012281955X',
#  'viaf:75121530',
#  'sabiork.compound:75',
#  'spdx:CC-BY-1.0',
#  'peptideatlas.dataset:PASS01237',
#  'did:sov:WRfXPg8dantKVubE3HX8pw',
#  'oryzabase.reference:42840',
#  'biostudies:S-EPMC6266652',
#  'seed.reaction:rxn00001',
#  'occ:br/1',
#  'cadsr:3771992',
#  'erm:ERM00000044',
#  'classyfire:C0004828',
#  'gcst:GCST000035',
#  'mmp.fun:MMP3888430',
#  'ecyano.experiment:18',
#  'dlxb:6VDC956',
#  'dlxc:M77F7JM',
#  'cameo:2019-08-03_00000089_1',
#  'nemo:smp-m3w9hbe',
#  'insdc.gca:GCA_000155495.1',
#  'spp:10.1621/vwN2g2HaX3']

# %%
namespace_provider_urls = []

for ci in empty_metadata_resource_urls:
    response = requests.get(f"{resolver_service_url}/{ci}").json()

    if response["payload"] is not None and response["payload"]["resolvedResources"] is not None:
        for resolvedResource in response["payload"]["resolvedResources"]:
            namespace_provider_urls.append(resolvedResource["compactIdentifierResolvedUrl"])

# %%
import urllib.parse

print("\n".join([urllib.parse.quote(x, safe="") for x in namespace_provider_urls]))
# Out:
# https%3A%2F%2Fwww.ebi.ac.uk%2Fchebi%2FsearchId.do%3FchebiId%3DCHEBI%3A36927
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fchebi%2Fterms%3Fobo_id%3DCHEBI%3A36927
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FCHEBI%2FCHEBI%3A36927
# https%3A%2F%2Fpurl.uniprot.org%2Funiprot%2FP0DP23
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fprotein%2FP0DP23
# https%3A%2F%2Fwww.ebi.ac.uk%2Fintenz%2Fquery%3Fcmd%3DSearchEC%26ec%3D1.1.1.1
# https%3A%2F%2Fwww.genome.jp%2Fdbget-bin%2Fwww_bget%3Fec%3A1.1.1.1
# http%3A%2F%2Fwww.enzyme-database.org%2Fquery.php%3Fec%3D1.1.1.1
# https%3A%2F%2Fwww.ebi.ac.uk%2Fenzymeportal%2Fsearch%2Fec%2F1.1.1.1
# https%3A%2F%2Fenzyme.expasy.org%2FEC%2F1.1.1.1
# https%3A%2F%2Fwww.ebi.ac.uk%2Fmiriam%2Fmain%2FMIR%3A00000008
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2FTaxonomy%2FBrowser%2Fwwwtax.cgi%3Fmode%3DInfo%26id%3D9606
# https%3A%2F%2Fpurl.uniprot.org%2Ftaxonomy%2F9606
# https%3A%2F%2Fwww.ebi.ac.uk%2Fena%2Fdata%2Fview%2FTaxon%3A9606
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNCBITAXON%2F9606
# http%3A%2F%2Ftaxonomy.bio2rdf.org%2Fdescribe%2F%3Furl%3Dhttp%3A%2F%2Fbio2rdf.org%2Ftaxonomy%3A9606
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fncbitaxon%2Fterms%3Fshort_form%3DNCBITaxon_9606
# https%3A%2F%2Fwww.ebi.ac.uk%2Fbiomodels%2FBIOMD0000000048
# http%3A%2F%2Fbiomodels.caltech.edu%2FBIOMD0000000048
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fbiomodels%2FBIOMD0000000048
# https%3A%2F%2Fwww.ebi.ac.uk%2Fintact%2Finteraction%2FEBI-2307691
# https%3A%2F%2Fwww.ebi.ac.uk%2Finterpro%2Fentry%2FIPR000100
# http%3A%2F%2Finterpro.bio2rdf.org%2Fdescribe%2F%3Furl%3Dhttp%3A%2F%2Fbio2rdf.org%2Finterpro%3AIPR000100
# https%3A%2F%2Fwww.kegg.jp%2Fentry%2Fhsa00620
# http%3A%2F%2Fapps.who.int%2Fclassifications%2Ficd10%2Fbrowse%2F2010%2Fen%23%2FC34
# https%3A%2F%2Fpir.georgetown.edu%2Fcgi-bin%2FipcSF%3Fid%3DPIRSF000100
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fpubmed%2F16333295
# http%3A%2F%2Fwww.hubmed.org%2Fdisplay.cgi%3Fuids%3D16333295
# http%3A%2F%2Feuropepmc.org%2Fabstract%2FMED%2F16333295
# http%3A%2F%2Flinkedlifedata.com%2Fresource%2Fpubmed%2Fid%2F16333295
# https%3A%2F%2Fomim.org%2Fentry%2F603903
# http%3A%2F%2Fmirror.omim.org%2Fentry%2F603903
# https%3A%2F%2Fwww.kegg.jp%2Fentry%2FC12345
# https%3A%2F%2Fwww.kegg.jp%2Fentry%2FR00100
# https%3A%2F%2Fdoi.org%2F10.1038%2Fnbt1156
# http%3A%2F%2Fproteopedia.org%2Fwiki%2Findex.php%2F2gc4
# https%3A%2F%2Fwww.rcsb.org%2Fstructure%2F2gc4
# https%3A%2F%2Fwww.ebi.ac.uk%2Fpdbsum%2F2gc4
# https%3A%2F%2Fpdbj.org%2Fmine%2Fsummary%2F2gc4
# http%3A%2F%2Fwww.ebi.ac.uk%2Fpdbe%2Fentry%2Fpdb%2F2gc4
# https%3A%2F%2Fwww.ebi.ac.uk%2FQuickGO%2FGTerm%3Fid%3DGO%3A0006915
# http%3A%2F%2Famigo.geneontology.org%2Famigo%2Fterm%2FGO%3A0006915
# http%3A%2F%2Fwww.informatics.jax.org%2Fsearches%2FGO.cgi%3Fid%3DGO%3A0006915
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FGO%2FGO%3A0006915
# http%3A%2F%2Fwww.pantherdb.org%2Fpanther%2Fcategory.do%3FcategoryAcc%3DGO%3A0006915
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fgo%2Fterms%3Fobo_id%3DGO%3A0006915
# https%3A%2F%2Fwww.kegg.jp%2Fentry%2FD00123
# https%3A%2F%2Fwww.yeastgenome.org%2Flocus%2FS000003909
# http%3A%2F%2Fsgd.bio2rdf.org%2Fdescribe%2F%3Furl%3Dhttp%3A%2F%2Fbio2rdf.org%2Fsgd%3AS000003909
# https%3A%2F%2Fbioentity.link%2F%23%2Flexicon%2Fpublic%2FS000003909
# https%3A%2F%2Fwww.alliancegenome.org%2Fgene%2FSGD%3AS000003909
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fsbo%2Fterms%3Fobo_id%3DSBO%3A0000262
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSBO%2FSBO%3A0000262
# https%3A%2F%2Fwww.ebi.ac.uk%2Fsbo%2Fmain%2FSBO%3A0000262
# https%3A%2F%2Fwww.kegg.jp%2Fentry%2FG00123
# https%3A%2F%2Fwww.wormbase.org%2Fget%3Fname%3DWBGene00000001
# https%3A%2F%2Fbioentity.link%2F%23%2Flexicon%2Fpublic%2FWBGene00000001
# https%3A%2F%2Fwww.alliancegenome.org%2Fgene%2FWB%3AWBGene00000001
# https%3A%2F%2Fpfam.xfam.org%2Ffamily%2FPF01234
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fnuccore%2FX58356
# http%3A%2F%2Fgetentry.ddbj.nig.ac.jp%2Fgetentry%3Fdatabase%3Dddbj%26accession_number%3DX58356
# https%3A%2F%2Fwww.ebi.ac.uk%2Fena%2Fdata%2Fview%2FX58356
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fnuccore%2FX58356
# http%3A%2F%2Fflybase.org%2Freports%2FFBgn0011293.html
# https%3A%2F%2Fbioentity.link%2F%23%2Flexicon%2Fpublic%2FFBgn0011293
# https%3A%2F%2Fwww.alliancegenome.org%2Fgene%2FFB%3AFBgn0011293
# https%3A%2F%2Fpubchem.ncbi.nlm.nih.gov%2Fsummary%2Fsummary.cgi%3Fcid%3D100101
# https%3A%2F%2Farxiv.org%2Fabs%2F0807.4956v1
# https%3A%2F%2Fwww.wormbase.org%2Fdb%2Fseq%2Fprotein%3Fname%3DWP%3ACE28239
# https%3A%2F%2Fpubchem.ncbi.nlm.nih.gov%2Fsummary%2Fsummary.cgi%3Fsid%3D100101
# http%3A%2F%2Fsabiork.h-its.org%2FnewSearch%3Fq%3Dsabioreactionid%3A75
# https%3A%2F%2Fwww.ebi.ac.uk%2Farrayexpress%2Fexperiments%2FE-MEXP-1712
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Farrayexpress-repository%2FE-MEXP-1712
# http%3A%2F%2Fwww.informatics.jax.org%2Faccession%2FMGI%3A2442292
# https%3A%2F%2Fbioentity.link%2F%23%2Flexicon%2Fpublic%2FMGI%3A2442292
# https%3A%2F%2Fwww.alliancegenome.org%2Fgene%2FMGI%3A2442292
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fprotein%2FNP_012345
# http%3A%2F%2Fwww.tcdb.org%2Fsearch%2Fresult.php%3Ftc%3D5.A.1.1.1
# https%3A%2F%2Fwww.ebi.ac.uk%2Fcgi-bin%2Fdbfetch%3Fdb%3Duniparc%26id%3DUPI000000000A
# http%3A%2F%2Fwww.uniprot.org%2Funiparc%2FUPI000000000A
# http%3A%2F%2Fmint.bio.uniroma2.it%2Fmint%2Fsearch%2FinFrameInteraction.do%3FinteractionAc%3DMINT-10000
# https%3A%2F%2Fwww.ebi.ac.uk%2Fintact%2Fquery%2Finteraction_id%3AMINT-10000
# http%3A%2F%2Fwww.signaling-gateway.org%2Fmolecule%2Fquery%3Fafcsid%3DA001094
# https%3A%2F%2Fdip.doe-mbi.ucla.edu%2Fdip%2FDIPview.cgi%3FID%3DDIP-743N
# http%3A%2F%2Fpir0.georgetown.edu%2Fcgi-bin%2Fresid%3Fid%3DAA0001
# http%3A%2F%2Farabidopsis.org%2Fservlets%2FTairObject%3Faccession%3DAASequence%3A1009107926
# http%3A%2F%2Fwww.arabidopsis.org%2Fservlets%2FTairObject%3Faccession%3DLocus%3A2200950
# http%3A%2F%2Farabidopsis.org%2Fservlets%2FTairObject%3Faccession%3DGene%3A2200934
# https%3A%2F%2Fdb.systemsbiology.net%2Fsbeams%2Fcgi%2FPeptideAtlas%2FSummarize_Peptide%3Fquery%3DQUERY%26searchForThis%3DPAp00000009
# http%3A%2F%2Fwww.lipidmaps.org%2Fdata%2FLMSDRecord.php%3FLMID%3DLMPR0102010012
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fgeo%2Fquery%2Facc.cgi%3Facc%3DGDS1234
# http%3A%2F%2Fwww.hmdb.ca%2Fmetabolites%2FHMDB00001
# http%3A%2F%2Fpathway.yeastgenome.org%2FYEAST%2Fnew-image%3Ftype%3DPATHWAY%26object%3DPWY3O-214
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fmod%2Fterms%3Fobo_id%3DMOD%3A00001
# http%3A%2F%2Fbioportal.bioontology.org%2Fontologies%2F1041%3Fp%3Dterms%26conceptid%3DMOD%3A00001
# http%3A%2F%2Fmerops.sanger.ac.uk%2Fcgi-bin%2Fpepsum%3Fmid%3DS01.001
# http%3A%2F%2Fwww.pantherdb.org%2Fpanther%2Ffamily.do%3FclsAccession%3DPTHR12345
# http%3A%2F%2Fwww.bioinf.manchester.ac.uk%2Fcgi-bin%2Fdbbrowser%2Fsprint%2Fsearchprintss.cgi%3Fprints_accn%3DPR00001%26display_opts%3DPrints%26category%3DNone%26queryform%3Dfalse%26regexpr%3Doff
# http%3A%2F%2Fligand-depot.rutgers.edu%2Fpyapps%2FldHandler.py%3Fformid%3Dcc-index-search%26target%3DABC%26operation%3Dccid
# http%3A%2F%2Fligand-expo.rcsb.org%2Fpyapps%2FldHandler.py%3Fformid%3Dcc-index-search%26target%3DABC%26operation%3Dccid
# http%3A%2F%2Faclame.ulb.ac.be%2Fperl%2FAclame%2FGenomes%2Fmge_view.cgi%3Fview%3Dinfo%26id%3Dmge%3A2
# https%3A%2F%2Fwww.ebi.ac.uk%2Fpride%2Farchive%2Fassays%2F1
# http%3A%2F%2Fwww.3dmet.dna.affrc.go.jp%2Fcgi%2Fshow_data.php%3Facc%3DB00162
# http%3A%2F%2Fisbndb.com%2Fsearch-all.html%3Fkw%3D9781584885658
# http%3A%2F%2Fwww.worldcat.org%2Fisbn%2F9781584885658
# http%3A%2F%2Fwww.kegg.jp%2Fentry%2Fsyn%3Assr3451
# https%3A%2F%2Fwww.brenda-enzymes.org%2Fphp%2Fresult_flat.php4%3Fecno%3D1.1.1.1
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Ffma%2Fterms%3Fobo_id%3DFMA%3A67112
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FFMA_subset%2FFMA%3A67112
# http%3A%2F%2Fmatrixdb.univ-lyon1.fr%2F%2Fcgi-bin%2Fcurrent%2FnewPort%3Ftype%3Dassociation%26value%3DP00747__P07355%26class%3DAssociation
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fgene%2F100010
# http%3A%2F%2Fncbigene.bio2rdf.org%2Fdescribe%2F%3Furl%3Dhttp%3A%2F%2Fbio2rdf.org%2Fncbigene%3A100010
# https%3A%2F%2Fpubchem.ncbi.nlm.nih.gov%2Fassay%2Fassay.cgi%3Faid%3D1018
# http%3A%2F%2Fbioportal.bioontology.org%2Fontologies%2FBAO%2Fbao%3ABAO_0002989
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fbao%2Fterms%3Fobo_id%3DBAO%3A0002989
# http%3A%2F%2Fwww.pathwaycommons.org%2Fpc%2Frecord2.do%3Fid%3D485991
# http%3A%2F%2Fpbil.univ-lyon1.fr%2Fcgi-bin%2Fview-tree.pl%3Fquery%3DHBG004341%26db%3DHOVERGEN
# http%3A%2F%2Fwww.wikipathways.org%2Finstance%2FWP100
# https%3A%2F%2Fwww.ebi.ac.uk%2Fthornton-srv%2Fdatabases%2Fcgi-bin%2FMACiE%2Fentry%2FgetPage.pl%3Fid%3DM0001
# http%3A%2F%2Fwww.mirbase.org%2Fcgi-bin%2Fmirna_entry.pl%3Facc%3DMI0000001
# https%3A%2F%2Fwww.genenames.org%2Fdata%2Fgene-symbol-report%2F%23%21%2Fhgnc_id%2F2674
# http%3A%2F%2Fzfin.org%2FZDB-GENE-041118-11
# https%3A%2F%2Fbioentity.link%2F%23%2Flexicon%2Fpublic%2FZDB-GENE-041118-11
# https%3A%2F%2Ftest.alliancegenome.org%2Fgene%2FZFIN%3AZDB-GENE-041118-11
# https%3A%2F%2Fwww.rhea-db.org%2Freaction%3Fid%3D12345
# http%3A%2F%2Fwww.sequenceontology.org%2Fmiso%2Fcurrent_release%2Fterm%2FSO%3A0000704
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSO%2FSO%3A0000704
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fso%2Fterms%3Fobo_id%3DSO%3A0000704
# https%3A%2F%2Fwww.ebi.ac.uk%2Fchembl%2Ftarget%2Finspect%2FCHEMBL3467
# http%3A%2F%2Flinkedchemistry.info%2Fchembl%2Fchemblid%2FCHEMBL3467
# https%3A%2F%2Frdf.ebi.ac.uk%2Fresource%2Fchembl%2Ftarget%2FCHEMBL3467
# http%3A%2F%2Fsabiork.h-its.org%2FkineticLawEntry.jsp%3FviewData%3Dtrue%26kinlawid%3D5046
# http%3A%2F%2Fwww.whocc.no%2Fatc_ddd_index%2F%3Fcode%3DA10BA02
# http%3A%2F%2Fwww.pharmgkb.org%2Fpathway%2FPA146123006
# http%3A%2F%2Fwww.pharmgkb.org%2Fdrug%2FPA448710
# http%3A%2F%2Fwww.pharmgkb.org%2Fdisease%2FPA447218
# http%3A%2F%2Fbidd.nus.edu.sg%2Fgroup%2FTTD%2FZFTTDDetail.asp%3FID%3DTTDS00056
# http%3A%2F%2Fbidd.nus.edu.sg%2Fgroup%2FTTD%2FZFTTDDRUG.asp%3FID%3DDAP000773
# https%3A%2F%2Fwww.ebi.ac.uk%2Fcompneur-srv%2FLGICdb%2FHTML%2F5HT3Arano.php
# http%3A%2F%2Fneuromorpho.org%2Fneuron_info.jsp%3Fneuron_name%3DRosa2
# https%3A%2F%2Fchem.nlm.nih.gov%2Fchemidplus%2Frn%2F57-27-2
# http%3A%2F%2Fctdbase.org%2Fdetail.go%3Ftype%3Dchem%26acc%3DD001151
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fbiosystems%2F001
# http%3A%2F%2Fsenselab.med.yale.edu%2FNeuronDB%2FNeuronProp.aspx%3Fid%3D265
# http%3A%2F%2Fctdbase.org%2Fdetail.go%3Ftype%3Dgene%26acc%3D101
# http%3A%2F%2Fctdbase.org%2Fdetail.go%3Ftype%3Ddisease%26db%3DMESH%26acc%3DD053716
# https%3A%2F%2Fbionumbers.hms.harvard.edu%2Fbionumber.aspx%3Fid%3D104674
# http%3A%2F%2Fwww.drugbank.ca%2Fdrugs%2FDB00001
# http%3A%2F%2Fwww.t3db.org%2Ftoxins%2FT3D0001
# http%3A%2F%2Fsmpdb.ca%2Fview%2FSMP00001
# https%3A%2F%2Fwww.genedb.org%2Fgene%2FLinJ.20.0070
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FTEDDY%2FTEDDY_0000066
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fteddy%2Fterms%3Fshort_form%3DTEDDY_0000066
# http%3A%2F%2Fwww.phosphosite.org%2FproteinAction.do%3Fid%3D12300
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fcl%2Fterms%3Fobo_id%3DCL%3A0000232
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FCL%2FCL%3A0000232
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fbto%2Fterms%3Fobo_id%3DBTO%3A0000146
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FBTO%2FBTO%3A0000146
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FKISAO%2Fkisao%3AKISAO_0000057
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fkisao%2Fterms%3Fshort_form%3DKISAO_0000057
# https%3A%2F%2Fwww.ebi.ac.uk%2Fpdbe-srv%2Fpdbechem%2FchemicalCompound%2Fshow%2FAB0
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fpato%2Fterms%3Fobo_id%3DPATO%3A0001998
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FPATO%2FPATO%3A0001998
# https%3A%2F%2Fglytoucan.org%2FStructures%2FGlycans%2FG77500AY
# http%3A%2F%2Flipidbank.jp%2Fcgi-bin%2Fdetail.cgi%3Fid%3DBBA0001
# http%3A%2F%2Fsmart.embl-heidelberg.de%2Fsmart%2Fdo_annotation.pl%3FDOMAIN%3DSM00015
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2FStructure%2Fcdd%2Fcddsrv.cgi%3Fuid%3Dcd00400
# http%3A%2F%2Fprodom.prabi.fr%2Fprodom%2Fcurrent%2Fcgi-bin%2Frequest.pl%3Fquestion%3DDBEN%26query%3DPD10000
# http%3A%2F%2Fwww.kegg.jp%2Fentry%2FK00001
# http%3A%2F%2Fwww.ncbi.nlm.nih.gov%2FStructure%2Fmmdb%2Fmmdbsrv.cgi%3Fuid%3D50885
# https%3A%2F%2Fwww.ebi.ac.uk%2Fintact%2Fimex%2Fmain.xhtml%3Fquery%3DIM-19210-3
# https%3A%2F%2Fimexcentral.org%2Ficentral%2Fimex%2Frec%2FIM-19210-3
# http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FRO_0002533
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fro%2Fterms%3Fshort_form%3DRO_0002533
# http%3A%2F%2Fwodaklab.org%2FiRefWeb%2Finteraction%2Fshow%2F617102
# http%3A%2F%2Fwww.jcvi.org%2Fmpidb%2Fexperiment.php%3Finteraction_id%3D172
# https%3A%2F%2Fwww.ebi.ac.uk%2Fintact%2Fquery%2Finteraction_id%3AMPIDB-INT-172
# http%3A%2F%2Fwww.phosphosite.org%2FsiteAction.do%3Fid%3D2842
# http%3A%2F%2Fwww.neurolex.org%2Fwiki%2FBirnlex_721
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FBIRNLEX%2FBirnlex_721
# http%3A%2F%2Fasap.ahabs.wisc.edu%2Fasap%2Ffeature_info.php%3FLocationID%3DWIS%26FeatureID%3DABE-0009634
# http%3A%2F%2Fsabiork.h-its.org%2FnewSearch%3Fq%3Decnumber%3A2.7.1.1
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FOPB%3Fconceptid%3Dhttp%253A%252F%252Fbhi.washington.edu%252FOPB%2523OPB_00573
# http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FOBI_0000070
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FOBI%2FOBI_0000070
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fobi%2Fterms%3Fobo_id%3DOBI_0000070
# http%3A%2F%2Fjjj.biochem.sun.ac.za%2Fmodels%2Fcurien%2F
# http%3A%2F%2Fjjj.bio.vu.nl%2Fmodels%2Fcurien%2F
# http%3A%2F%2Fjjj.mib.ac.uk%2Fmodels%2Fcurien
# http%3A%2F%2Fsenselab.med.yale.edu%2FModelDB%2FShowModel.asp%3Fmodel%3D45539
# http%3A%2F%2Fwww.subtiwiki.uni-goettingen.de%2Fwiki%2Findex.php%2FBSU29180
# http%3A%2F%2Fdoqcs.ncbs.res.in%2Ftemplate.php%3F%26y%3Dpathwaydetails%26pn%3D131
# http%3A%2F%2Fdoqcs.ncbs.res.in%2Ftemplate.php%3F%26y%3Daccessiondetails%26an%3D57
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fuo%2Fterms%3Fobo_id%3DUO%3A0000080
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUO%2FUO%3A0000080
# http%3A%2F%2Fpid.nci.nih.gov%2Fsearch%2Fpathway_landing.shtml%3Fwhat%3Dgraphic%26jpg%3Don%26pathway_id%3Dpi3kcipathway
# https%3A%2F%2Fclinicaltrials.gov%2Fct2%2Fshow%2FNCT00222573
# http%3A%2F%2Fwww.chemspider.com%2FChemical-Structure.56586.html
# http%3A%2F%2Fomia.angis.org.au%2F1000%2F
# http%3A%2F%2Fwww.candidagenome.org%2Fcgi-bin%2Flocus.pl%3Fdbid%3DCAL0003079
# https%3A%2F%2Fwww.ebi.ac.uk%2Fthornton-srv%2Fdatabases%2FCSA%2FSearchResults.php%3FPDBID%3D1a05
# http%3A%2F%2Fncit.nci.nih.gov%2Fncitbrowser%2FConceptReport.jsp%3Fdictionary%3DNCI%2520Thesaurus%26code%3DC80519
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fncit%2Fterms%3Fshort_form%3DNCIT_C80519
# http%3A%2F%2Fwww.antweb.org%2Fspecimen.do%3Fname%3Dcasent0106247
# https%3A%2F%2Fwww.biocatalogue.org%2Fservices%2F614
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fpmc%2Farticles%2FPMC3084216%2F%3Ftool%3Dpubmed
# http%3A%2F%2Feuropepmc.org%2Farticles%2FPMC3084216
# https%3A%2F%2Famoebadb.org%2Famoeba%2Fapp%2Frecord%2Fgene%2FEDI_244000
# http%3A%2F%2Fwww.lgcstandards-atcc.org%2FProducts%2FAll%2F11303.aspx
# http%3A%2F%2Fmicrosporidiadb.org%2Fmicro%2FshowRecord.do%3Fname%3DGeneRecordClasses.GeneRecordClass%26source_id%3DECU03_0820i
# http%3A%2F%2Fplasmodb.org%2Fplasmo%2FshowRecord.do%3Fname%3DGeneRecordClasses.GeneRecordClass%26source_id%3DPF11_0344
# https%3A%2F%2Fcryptodb.org%2Fcryptodb%2Fapp%2Frecord%2Fgene%2Fcgd7_230
# https%3A%2F%2Fgiardiadb.org%2Fgiardiadb%2Fapp%2Frecord%2Fgene%2FGL50803_102438
# http%3A%2F%2Ftrichdb.org%2Ftrichdb%2FshowRecord.do%3Fname%3DGeneRecordClasses.GeneRecordClass%26source_id%3DTVAG_386080
# http%3A%2F%2Fbeetlebase.org%2Fcgi-bin%2Fgbrowse%2FBeetleBase3.gff3%2F%3Fname%3DTC010103
# http%3A%2F%2Fflypush.imgen.bcm.tmc.edu%2Fpscreen%2Fdetails.php%3Fline%3DKG09531
# http%3A%2F%2Ftritrypdb.org%2Ftritrypdb%2FshowRecord.do%3Fname%3DGeneRecordClasses.GeneRecordClass%26source_id%3DTb927.8.620
# http%3A%2F%2Ftoxodb.org%2Ftoxo%2FshowRecord.do%3Fname%3DGeneRecordClasses.GeneRecordClass%26source_id%3DTGME49_053730
# http%3A%2F%2Fwww.boldsystems.org%2Findex.php%2FTaxbrowser_Taxonpage%3Ftaxid%3D27267
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fprobe%2F%3Fterm%3D1000000
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fgenome%2Fsts%2Fsts.cgi%3Fuid%3D456789
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fnucest%2FBP100000
# https%3A%2F%2Fwww.ebi.ac.uk%2Fena%2Fdata%2Fview%2FBP100000
# http%3A%2F%2Fgetentry.ddbj.nig.ac.jp%2Fgetentry%2Fna%2FBP100000
# http%3A%2F%2Fwww.ecogene.org%2Fgene%2FEG10173
# http%3A%2F%2Fgreengenes.lbl.gov%2Fcgi-bin%2Fshow_one_record_v2.pl%3FprokMSA_id%3D100000
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fnucest%2FEY223054.1
# http%3A%2F%2Fwww.ars-grin.gov%2Fcgi-bin%2Fnpgs%2Fhtml%2Ftaxon.pl%3F19333
# http%3A%2F%2Fwww.gabipd.org%2Fdatabase%2Fcgi-bin%2FGreenCards.pl.cgi%3FBioObjectId%3D2679240%26Mode%3DShowBioObject
# http%3A%2F%2Fh-invitational.jp%2Fhinv%2Fspsoup%2Flocus_view%3Fhix_id%3DHIX0004394
# http%3A%2F%2Fh-invitational.jp%2Fhinv%2Fspsoup%2Ftranscript_view%3Fhit_id%3DHIT000195363
# http%3A%2F%2Fwww.homd.org%2Fmodules.php%3Fop%3Dmodload%26name%3DGenomeList%26file%3Dindex%26link%3Ddetailinfo%26seqid%3DSEQF1003
# http%3A%2F%2Fh-invitational.jp%2Fhinv%2Fprotein%2Fprotein_view.cgi%3Fhip_id%3DHIP000030660
# http%3A%2F%2Fwww.homd.org%2Fmodules.php%3Fop%3Dmodload%26name%3DHOMD%26file%3Dindex%26oraltaxonid%3D811%26view%3Ddynamic
# https%3A%2F%2Fwww-is.biotoul.fr%2Fscripts%2FficheIS.php%3Fname%3DISA1083-2
# http%3A%2F%2Fwww.fludb.org%2Fbrc%2FfluSegmentDetails.do%3FncbiGenomicAccession%3DCY077097
# http%3A%2F%2Fwww.jcm.riken.go.jp%2Fcgi-bin%2Fjcm%2Fjcm_number%3FJCM%3D17254
# http%3A%2F%2Fimg.jgi.doe.gov%2Fcgi-bin%2Fw%2Fmain.cgi%3Fsection%3DTaxonDetail%26taxon_oid%3D648028003
# http%3A%2F%2Fwww.mycobank.org%2FBiolomics.aspx%3FTable%3DMycobank%26MycoBankNr_%3D349124
# http%3A%2F%2Fwww.maizegdb.org%2Fcgi-bin%2Fdisplaylocusrecord.cgi%3Fid%3D25011
# http%3A%2F%2Fimg.jgi.doe.gov%2Fcgi-bin%2Fw%2Fmain.cgi%3Fsection%3DGeneDetail%26gene_oid%3D638309541
# http%3A%2F%2Fwww.pseudomonas.com%2Ffeature%2Fshow%2F%3Flocus_tag%3DPSEEN0001
# http%3A%2F%2Fwww.nbrc.nite.go.jp%2FNBRC2%2FNBRCCatalogueDetailServlet%3FID%3DNBRC%26CAT%3D00001234
# http%3A%2F%2Fwww.gramene.org%2Fdb%2Fprotein%2Fprotein_search%3Fprotein_id%3D78073
# http%3A%2F%2Fwww.gramene.org%2Fdb%2Fgenes%2Fsearch_gene%3Facc%3DGR%3A0080039
# http%3A%2F%2Fwww.gramene.org%2Fdb%2Fontology%2Fsearch%3Fid%3DGR_tax%3A013681
# http%3A%2F%2Fwww.gramene.org%2Fdb%2Fqtl%2Fqtl_display%3Fqtl_accession_id%3DCQG5
# http%3A%2F%2Fwww.xenbase.org%2Fgene%2Fshowgene.do%3Fmethod%3DdisplayGeneSummary%26geneId%3D922462
# http%3A%2F%2Fsolgenomics.net%2Fphenome%2Flocus_display.pl%3Flocus_id%3D0001
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FEDAM%2Fdata_1664
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fedam%2Fterms%3Fshort_form%3Ddata_1664
# http%3A%2F%2Fbioportal.bioontology.org%2Fontologies%2F1046
# https%3A%2F%2Fwww.ebi.ac.uk%2Fmiriam%2Fmain%2Fresources%2FMIR%3A00100005
# http%3A%2F%2Fwww.arachnoserver.org%2Ftoxincard.html%3Fid%3DAS000060
# https%3A%2F%2Fbioinformatics.cineca.it%2FPMDB%2Fuser%2F%2Fsearch.php%3Fidsearch%3DPM0012345
# http%3A%2F%2Fbiocyc.org%2Fgetid%3Fid%3DECOLI%3ACYT-D-UBIOX-CPLX
# http%3A%2F%2Ffossilworks.org%2F%3Fa%3DtaxonInfo%26taxon_no%3D83088
# http%3A%2F%2Fwww.cazy.org%2FGT10.html
# https%3A%2F%2Fwww.ebi.ac.uk%2FQuickGO%2FGProtein%3Fac%3DP12345
# http%3A%2F%2Fcompluyeast2dpage.dacya.ucm.es%2Fcgi-bin%2F2d%2F2d.cgi%3Fac%3DO08709
# http%3A%2F%2Feggnog.embl.de%2Fversion_3.0%2Fcgi%2Fsearch.py%3Fsearch_term_0%3DveNOG12876
# http%3A%2F%2Fwww.york.ac.uk%2Fres%2Fthomas%2FGene.cfm%3FrecordID%3DEB0170
# https%3A%2F%2Fbacteria.ensembl.org%2Fid%2FMU9_3181
# https%3A%2F%2Fprotists.ensembl.org%2Fid%2FPF3D7_1328700
# https%3A%2F%2Fmetazoa.ensembl.org%2Fid%2FFBtr0084214
# https%3A%2F%2Feuhcvdb.ibcp.fr%2FeuHCVdb%2Fdo%2FdisplayHCVEntry%3FprimaryAC%3DM58335
# https%3A%2F%2Fplants.ensembl.org%2Fid%2FAT1G73965
# https%3A%2F%2Ffungi.ensembl.org%2Fid%2FCADAFLAT00006211
# http%3A%2F%2Fgenatlas.medecine.univ-paris5.fr%2Ffiche.php%3Fsymbol%3DHBB
# http%3A%2F%2Fwww.cathdb.info%2Fcathnode%2F1.10.10.200
# https%3A%2F%2Furgi.versailles.inra.fr%2FGenefarm%2FGene%2Fdisplay_gene.htpl%3FGENE_ID%3D4892
# http%3A%2F%2Fpbil.univ-lyon1.fr%2Fcgi-bin%2Fview-tree.pl%3Fdb%3DHOGENOM5%26query%3DHBG284870
# http%3A%2F%2Fwww.gpcrdb.org%2Fprotein%2FRL3R1_HUMAN%2F
# ftp%3A%2F%2Fftp.embl-heidelberg.de%2Fpub%2Fdatabases%2Fprotein_extras%2Fhssp%2F102l.hssp.bz2
# ftp%3A%2F%2Fftp.cmbi.ru.nl%2Fpub%2Fmolbio%2Fdata%2Fhssp%2F102l.hssp.bz2
# http%3A%2F%2Fwww.ensembl.org%2FMulti%2FGeneTree%2FImage%3Fdb%3Dcore%3Bgt%3DENSGT00550000074763
# http%3A%2F%2Ftuberculist.epfl.ch%2Fquicksearch.php%3Fgene%2Bname%3DRv1908c
# http%3A%2F%2Fmycobrowser.epfl.ch%2Fmarinosearch.php%3Fgene%2Bname%3DMMAR_2462
# http%3A%2F%2Fmycobrowser.epfl.ch%2Fsmegmasearch.php%3Fgene%2Bname%3DMSMEG_3769
# http%3A%2F%2Fcegg.unige.ch%2Forthodb%2Fresults%3Fsearchtext%3DQ9P0K8
# http%3A%2F%2Fmycobrowser.epfl.ch%2Fleprosysearch.php%3Fgene%2Bname%3DML0224
# http%3A%2F%2Fwww.orpha.net%2Fconsor%2Fcgi-bin%2FOC_Exp.php%3FLng%3DEN%26Expert%3D85163
# http%3A%2F%2Forphanet.bio2rdf.org%2Fdescribe%2F%3Furl%3Dhttp%3A%2F%2Fbio2rdf.org%2Forphanet%3A85163
# http%3A%2F%2Fperoxibase.toulouse.inra.fr%2Fbrowse%2Fprocess%2Fview_perox.php%3Fid%3D5282
# http%3A%2F%2Fsubstrate.burnham.org%2Fprotein%2Fannotation%2F1915%2Fhtml
# http%3A%2F%2Fphylomedb.org%2F%3Fseqid%3DPhy000CLXM_RAT
# http%3A%2F%2Fcutdb.burnham.org%2Frelation%2Fshow%2F25782
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fsites%2Fentrez%3FDb%3Dproteinclusters%26Cmd%3DDetailsSearch%26Term%3DO80725
# http%3A%2F%2Fwww.proteinmodelportal.org%2Fquery%2Funiprot%2FQ0VCA6
# http%3A%2F%2Fwww.protonet.cs.huji.ac.il%2Frequested%2Fcluster_card.php%3Fcluster%3D4349895
# http%3A%2F%2Fwww.protonet.cs.huji.ac.il%2Frequested%2Fprotein_card.php%3Fprotein_id%3D16941567
# https%3A%2F%2Fswissmodel.expasy.org%2Frepository%2Funiprot%2FP23298
# http%3A%2F%2Frebase.neb.com%2Frebase%2Fenz%2F101.html
# https%3A%2F%2Fwww.vectorbase.org%2Fsearch%2Fsite%2FISCW007415%3F%26site%3D%22Genome%22
# http%3A%2F%2Fwww.mirbase.org%2Fcgi-bin%2Fmature.pl%3Fmature_acc%3DMIMAT0000001
# http%3A%2F%2Fcommonchemistry.org%2FChemicalDetail.aspx%3Fref%3D50-00-0
# http%3A%2F%2Fwww.kegg.jp%2Fentry%2FT30002
# http%3A%2F%2Fwww.kegg.jp%2Fentry%2Feco
# http%3A%2F%2Fjglobal.jst.go.jp%2Fen%2Fredirect%3FNikkaji_No%3DJ55.713G
# http%3A%2F%2Fwww.pharmgkb.org%2Fgene%2FPA131
# http%3A%2F%2Fstormo.wustl.edu%2FScerTF%2Fdetails%2FRSC3%2F
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fsra%2FSRX000007
# https%3A%2F%2Fwww.ebi.ac.uk%2Fena%2Fdata%2Fview%2FSRX000007
# http%3A%2F%2Ftrace.ddbj.nig.ac.jp%2FDRASearch%2Fexperiment%3Facc%3DSRX000007
# http%3A%2F%2Frgd.mcw.edu%2Frgdweb%2Fontology%2Fannot.html%3Facc_id%3DPW%3A0000208
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fpw%2Fterms%3Fobo_id%3DPW%3A0000208
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FPW%2FPW%3A0000208
# http%3A%2F%2Frna.igmors.u-psud.fr%2FNAPP%2FNiveau2.php%3Fspecie%3D351
# http%3A%2F%2Frhesus.amu.edu.pl%2Fmirnest%2Fcopy%2Fdetails.php%3Fid%3DMNEST029358
# http%3A%2F%2Fwww.noncode.org%2FNONCODERv3%2Fncrna.php%3Fncid%3D377550
# http%3A%2F%2Fcrdd.osdd.net%2Fservers%2Fvirsirnadb%2Frecord.php%3Fdetails%3Dvirsi1909
# http%3A%2F%2Felm.eu.org%2Felms%2FelmPages%2FCLV_MEL_PAP_1.html
# http%3A%2F%2Fimmunet.cn%2Fbdb%2Findex.php%2Fmimoset%2F1
# https%3A%2F%2Fbykdb.ibcp.fr%2Fdata%2Fhtml%2Fannotated%2FA0A009E7X8.html
# http%3A%2F%2Fwww-bionet.sscc.ru%2Fsitex%2Findex.php%3Fsiteid%3D1000
# http%3A%2F%2Fclipserve.clip.ubc.ca%2Ftopfind%2Fproteins%2FQ9UKQ2
# https%3A%2F%2Fco.mbine.org%2Fspecifications%2Fsbgn.er.level-1.version-1.2
# http%3A%2F%2Fbioinfo.iitk.ac.in%2FMIPModDB%2Fresult.php%3Fcode%3DHOSAPI0399
# http%3A%2F%2Fwww.conoserver.org%2F%3Fpage%3Dcard%26table%3Dprotein%26id%3D2639
# http%3A%2F%2Fwww.kazusa.or.jp%2Fhuge%2Fgfpage%2FKIAA0001%2F
# http%3A%2F%2Fwww.cabri.org%2FCABRI%2Fsrs-bin%2Fwgetz%3F-e%2B-page%2BEntryPage%2B%5Bdsmz_mutz-id%3AACC%20291%5D
# http%3A%2F%2Fwww.be.cabri.org%2FCABRI%2Fsrs-bin%2Fwgetz%3F-e%2B-page%2BEntryPage%2B%5Bdsmz_mutz-id%3AACC%20291%5D
# http%3A%2F%2Fdictybase.org%2Fgene%2FDDB_G0267522
# http%3A%2F%2Fstring.embl.de%2Finteractions%2FP53350
# http%3A%2F%2Fstring-db.org%2Finteractions%2FP53350
# http%3A%2F%2Fwww.bindingdb.org%2Fcompact%2Fe999
# http%3A%2F%2Fphenol-explorer.eu%2Ffoods%2F75
# http%3A%2F%2Fstitch.embl.de%2Finteractions%2FBQJCRHHNABKAKU
# http%3A%2F%2Fwww.whocc.no%2Fatcvet%2Fatcvet_index%2F%3Fcode%3DQJ51RV02
# http%3A%2F%2Fwww.snomedbrowser.com%2FCodes%2FDetails%2F284196006
# http%3A%2F%2Fwww.nlm.nih.gov%2Fcgi%2Fmesh%2F2012%2FMB_cgi%3Fmode%3D%26index%3D17186%26view%3Dexpanded
# http%3A%2F%2Fkanaya.naist.jp%2Fknapsack_jsp%2Finformation.jsp%3Fword%3DC00000001
# http%3A%2F%2Fwww.massbank.jp%2Fjsp%2FFwdRecord.jsp%3Fid%3DPB000166
# http%3A%2F%2Fwww.massbank.eu%2FMassBank%2Fjsp%2FFwdRecord.jsp%3Fid%3DPB000166
# http%3A%2F%2Fwebprod3.hc-sc.gc.ca%2Fdpd-bdpp%2Finfo.do%3Flang%3Deng%26code%3D63250
# http%3A%2F%2Fgmd.mpimp-golm.mpg.de%2FMetabolites%2F68513255-fc44-4041-bc4b-4fd2fae7541d.aspx
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fhomologene%2F1000
# http%3A%2F%2Fhomologene.bio2rdf.org%2Fdescribe%2F%3Furl%3Dhttp%3A%2F%2Fbio2rdf.org%2Fhomologene%3A1000
# http%3A%2F%2Fgenome.crg.es%2Fdatasets%2Fabs2005%2Fentries%2FA0014.html
# http%3A%2F%2Fumbbd.ethz.ch%2Fservlets%2Fpageservlet%3Fptype%3Dc%26compID%3Dc0001
# http%3A%2F%2Fwww.dpvweb.net%2Fdpv%2Fshowdpv.php%3Fdpvno%3D100
# http%3A%2F%2Faps.unmc.edu%2FAP%2Fdatabase%2Fquery_output.php%3FID%3D01001
# http%3A%2F%2Fcdb.ics.uci.edu%2Fcgibin%2FChemicalDetailWeb.py%3Fchemical_id%3D3966782
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2FIEB%2FResearch%2FAcembly%2Fav.cgi%3Fdb%3Dworm%26c%3DGene%26l%3Daap-1
# http%3A%2F%2Fgenius.embnet.dkfz-heidelberg.de%2Fmenu%2Fcgi-bin%2Fsrs7.1.3.1%2Fwgetz%3F-id%2B4ktAl1fNMTA%2B-e%2B%5BIMGT%3A%27M94112%27%5D
# http%3A%2F%2Fwww.imgt.org%2Fligmdb%2Fview%3Fid%3DM94112
# http%3A%2F%2Fwww.guidetopharmacology.org%2FGRAC%2FObjectDisplayForward%3FobjectId%3D101
# http%3A%2F%2Fworfdb.dfci.harvard.edu%2Findex.php%3Fsearch_type%3Dname%26page%3Dshowresultrc%26race_query%3DT01B6.1
# http%3A%2F%2Fwww.soybase.org%2Fsbt%2Fsearch%2Fsearch_results.php%3Fcategory%3DSNP%26search_term%3DBARC-013845-01256
# http%3A%2F%2Fnematode.lab.nig.ac.jp%2Fdb2%2FShowCloneInfo.php%3Fclone%3D6b1
# http%3A%2F%2Fcgsc.biology.yale.edu%2FSite.php%3FID%3D74
# https%3A%2F%2Fwww.ebi.ac.uk%2Farrayexpress%2Farrays%2FA-GEOD-50
# http%3A%2F%2Fantirrhinum.net%2Fcgi-bin%2Face%2Fgeneric%2Ftree%2FDragonDB%3Fname%3D3hB06%3Bclass%3DDNA
# http%3A%2F%2Fwww.kazusa.or.jp%2Frouge%2Fgfpage%2FmKIAA4200%2F
# http%3A%2F%2Fmerops.sanger.ac.uk%2Fcgi-bin%2Ffamsum%3Ffamily%3DS1
# http%3A%2F%2Fantirrhinum.net%2Fcgi-bin%2Face%2Fgeneric%2Ftree%2FDragonDB%3Fname%3DDEF%26amp%3Bclass%3DLocus
# http%3A%2F%2Fantirrhinum.net%2Fcgi-bin%2Face%2Fgeneric%2Ftree%2FDragonDB%3Fname%3Dcho%26amp%3Bclass%3DAllele
# http%3A%2F%2Fantirrhinum.net%2Fcgi-bin%2Face%2Fgeneric%2Ftree%2FDragonDB%3Fname%3DAMDEFA%3Bclass%3DPeptide
# https%3A%2F%2Fcatalog.loc.gov%2Fvwebv%2Fsearch%3FsearchCode%3DSTNO%26searchArg%3D0745-4570%26searchType%3D1%26recCount%3D25
# https%3A%2F%2Fportal.issn.org%2Fresource%2FISSN%2F0745-4570
# http%3A%2F%2Flgsun.grc.nia.nih.gov%2Fcgi-bin%2Fpro3%3Fsname1%3DJ0705A10
# http%3A%2F%2Farabidopsis.info%2FStockInfo%3FNASC_id%3DN1899
# http%3A%2F%2Fwww.pazar.info%2Fcgi-bin%2Ftf_search.cgi%3FgeneID%3DTF0001053
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMO%2FArrayGroup
# https%3A%2F%2Fmged.sourceforge.net%2Fontologies%2FMGEDontology.php%23ArrayGroup
# http%3A%2F%2Fmods.rna.albany.edu%2Fmods%2Fmodifications%2Fview%2F101
# http%3A%2F%2Fwww.plantontology.org%2Famigo%2Fgo.cgi%3Fview%3Ddetails%26query%3DPO%3A0009089
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FPO%2FPO%3A0009089
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fpo%2Fterms%3Fobo_id%3DPO%3A0009089
# http%3A%2F%2Fciliate.org%2Findex.php%2Ffeature%2Fdetails%2FTTHERM_00648910
# http%3A%2F%2Fpurl.org%2Fphylo%2Ftreebase%2Fphylows%2Fstudy%2FTB2%3AS1000%3Fformat%3Dhtml
# http%3A%2F%2Fwww.jcvi.org%2Fcgi-bin%2Ftigrfams%2FHmmReportPage.cgi%3Facc%3DTIGR00010
# http%3A%2F%2Friodb01.ibase.aist.go.jp%2Fsdbs%2Fcgi-bin%2Fcre_frame_disp.cgi%3Fsdbsno%3D4544
# http%3A%2F%2Fwebapps2.ucalgary.ca%2F~groupii%2Fcgi-bin%2Fintron.cgi%3Fname%3DCu.me.I1
# http%3A%2F%2Fwww.guidetopharmacology.org%2FGRAC%2FFamilyDisplayForward%3FfamilyId%3D78
# http%3A%2F%2Fwww.vbase2.org%2Fvgene.php%3Fid%3DhumIGHV025
# https%3A%2F%2Fwww.genecards.org%2Fcgi-bin%2Fcarddisp.pl%3Fgene%3DABL1
# http%3A%2F%2Fwww.cs.tau.ac.il%2F~spike%2Fmaps%2Fspike00001.html
# http%3A%2F%2Fmetlin.scripps.edu%2Fmetabo_info.php%3Fmolid%3D1455
# http%3A%2F%2Fumbbd.ethz.ch%2Fservlets%2Fpageservlet%3Fptype%3Dep%26enzymeID%3De0333
# http%3A%2F%2Fwww.mmrrc.org%2Fcatalog%2FgetSDS.php%3Fmmrrc_id%3D70
# http%3A%2F%2Fumbbd.ethz.ch%2Fservlets%2Fpageservlet%3Fptype%3Dr%26reacID%3Dr0001
# http%3A%2F%2Fumbbd.ethz.ch%2Fservlets%2Fpageservlet%3Fptype%3Dp%26pathway_abbr%3Dala
# http%3A%2F%2Fdictybase.org%2Fdb%2Fcgi-bin%2Ffeature_page.pl%3Fprimary_id%3DDDB0016567
# http%3A%2F%2Fwww.umbbd.ethz.ch%2Fservlets%2Frule.jsp%3Frule%3Dbt0001
# http%3A%2F%2Fcomgen.pl%2Fmirex1%2F%3Fpage%3Dresults%2Frecord%26name%3D165a%26exref%3Dpp2a%26limit%3Dyes
# https%3A%2F%2Fwww.ebi.ac.uk%2Fcgi-bin%2Fimgt%2Fhla%2Fget_allele.cgi%3FA%2A01%3A01%3A01%3A01
# https%3A%2F%2Fbdsc.indiana.edu%2Fstocks%2F33607
# http%3A%2F%2Fopm.phar.umich.edu%2Fprotein.php%3Fpdbid%3D1h68
# http%3A%2F%2Fwww.allergome.org%2Fscript%2Fdettaglio.php%3Fid_molecule%3D1948
# http%3A%2F%2Fwww.pombase.org%2Fspombe%2Fresult%2FSPCC13B11.01
# http%3A%2F%2Fwww.proteinatlas.org%2FENSG00000026508
# http%3A%2F%2Fjaxmice.jax.org%2Fstrain%2F005012.html
# http%3A%2F%2Fwww.ubio.org%2Fbrowser%2Fdetails.php%3FnamebankID%3D2555646
# http%3A%2F%2Fyetfasco.ccbr.utoronto.ca%2FshowPFM.php%3Fmot%3DYOR172W_571.0
# http%3A%2F%2Fdiana.imis.athena-innovation.gr%2FDianaTools%2Findex.php%3Fr%3Dtarbase%2Findex%26mirnas%3Dhsa-let-7a-2-3p
# http%3A%2F%2Fwww.jcvi.org%2Fcharprotdb%2Findex.cgi%2Fview%2FCH_001923
# https%3A%2F%2Fomabrowser.org%2Fcgi-bin%2Fgateway.pl%3Ff%3DDisplayEntry%26p1%3DHUMAN16963
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fprotein%2FCAA71118.1%3Freport%3Dgenpept
# https%3A%2F%2Fomabrowser.org%2Fcgi-bin%2Fgateway.pl%3Ff%3DDisplayGroup%26p1%3DLCSCCPN
# http%3A%2F%2Fwww.ncbi.nlm.nih.gov%2FUniGene%2Fclust.cgi%3FUGID%3D4900
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fprotein%2FCAA71118.1
# http%3A%2F%2Fbitterdb.agri.huji.ac.il%2FReceptor.php%3Fid%3D1
# http%3A%2F%2Fbitterdb.agri.huji.ac.il%2Fbitterdb%2Fcompound.php%3Fid%3D46
# http%3A%2F%2Ftrace.ddbj.nig.ac.jp%2FBPSearch%2Fbioproject%3Facc%3DPRJDB3
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fbioproject%3Fterm%3DPRJDB3
# https%3A%2F%2Fwww.ebi.ac.uk%2Fena%2Fdata%2Fview%2FPRJDB3
# http%3A%2F%2Fpiroplasmadb.org%2Fpiro%2FshowRecord.do%3Fname%3DGeneRecordClasses.GeneRecordClass%26source_id%3DTA14985
# http%3A%2F%2Funite.ut.ee%2Fbl_forw.php%3Fnimi%3DUDB000691
# http%3A%2F%2Fncim.nci.nih.gov%2Fncimbrowser%2FConceptReport.jsp%3Fdictionary%3DNCI%2520MetaThesaurus%26code%3DC0026339
# http%3A%2F%2Fwww.proglycprot.org%2Fdetail.aspx%3FProId%3DAC119
# https%3A%2F%2Fpolbase.neb.com%2Fpolymerases%2F19-T4%23sequences
# http%3A%2F%2Fwww.receptors.org%2Fnucleardb%2Fproteins%2Fprgr_human
# http%3A%2F%2Fsupfam.org%2FSUPERFAMILY%2Fcgi-bin%2Fscop.cgi%3Fipid%3DSSF57615
# http%3A%2F%2Fcbg.garvan.unsw.edu.au%2Fpina%2Finteractome.oneP.do%3Fac%3DQ13485%26showExtend%3Dnull
# http%3A%2F%2Fbacmap.wishartlab.com%2Forganisms%2F1050
# http%3A%2F%2Frice.plantbiology.msu.edu%2Fcgi-bin%2FORF_infopage.cgi%3F%26orf%3DLOC_Os02g13300
# https%3A%2F%2Fwww.uniprot.org%2Ftissues%2FTS-0285
# https%3A%2F%2Fwww.genenames.org%2Fcgi-bin%2Fgene_symbol_report%3Fmatch%3DDAPK1
# http%3A%2F%2Fwww.pantherdb.org%2Fpathway%2FpathwayDiagram.jsp%3FcatAccession%3DP00024
# https%3A%2F%2Ffungidb.org%2Ffungidb%2Fapp%2Frecord%2Fgene%2FCNBG_0001
# http%3A%2F%2Fwww.flyrnai.org%2Fcgi-bin%2FRNAi_gene_lookup_public.pl%3Fgname%3DDRSC05221
# http%3A%2F%2Fdarcsite.genzentrum.lmu.de%2Fdarc%2Fview.php%3Fid%3D1250
# http%3A%2F%2Fcerevisiae.oridb.org%2Fdetails.php%3Fid%3D1
# http%3A%2F%2Fpombe.oridb.org%2Fdetails.php%3Fid%3D1
# http%3A%2F%2Fscop.mrc-lmb.cam.ac.uk%2Fscop%2Fsearch.cgi%3Fsunid%3D47419
# http%3A%2F%2Fscop.berkeley.edu%2Fsunid%3D47419
# https%3A%2F%2Fwww.ebi.ac.uk%2Fena%2Fdata%2Fview%2FBN000065
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fnuccore%2FBN000065
# http%3A%2F%2Fidp1.force.cs.is.nagoya-u.ac.jp%2Fpscdb%2F051.html
# http%3A%2F%2Fwww.pantree.org%2Fnode%2FannotationNode.jsp%3Fid%3DPTN000000026
# http%3A%2F%2Forion.rnet.missouri.edu%2F~nz953%2FDOMMINO%2Findex.php%2Fresult%2Fshow_network%2F2GC4
# http%3A%2F%2Fwww.ncbi.nlm.nih.gov%2FCCDS%2FCcdsBrowse.cgi%3FREQUEST%3DCCDS%26DATA%3DCCDS13573.1
# https%3A%2F%2Fwww.ebi.ac.uk%2Fgxa%2Fgenes%2FAT4G01080
# https%3A%2F%2Fwww.ebi.ac.uk%2Fgxa%2Fexperiments%2FE-MTAB-2037
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fatlas-experiments%2FE-MTAB-2037
# http%3A%2F%2Fwww.hprd.org%2Fprotein%2F00001
# ftp%3A%2F%2Fftp.ebi.ac.uk%2Fpub%2Fdatabases%2Flrgex%2FLRG_1.xml
# http%3A%2F%2Fwww.ensembl.org%2FHomo_sapiens%2FLRG%2FSummary%3Flrg%3DLRG_1
# http%3A%2F%2Fasia.ensembl.org%2FHomo_sapiens%2FLRG%2FSummary%3Flrg%3DLRG_1
# http%3A%2F%2Fuswest.ensembl.org%2FHomo_sapiens%2FLRG%2FSummary%3Flrg%3DLRG_1
# http%3A%2F%2Fuseast.ensembl.org%2FHomo_sapiens%2FLRG%2FSummary%3Flrg%3DLRG_1
# https%3A%2F%2Fwww.ebi.ac.uk%2Fmetabolights%2FMTBLS1
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fmetabolights_dataset%2FMTBLS1
# https%3A%2F%2Forcid.org%2F0000-0002-5355-2576
# http%3A%2F%2Fnbn-resolving.org%2Fresolver%3Fidentifier%3Durn%3Anbn%3Afi%3Atkk-004781%26verb%3Dredirect
# http%3A%2F%2Fkinase.bioinformatics.tw%2Fshowall.jsp%3Ftype%3DKinase%26info%3DGene%26name%3DAURKA%26drawing%3D0%26sorting%3D0%26kinome%3D1
# http%3A%2F%2Fwww.uniprot.org%2Funiprot%2FQ5BJF6-3
# http%3A%2F%2Fpurl.uniprot.org%2Funiprot%2FQ5BJF6-3
# http%3A%2F%2Fwww.uniprot.org%2Funiparc%2F%3Fquery%3DQ5BJF6-3
# http%3A%2F%2Fkinase.bioinformatics.tw%2Fshowall.jsp%3Ftype%3DPhosphoProtein%26info%3DGene%26name%3DAURKA%26drawing%3D0%26sorting%3D0%26kinome%3D0
# http%3A%2F%2Fwww.chemspider.com%2Finchikey%3DRYYVLZVUVIJVGH-UHFFFAOYSA-N
# http%3A%2F%2Fcactus.nci.nih.gov%2Fchemical%2Fstructure%2FRYYVLZVUVIJVGH-UHFFFAOYSA-N%2Fnames
# http%3A%2F%2Fwww.chemspider.com%2FInChI%3D1S%2FC2H6O%2Fc1-2-3%2Fh3H%2C2H2%2C1H3
# http%3A%2F%2Fwebbook.nist.gov%2Fcgi%2Fcbook.cgi%3FInChI%3D1S%2FC2H6O%2Fc1-2-3%2Fh3H%2C2H2%2C1H3
# https%3A%2F%2Fwww.ebi.ac.uk%2Fchebi%2FadvancedSearchFT.do%3FsearchString%3DInChI%3D1S%2FC2H6O%2Fc1-2-3%2Fh3H%2C2H2%2C1H3
# http%3A%2F%2Frdf.openmolecules.net%2F%3FInChI%3D1S%2FC2H6O%2Fc1-2-3%2Fh3H%2C2H2%2C1H3
# http%3A%2F%2Fen.wikipedia.org%2Fwiki%2FSM_UB-81
# http%3A%2F%2Fdbpedia.org%2Fpage%2FSM_UB-81
# http%3A%2F%2Fbioinformatics.hsanmartino.it%2Fhypercldb%2Fcl3603.html
# http%3A%2F%2Fwww.kegg.jp%2Fentry%2Fev%3AE00032
# http%3A%2F%2Fbipaa.genouest.org%2Fapps%2Fgrs-2.3%2Fgrs%3FreportID%3Daphidbase_transcript_report%26objectID%3DACYPI000159
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fefo%2Fterms%3Fobo_id%3DEFO%3A0004859
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FEFO%2Fefo%3AEFO_0004859
# https%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004859
# http%3A%2F%2Fwww.hgmd.cf.ac.uk%2Fac%2Fgene.php%3Fgene%3DCALM1
# https%3A%2F%2Fwww.affymetrix.com%2FLinkServlet%3Fprobeset%3D243002_at
# http%3A%2F%2Fcu.affymetrix.bio2rdf.org%2Fdescribe%2F%3Furl%3Dhttp%3A%2F%2Fbio2rdf.org%2Faffymetrix%3A243002_at
# http%3A%2F%2Fwww.treefam.org%2Ffamily%2FTF101014
# http%3A%2F%2Fwww.bioinsilico.org%2Fcgi-bin%2FCAPSDB%2FgetCAPScluster%3Fnidcl%3D434
# http%3A%2F%2Fepsf.bmad.bii.a-star.edu.sg%2Fcube%2Fdb%2Fdata%2FAKR%2F
# http%3A%2F%2Fidp1.force.cs.is.nagoya-u.ac.jp%2FIDEAL%2FidealItem.php%3Fid%3DIID00001
# http%3A%2F%2Fwww.pocketome.org%2Ffiles%2F1433C_TOBAC_1_252.html
# http%3A%2F%2Fpsb.kobic.re.kr%2FSTAP%2Frefinement1%2Fresult.php%3Fsearch%3D1a24
# http%3A%2F%2Fgenomesonline.org%2Fcgi-bin%2FGOLD%2Fbin%2FGOLDCards.cgi%3Fgoldstamp%3DGm00047
# http%3A%2F%2Fbugs.sgul.ac.uk%2Fbugsbase%2Ftabs%2Fexperiment.php%3Fexpt_id%3D288%26action%3Dview
# http%3A%2F%2Fbugs.sgul.ac.uk%2Fbugsbase%2Ftabs%2Fprotocol.php%3Fprotocol_id%3D67%26amp%3Baction%3Dview
# http%3A%2F%2Fwww.variationontology.org%2Fcgi-bin%2Famivario%2Fterm-details.cgi%3Fterm%3DVariO%3A0294
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVARIO%2FVariO%3A0294
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fvario%2Fterms%3Fobo_id%3DVariO%3A0294
# http%3A%2F%2Ftolweb.org%2F98034
# http%3A%2F%2Fwww.viprbrc.org%2Fbrc%2FviprStrainDetails.do%3FstrainName%3DBeAn%2070563%26decorator%3Darena
# http%3A%2F%2Fwww.fungalbarcoding.org%2FBioloMICS.aspx%3FTable%3DFungal%20barcodes%26Rec%3D2224%26Fields%3DAll%26ExactMatch%3DT
# https%3A%2F%2Frfam.xfam.org%2Ffamily%2FRF00230
# http%3A%2F%2Fepd.vital-it.ch%2Fcgi-bin%2Fquery_result.pl%3Fout_format%3DNICE%26Entry_0%3DTA_H3
# http%3A%2F%2Fwasabi.lutzonilab.net%2Fpub%2FdisplayTaxonInfo%3Faftol_id%3D959
# http%3A%2F%2Fwww.aspergillusgenome.org%2Fcgi-bin%2Flocus.pl%3Fdbid%3DASPL0000349247
# http%3A%2F%2Fwww.aspergillusgenome.org%2Fcgi-bin%2Fprotein%2FproteinPage.pl%3Fdbid%3DASPL0000349247
# http%3A%2F%2Fautism.mindspec.org%2FGeneDetail%2FADA
# http%3A%2F%2Fbacmap.wishartlab.com%2Fmaps%2FAP011135%2Findex.html
# http%3A%2F%2Fwww.hipaaspace.com%2FMedical_Billing%2FCoding%2FNational.Drug.Codes%2F0002-1975-61
# http%3A%2F%2Fndc.bio2rdf.org%2Fdescribe%2F%3Furl%3Dhttp%3A%2F%2Fbio2rdf.org%2Fndc%3A0002-1975-61
# https%3A%2F%2Fbgee.org%2F%3Fpage%3Dgene%26gene_id%3DFBgn0000015
# http%3A%2F%2Fbgee.unil.ch%2Fbgee%2Fbgee%3Fpage%3Danatomy%26action%3Dorgans%26stage_id%3DHsapDO%3A0000004%26stage_children%3Don
# http%3A%2F%2Fbgee.unil.ch%2Fbgee%2Fbgee%3Fpage%3Dgene_family%26action%3Dfamily_details%26gene_family_id%3DENSFM00500000270089
# http%3A%2F%2Fbgee.unil.ch%2Fbgee%2Fbgee%3Fpage%3Danatomy%26action%3Dorgan_details%26organ_id%3DEHDAA%3A2185%26organ_children%3Don
# https%3A%2F%2Fcgap.nci.nih.gov%2FPathways%2FBioCarta%2Fh_aktPathway
# http%3A%2F%2Fgmd.mpimp-golm.mpg.de%2FSpectrums%2F53d583d8-40c6-40e1-9296-23f821cd77a5
# http%3A%2F%2Fgmd.mpimp-golm.mpg.de%2Fprofile%2Fdefault.aspx%3FXemlId%3D10b38aaf-b977-4950-85b8-f4775f66658d
# http%3A%2F%2Fgmd.mpimp-golm.mpg.de%2FReferenceSubstances%2F8cf84adb-b4db-4807-ac98-0004247c35df
# http%3A%2F%2Fgmd.mpimp-golm.mpg.de%2FAnalytes%2F4f0fa9b6-514f-4ff4-98cc-0009bc08eb80
# https%3A%2F%2Fwww.ebi.ac.uk%2Fintact%2Fmolecule%2FEBI-366083
# https%3A%2F%2Fdailymed.nlm.nih.gov%2Fdailymed%2FdrugInfo.cfm%3Fsetid%3D973a9333-fec7-46dd-8eb5-25738f06ee54
# http%3A%2F%2Fwww.depod.bioss.uni-freiburg.de%2Fshowp.php%3Fgene%3DPTPN1
# http%3A%2F%2Fwww.phytozome.net%2FgenePage.php%3Fcrown%26method%3D0%26search%3D1%26detail%3D1%26searchText%3Dlocusname%3AGlyma0021s00410
# http%3A%2F%2Fwww.cellsignal.com%2Freference%2Fpathway%2FAkt_PKB.html
# http%3A%2F%2Fgenolist.pasteur.fr%2FSubtiList%2Fgenome.cgi%3Fexternal_query%2BBG11523
# http%3A%2F%2Fsideeffects.embl.de%2Fse%2FC0017565%2F
# http%3A%2F%2Fsideeffects.embl.de%2Fdrugs%2F2244%2F
# https%3A%2F%2Fwww.broadinstitute.org%2Fannotation%2Fgenome%2Fmagnaporthe_grisea%2FGeneDetails.html%3Fsp%3DS7000002168151102
# http%3A%2F%2Fccr.coriell.org%2FSections%2FSearch%2FSample_Detail.aspx%3FRef%3DGM17027
# http%3A%2F%2Fwww.wikigenes.org%2Fe%2Fgene%2Fe%2F3771877.html
# https%3A%2F%2Fmips.helmholtz-muenchen.de%2Fcorum%2F%3Fid%3D100
# http%3A%2F%2Fecoliwiki.net%2Fcolipedia%2Findex.php%2FaaeA%3AGene
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMA%2FMA%3A0002502
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fma%2Fterms%3Fobo_id%3DMA%3A0002502
# http%3A%2F%2Fwww.informatics.jax.org%2Fsearches%2FAMA.cgi%3Fid%3DMA%3A0002502
# http%3A%2F%2Fwww.jstor.org%2Fstable%2F3075966
# https%3A%2F%2Fwww.ebi.ac.uk%2Finterpro%2Fgenomeproperties%2F%23GenProp0699
# http%3A%2F%2Fwww.unimod.org%2Fmodifications_view.php%3Feditid1%3D1200
# http%3A%2F%2Fvbrc.org%2Fgene_detail.asp%3Fgene_id%3D35742
# http%3A%2F%2Fviralzone.expasy.org%2Fall_by_protein%2F992.html
# http%3A%2F%2Fcsbl.bmb.uga.edu%2FDOOR%2Foperon.php%3Fid%3D1398574
# http%3A%2F%2Fdegradome.uniovi.es%2Fcgi-bin%2Fprotease%2FAx1
# http%3A%2F%2Fplanttfdb.cbi.pku.edu.cn%2Ftf.php%3Fsp%3DAth%26did%3DAT1G01030.1
# http%3A%2F%2Fwww.transcriptionfactor.org%2Findex.cgi%3FSearch%2FDomain%2Bdomain%3A0045310%2Bcat%3ADBD
# http%3A%2F%2Fwww.molbase.com%2Fen%2Findex.php%3Fapp%3Dsearch%26search_keyword%3D128796-39-4
# http%3A%2F%2Fyeastrc.org%2Fpdr%2FviewProtein.do%3Fid%3D2673500
# http%3A%2F%2Ffunc.mshri.on.ca%2Ffly%2Fgenes%2Flist_functional_scores%2F10194
# http%3A%2F%2Ffunc.mshri.on.ca%2Fhuman%2Fgenes%2Flist_functional_scores%2F119514
# http%3A%2F%2Fmetarray.ucsc.edu%2Fcgi-bin%2Fintron%2FyirIntrondb%3ForfName%3DSNR17A
# http%3A%2F%2Ffunc.mshri.on.ca%2Fmouse%2Fgenes%2Flist_functional_scores%2F1351341
# http%3A%2F%2Fwww.cbioportal.org%2Fstudy%3Fid%3Dlaml_tcga_pub%23summary
# http%3A%2F%2Ffunc.mshri.on.ca%2Fyeast%2Fgenes%2Flist_functional_scores%2F2701
# http%3A%2F%2Fwww-deletion.stanford.edu%2Fcgi-bin%2FYDPM%2FYDPM_search.cgi%3Fthelist%3DYAL001C
# https%3A%2F%2Fwww.wormbase.org%2Fspecies%2Fc_elegans%2Frnai%2FWBRNAi00086878
# http%3A%2F%2Fcaps.ncbs.res.in%2Fcgi-bin%2Fpass2%2F%2Fshow_sf.py%3Fsf_id%3D46977
# http%3A%2F%2Fdb-mml.sjtu.edu.cn%2FICEberg%2Ffeature_page.php%3Fice_id%3D100
# http%3A%2F%2Fdb-mml.sjtu.edu.cn%2FICEberg%2Fbrowse_result.php%3Ftype%3Dfam%26fam_id%3D1
# http%3A%2F%2Fwww.mgc.ac.cn%2Fcgi-bin%2FVFs%2Fgene.cgi%3FGeneID%3DVFG2154
# http%3A%2F%2Fwww.mgc.ac.cn%2Fcgi-bin%2FVFs%2Fgenus.cgi%3FGenus%3DChlamydia
# http%3A%2F%2Fwww.nlm.nih.gov%2Fcgi%2Fmesh%2F2013%2FMB_cgi%3Fmode%3D%26index%3D17165%26view%3Dexpanded
# http%3A%2F%2Fwww.kegg.jp%2Fentry%2FM00002
# http%3A%2F%2Fwww.kegg.jp%2Fentry%2FH00076
# http%3A%2F%2Fligandbox.protein.osaka-u.ac.jp%2Fligandbox%2Fcgi-bin%2Fliginf.cgi%3Fid%3DD00001
# https%3A%2F%2Fwww.glycoepitope.jp%2Fepitopes%2FEP0311
# http%3A%2F%2Fwww.nlm.nih.gov%2Fmedlineplus%2Fency%2Farticle%2F002804.htm
# http%3A%2F%2Fjcggdb.jp%2Fidb%2Fjcggdb%2FJCGG-STR008690
# http%3A%2F%2Fwww.bioinfo.org%2FNONCODEv4%2Fshow_rna.php%3Fid%3DNONHSAT000001
# http%3A%2F%2Fvirtualflybrain.org%2Freports%2F00000001
# http%3A%2F%2Fwww.bioinfo.org%2FNONCODEv4%2Fshow_gene.php%3Fid%3DNONHSAG00001
# http%3A%2F%2Fwww.shigen.nig.ac.jp%2Frice%2ForyzabaseV4%2Fgene%2Fdetail%2F117
# http%3A%2F%2Fwww.shigen.nig.ac.jp%2Frice%2ForyzabaseV4%2Fstrain%2FinducedMutationLine%2Fdetail%2F21393
# http%3A%2F%2Foryzatagline.cirad.fr%2Fcgi-bin%2Fgeneral_mutant.pl%3Fline%3DAADB12
# http%3A%2F%2Fwww.shigen.nig.ac.jp%2Frice%2ForyzabaseV4%2Fstrain%2FwildCore%2Fdetail%2F1
# http%3A%2F%2Fwww.shigen.nig.ac.jp%2Frice%2ForyzabaseV4%2Fdevstageineachorgan%2Fdetail%2F34
# http%3A%2F%2Fpax-db.org%2F%23%21protein%2F977869
# http%3A%2F%2Fwww.rcsb.org%2Fpdb%2Fligand%2Fligandsummary.do%3FhetId%3DTRQ
# https%3A%2F%2Fwww.ebi.ac.uk%2Fpdbe-srv%2Fpdbechem%2FchemicalCompound%2Fshow%2FTRQ
# http%3A%2F%2Fmerops.sanger.ac.uk%2Fcgi-bin%2Fpepsum%3Fid%3DI31.952
# http%3A%2F%2Fpax-db.org%2F%23%21species%2F9606
# http%3A%2F%2Fpharminfo.pharm.kyoto-u.ac.jp%2Fservices%2Fglida%2Fgpcr_information.php%3Fid%3DACM1_HUMAN
# https%3A%2F%2Fanimaldiversity.org%2Faccounts%2FLycalopex_vetulus%2F
# http%3A%2F%2Fbioinformatics.ramapo.edu%2FGRSDB2%2Fgeneview.php%3FgeneID%3D10142
# http%3A%2F%2Fpharminfo.pharm.kyoto-u.ac.jp%2Fservices%2Fglida%2Fligand_information.php%3Fid%3DL000001
# http%3A%2F%2Fcompbio.cs.queensu.ca%2Fcgi-bin%2Fcompbio%2Fsearch%2Fmain.cgi%3Fsearch_mode%3Did%26amp%3Bid_type%3Dsnp_id%26amp%3Bid_val%3Drs17852708
# http%3A%2F%2Fproteomecentral.proteomexchange.org%2Fcgi%2FGetDataset%3FID%3DPXD000500
# http%3A%2F%2Fresearch.nhgri.nih.gov%2Fapps%2Fhomeodomain%2Fweb%2Findex.cgi%3Fmode%3Dview%26amp%3Bview%3Dproteins%26amp%3Bid%3D63
# http%3A%2F%2Fbiomodels.net%2Frdf%2Fvocabulary.rdf%23rateRule
# http%3A%2F%2Fbioinfo.lifl.fr%2Fnorine%2Fresult.jsp%3FID%3DNOR00681
# http%3A%2F%2Fsenselab.med.yale.edu%2FORDB%2FData%2F8497
# http%3A%2F%2Fwww.p3db.org%2Fphosphosite.php%3Fid%3D65%26ref%3D0
# http%3A%2F%2Fsenselab.med.yale.edu%2FOdorDB%2FData%2F74%2F%3Fdb%3D5
# http%3A%2F%2Fwww.animalgenome.org%2Fcgi-bin%2FQTLdb%2FBT%2Fqdetails%3FQTL_ID%3D4685
# http%3A%2F%2Fwww.p3db.org%2Fprotein.php%3Fid%3D70%26amp%3Bref%3D0
# http%3A%2F%2Ftopdb.enzim.hu%2F%3Fm%3Dshow%26id%3DAP00378
# http%3A%2F%2Fwww.animalgenome.org%2Fcgi-bin%2FQTLdb%2FGG%2Fqdetails%3FQTL_ID%3D14362
# https%3A%2F%2Fwww.ebi.ac.uk%2Fmetagenomics%2Fsamples%2FSRS086444
# http%3A%2F%2Fwww.animalgenome.org%2Fcgi-bin%2FQTLdb%2FOA%2Fqdetails%3FQTL_ID%3D19803
# https%3A%2F%2Fwww.ebi.ac.uk%2Fega%2Fstudies%2FEGAS00000000001
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fega%2FEGAS00000000001
# http%3A%2F%2Fwww.animalgenome.org%2Fcgi-bin%2FQTLdb%2FSS%2Fqdetails%3FQTL_ID%3D14
# https%3A%2F%2Fwww.ebi.ac.uk%2Fega%2Fdatasets%2FEGAD00000000001
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fega%2FEGAD00000000001
# https%3A%2F%2Fbiomodels.net%2Fvocab%2Fidot.rdf%23identifierPattern
# http%3A%2F%2Fantibodyregistry.org%2FAB_493771
# http%3A%2F%2Fbioportal.bioontology.org%2Fontologies%2FMAMO%2F%3Fp%3Dclasses%26conceptid%3Dhttp%3A%2F%2Fidentifiers.org%2Fmamo%2FMAMO_0000026
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fmamo%2Fterms%3Fshort_form%3DMAMO_0000026
# https%3A%2F%2Fwww.ebi.ac.uk%2Fpride%2Farchive%2Fprojects%2FPXD000440
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fpride%2FPXD000440
# http%3A%2F%2Fintron.ucsc.edu%2Fcgi-bin%2Fyeast4.3%2Fintronreports.pl%3Foutputformat%3Dfull%26amp%3BorfName%3DSNR17A
# https%3A%2F%2Fwww.genenames.org%2Fgenefamilies%2FPADI
# http%3A%2F%2Fardb.cbcb.umd.edu%2Fcgi%2Fsearch.cgi%3Fdb%3DL%26amp%3Bfield%3Dni%26amp%3Bterm%3DCAE46076
# https%3A%2F%2Fwww.proteomicsdb.org%2F%23human%2FproteinDetails%2F53504%2Fsummary
# http%3A%2F%2Fwww.humanproteomemap.org%2Fprotein.php%3Fhpm_id%3D1968
# https%3A%2F%2Fwww.proteomicsdb.org%2F%23human%2FproteinDetails%2F53504%2Fpeptides%2F
# http%3A%2F%2Fwww.drugbank.ca%2Fbiodb%2Fbio_entities%2FBE0000048
# http%3A%2F%2Ffoodb.ca%2Fcompounds%2FFDB002100
# http%3A%2F%2Fwww.humanproteomemap.org%2Fspectrum.php%3Fpep_id%3D9606117
# http%3A%2F%2Fzinc15.docking.org%2Fsubstances%2FZINC1084
# http%3A%2F%2Ffdasis.nlm.nih.gov%2Fsrs%2Fsrsdirect.jsp%3Fregno%3D3G6A5W338E
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fordo%2Fterms%3Fshort_form%3DOrphanet_C023
# https%3A%2F%2Fwww.ebi.ac.uk%2Fontology-lookup%2F%3FtermId%3DPAR%3A0116
# https%3A%2F%2Fwww.ebi.ac.uk%2Fmetagenomics%2Fprojects%2FERP004492
# http%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fclinvar%2FRCV000033555.3%2F
# https%3A%2F%2Fwww.clinicaltrialsregister.eu%2Fctr-search%2Fsearch%3Fquery%3D2008-005144-16
# https%3A%2F%2Fwww.google.com%2Fpatents%2FUS4145692
# http%3A%2F%2Fpatft.uspto.gov%2Fnetacgi%2Fnph-Parser%3FSect2%3DPTO1%26Sect2%3DHITOFF%26p%3D1%26u%3D%2Fnetahtml%2FPTO%2Fsearch-bool.html%26r%3D1%26f%3DG%26l%3D50%26d%3DPALL%26RefSrch%3Dyes%26Query%3DPN%2F4145692
# http%3A%2F%2Fexac.broadinstitute.org%2Fvariant%2F22-46615880-T-C
# https%3A%2F%2Fworldwide.espacenet.com%2Fclassification%3Flocale%3Den_EP%23%21%2FCPC%3DA01M1%2F026
# https%3A%2F%2Fwww.gwascentral.org%2Fstudy%2FHGVST1828
# https%3A%2F%2Fwww.gwascentral.org%2Fmarker%2FHGVM15354
# http%3A%2F%2Fbigg.ucsd.edu%2Fmodels%2Funiversal%2Fmetabolites%2F12dgr161
# http%3A%2F%2Flincsportal.ccs.miami.edu%2Fcells%2F%23%2Fview%2FLCL-2085
# http%3A%2F%2Flincs.hms.harvard.edu%2Fdb%2Fproteins%2F200282%2F
# http%3A%2F%2Flincsportal.ccs.miami.edu%2FSmallMolecules%2F%23%2Fview%2FLSM-6306
# http%3A%2F%2Fexac.broadinstitute.org%2Ftranscript%2FENST00000407236
# http%3A%2F%2Fexac.broadinstitute.org%2Fgene%2FENSG00000169174
# https%3A%2F%2Fwww.wikidata.org%2Fwiki%2FQ2207226
# http%3A%2F%2Fwww.grenoble.prabi.fr%2Fobiwarehouse%2Funipathway%2Fupc%3Fupid%3DUPC04349
# http%3A%2F%2Fbigg.ucsd.edu%2Fmodels%2FiECABU_c1320
# https%3A%2F%2Fregistry.identifiers.org%2Fdeprecation%2Fresources%2FMIR%3A00100729%2FBiotin_biosynthesis
# http%3A%2F%2Fmodelseed.org%2Fbiochem%2Fcompounds%2Fcpd15380
# http%3A%2F%2Fbigg.ucsd.edu%2Fcompartments%2Fc
# http%3A%2F%2Fbigg.ucsd.edu%2Fmodels%2Funiversal%2Freactions%2F13GS
# http%3A%2F%2Flinkedlifedata.com%2Fresource%2Fumls%2Fid%2FC0021390
# https%3A%2F%2Fwww.ebi.ac.uk%2Fpdbe%2Fentry%2Femdb%2FEMD-1001
# http%3A%2F%2Fid.nlm.nih.gov%2Fmesh%2FC000100
# http%3A%2F%2Fmirtarbase.mbc.nctu.edu.tw%2Fphp%2Fdetail.php%3Fmirtid%3DMIRT000002
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10015919
# http%3A%2F%2Flisanwanglab.org%2FDASHR%2Fentry%2Fhsa-mir-200a
# http%3A%2F%2Fmona.fiehnlab.ucdavis.edu%2F%23%2Fspectra%2Fsplash%2Fsplash10-0zq2000000-77302b0326a418630a84
# https%3A%2F%2Fdashr1.lisanwanglab.org%2Fentry%2Fhsa-mir-200a%23hsa-mir-200a%23exprPerTissueTable
# http%3A%2F%2Fwww.grenoble.prabi.fr%2Fobiwarehouse%2Funipathway%2Fucr%3Fupid%3DUCR00226
# http%3A%2F%2Fwww.sasbdb.org%2Fdata%2FSASDAX8
# http%3A%2F%2Fcompbio.charite.de%2Fhpoweb%2Fshowterm%3Fid%3DHP%3A0000118
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fhp%2Fterms%3Fobo_id%3DHP%3A0000118
# https%3A%2F%2Fwww.genenames.org%2Fcgi-bin%2Fgenefamilies%2Fset%2F141
# https%3A%2F%2Fmedical-data-models.org%2Fforms%2F4776
# http%3A%2F%2Fcicblade.dep.usal.es%3A8080%2FAPID%2FInteractions.action%3Fprotein%3DP01116
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fprobonto%2Fterms%3Fshort_form%3DPROB_c0000005
# https%3A%2F%2Fwww.storedb.org%2F%3FSTOREDB%3ASTUDY1040
# http%3A%2F%2Fwww.kegg.jp%2Fentry%2Fhsa00190
# http%3A%2F%2Fwww.informatics.jax.org%2Fsearches%2FPhat.cgi%3Fid%3DMP%3A0005452
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fmp%2Fterms%3Fobo_id%3DMP%3A0005452
# https%3A%2F%2Fbioportal.bioontology.org%2Fontologies%2FMP%2FMP%3A0005452
# http%3A%2F%2Fplanttfdb.cbi.pku.edu.cn%2Ftf.php%3Fuid%3DAth_AT1G01030.1
# http%3A%2F%2Fmulticellds.org%2FMultiCellDB%2FMCDS_C_0000000001
# http%3A%2F%2Fmulticellds.org%2FMultiCellDB%2FMCDS_L_0000000001
# http%3A%2F%2Fmulticellds.org%2FMultiCellDB%2FMCDS_S_0000000001
# http%3A%2F%2Fe-cyanobacterium.org%2Fbcs%2Fentity%2F23%2F
# http%3A%2F%2Flincsportal.ccs.miami.edu%2Fdatasets%2F%23%2Fview%2FLDS-1110
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Flincs%2FLDS-1110
# http%3A%2F%2Fe-cyanobacterium.org%2Fmodels%2Fmodel%2F26%2F
# http%3A%2F%2Fe-cyanobacterium.org%2Fbcs%2Frule%2F56%2F
# http%3A%2F%2Fddr.nal.usda.gov%2Fdspace%2Fhandle%2F10113%2F50018
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fms%2Fterms%3Fobo_id%3DMS%3A1000001
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMS%2FMS%3A1000001
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fenvo%2Fterms%3Fobo_id%3DENVO%3A09200010
# http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FENVO%2FENVO%3A09200010
# https%3A%2F%2Fwww.grid.ac%2Finstitutes%2Fgrid.225360.0
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fmedgen%2F760050
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fclinvar%2Fvariation%2F12345
# http%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fclinvar%3Fterm%3DSCV000151292
# https%3A%2F%2Fregistry.identifiers.org%2Fregistry%3Fquery%3D%22MIR%3A00100037%22
# http%3A%2F%2Fprogenetix.org%2Fpgx%3Aicdom%3A8500_3
# http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FIAO_0000030
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fprojects%2Fgap%2Fcgi-bin%2Fstudy.cgi%3Fstudy_id%3Dphs000768.v2.p1
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fomit%2Fterms%3Fshort_form%3DOMIT_0005506
# http%3A%2F%2Fgetentry.ddbj.nig.ac.jp%2Fgetentry%2Fdad%2FAAA35559
# https%3A%2F%2Fwww.ebi.ac.uk%2Fena%2Fdata%2Fview%2FAAA35559
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fprotein%2FAAA35559
# https%3A%2F%2Fportal.gdc.cancer.gov%2Fcases%2Fae8c77fe-e6c8-44d5-8265-4a38c637bbef
# https%3A%2F%2Fmetacyc.org%2FMETA%2FNEW-IMAGE%3Ftype%3DREACTION%26object%3DRXN-14904
# https%3A%2F%2Fglytoucan.org%2FStructures%2FGlycans%2FG00054MO
# https%3A%2F%2Fmetacyc.org%2Fcompound%3Forgid%3DMETA%26id%3DCPD-10330
# https%3A%2F%2Fcn.dataone.org%2Fcn%2Fv2%2Fresolve%2F%7B00030692-0FE1-4A1B-955E-A2E55D659267%7D
# https%3A%2F%2Fmmp.sfb.uit.no%2Fdatabases%2Fmarref%2F%23%2Frecords%2FMMP3312982.2
# http%3A%2F%2Fwww.cathdb.info%2Fcathnode%2F1.10.8.10
# https%3A%2F%2Fmmp.sfb.uit.no%2Fdatabases%2Fmarcat%2F%23%2Frecords%2FMMP743597.11
# https%3A%2F%2Fmmp.sfb.uit.no%2Fdatabases%2Fmardb%2F%23%2Frecords%2FMMP02954345.1
# https%3A%2F%2Faopwiki.org%2Faops%2F98
# https%3A%2F%2Fbio.tools%2Funiprotkb
# https%3A%2F%2Fgenelab-data.ndc.nasa.gov%2Fgenelab%2Faccession%2FGLDS-141
# https%3A%2F%2Fwww.arraymap.org%2Fpgx%3Aicdom%3A8500_3
# http%3A%2F%2Fwww.begdb.com%2Findex.php%3Faction%3DoneMolecule%26state%3Dshow%26id%3D4214
# https%3A%2F%2Fherv.img.cas.cz%2Fs%2FTHE1B
# https%3A%2F%2Frepo.napdi.org%2Fstudy%2F28
# http%3A%2F%2Fcrispr.i2bc.paris-saclay.fr%2Fcgi-bin%2Fcrispr%2FSpecieProperties_db.cgi%3FTaxon_id%5B%5D%3D551115
# https%3A%2F%2Fdb.systemsbiology.net%2Fsbeams%2Fcgi%2FPeptideAtlas%2FShowObservedSpectrum%3Fusi%3Dmzspec%3APXD002255%3A%3AES_XP_Ubi_97H_HCD_349%3Ascan%3A9617%3ALAEIYVNSSFYK%2F2
# http%3A%2F%2Fsugarbind.expasy.org%2Flectins%2F172
# http%3A%2F%2Fsearch.sisuproject.fi%2F%23%2Fvariant%2F17%3A41223048
# https%3A%2F%2Flicebase.org%2F%3Fq%3DEMLSAT00000003403
# https%3A%2F%2Furgi.versailles.inra.fr%2Fgnpis%2F%23result%2Fterm%3DAY109603
# https%3A%2F%2Frnacentral.org%2Frna%2FURS0000759CF4
# http%3A%2F%2Fwww.genoscope.cns.fr%2Fagc%2Fmicroscope%2Fmage%2Finfo.php%3Fid%3D5601141
# http%3A%2F%2Fswissregulon.unibas.ch%2Fquery%2FAHR
# https%3A%2F%2Fwebchem.ncbr.muni.cz%2FPlatform%2FValidatorDb%2FByStructure%2F2h6o
# https%3A%2F%2Fdatalab.rwth-aachen.de%2FMINDER%2Fresource%2Faef4c195-9cf9-46db-a12a-7cfd1ff3eec3
# http%3A%2F%2Fvmh.uni.lu%2F%23metabolite%2Fh2o
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fnmrcv%2Fterms%3Fshort_form%3DNMR%3A1000003
# https%3A%2F%2Fvmh.uni.lu%2F%23reaction%2FHEX1
# http%3A%2F%2Fascl.net%2F1801.012
# https%3A%2F%2Fwww.facebase.org%2Fdata%2Frecord%2F%231%2Fisa%3Adataset%2Faccession%3DFB00000917
# http%3A%2F%2Fdata.europa.eu%2F89h%2Fjrc-eurl-ecvam-chemagora
# https%3A%2F%2Fgudmap.org%2Fid%2FQ-2958
# http%3A%2F%2Fn2t.net%2Fark%3A%2F57799%2Fb97957
# https%3A%2F%2Fwww.metabolome-express.org%2Fdatasetview.php%3Fdatasetid%3D36
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fmetabolome_express%2FMEX36
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fmetabolomics_workbench%2FST000900
# http%3A%2F%2Fwww.metabolomicsworkbench.org%2Fdata%2FDRCCMetadata.php%3FMode%3DStudy%26StudyID%3DST000900
# http%3A%2F%2Fgpmdb.thegpm.org%2F~%2Fdblist_gpmnum%2Fgpmnum%3DGPM32310002988
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fgpmdb%2FGPM32310002988
# http%3A%2F%2Fwww.metabolomicsworkbench.org%2Fdata%2FDRCCMetadata.php%3FMode%3DProject%26ProjectID%3DPR000001
# https%3A%2F%2Fmassive.ucsd.edu%2FProteoSAFe%2FQueryMSV%3Fid%3DMSV000082131
# https%3A%2F%2Fwww.omicsdi.org%2Fdataset%2Fmassive%2FMSV000082131
# http%3A%2F%2Fbioportal.bioontology.org%2Fontologies%2FFPLX%2F%3Fp%3Dclasses%26conceptid%3Dhttp%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FFPLX%2523_RAS
# https%3A%2F%2Faopwiki.org%2Fevents%2F3
# https%3A%2F%2Faopwiki.org%2Fstressors%2F9
# https%3A%2F%2Faopwiki.org%2Frelationships%2F5
# https%3A%2F%2Farchive.softwareheritage.org%2Fbrowse%2Fswh%3A1%3Arev%3A309cf2674ee7a0749978cf8265ab91a60aea0f7d
# https%3A%2F%2Fdos-gdc.ucsc-cgp-dev.org%2Fga4gh%2Fdos%2Fv1%2Fdataobjects%2F23fa7b4b-9d68-429b-aece-658b11124bb3
# https%3A%2F%2Fcomptox.epa.gov%2Fdashboard%2FDTXSID2021028
# https%3A%2F%2Fwww.ebi.ac.uk%2Fcomplexportal%2Fcomplex%2FCPX-2158
# https%3A%2F%2Fligandbook.org%2Fpackage%2F785
# https%3A%2F%2Fwww.rebuildingakidney.org%2Fid%2FQ-2958
# http%3A%2F%2Fregistry.api.hq.identifiers.org%2FsemanticApi%2FgetRegistryOntology%23DataCollection
# https%3A%2F%2Fw3id.org%2Foc%2Foci%2F1-18
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Ffoodon%2Fterms%3Fobo_id%3DFOODON%3A03307879
# http%3A%2F%2Fbis.zju.edu.cn%2Fricenetdb%2Fgenedetails.php%3FID%3DLOC_Os01g49190.1
# http%3A%2F%2Fbis.zju.edu.cn%2Fricenetdb%2Fproteindetails.php%3FID%3DLOC_Os01g49190
# https%3A%2F%2Fwww.gtexportal.org%2Fhome%2Fgene%2FBRIP1
# http%3A%2F%2Fbis.zju.edu.cn%2Fricenetdb%2Fcompounddetails.php%3FID%3DOSC1416
# http%3A%2F%2Fbis.zju.edu.cn%2Fricenetdb%2Freactiondetails.php%3FID%3DOSR0818
# http%3A%2F%2Fbis.zju.edu.cn%2Fricenetdb%2FmiRNAdetails.php%3FID%3Dosa-miR446
# https%3A%2F%2Famzn.com%2F0471491039
# https%3A%2F%2Fwww.worldcat.org%2Foclc%2F634515043
# https%3A%2F%2Fdataguids.org%2Fga4gh%2Fdos%2Fv1%2Fdataobjects%2Fdg.4503%2F01b048d0-e128-4cb0-94e9-b2d2cab7563d
# http%3A%2F%2Fwww.oid-info.com%2Fcgi-bin%2Fdisplay%3Foid%3D2.16.840%26submit%3DDisplay%26action%3Ddisplay
# https%3A%2F%2Fflowrepository.org%2Fid%2FFR-FCM-ZYGW
# http%3A%2F%2Faddgene.org%2F50943
# https%3A%2F%2Fwww.cancerrxgene.org%2Ftranslation%2FDrug%2F1242
# https%3A%2F%2Fbacdive.dsmz.de%2Fstrain%2F131392
# https%3A%2F%2Fwww.ebi.ac.uk%2Fols%2Fontologies%2Fido%2Fterms%3Fobo_id%3DIDO%3A0000504
# http%3A%2F%2Fwww.isni.org%2Fisni%2F000000012281955X
# http%3A%2F%2Fviaf.org%2Fviaf%2F75121530
# http%3A%2F%2Fsabiork.h-its.org%2FnewSearch%3Fq%3D75
# https%3A%2F%2Fspdx.org%2Flicenses%2FCC-BY-1.0
# http%3A%2F%2Fwww.peptideatlas.org%2FPASS%2FPASS01237
# https%3A%2F%2Funiresolver.io%2F%23did%3Asov%3AWRfXPg8dantKVubE3HX8pw
# https%3A%2F%2Fshigen.nig.ac.jp%2Frice%2Foryzabase%2Freference%2Fdetail%2F42840
# https%3A%2F%2Fwww.ebi.ac.uk%2Fbiostudies%2Fstudies%2FS-EPMC6266652
# http%3A%2F%2Fmodelseed.org%2Fbiochem%2Freactions%2Frxn00001
# https%3A%2F%2Fw3id.org%2Foc%2Fcorpus%2Fbr%2F1
# https%3A%2F%2Fcadsrapi.nci.nih.gov%2Fcadsrapi4%2FGetXML%3Fquery%3DDataElement%5B%40publicId%3D3771992%5D
# https%3A%2F%2Fnanocommons.github.io%2Fidentifiers%2Fregistry%23ERM00000044
# http%3A%2F%2Fclassyfire.wishartlab.com%2Ftax_nodes%2FC0004828
# https%3A%2F%2Fwww.ebi.ac.uk%2Fgwas%2Fstudies%2FGCST000035
# https%3A%2F%2Fmmp.sfb.uit.no%2Fdatabases%2Fmarfun%2F%23%2Frecords%2FMMP3888430
# https%3A%2F%2Fwww.e-cyanobacterium.org%2Fexperiments-repository%2F%3Faction%3Ddetail%26id%3D18
# https%3A%2F%2Fdoulix.com%2Fbiomodules%2F6VDC956%2F
# https%3A%2F%2Fdoulix.com%2Fconstructs%2FM77F7JM%2F
# https%3A%2F%2Fwww.cameo3d.org%2Fsp%2Ftargets%2Ftarget%2F2019-08-03_00000089_1
# https%3A%2F%2Fassets.nemoarchive.org%2Fsmp-m3w9hbe
# https%3A%2F%2Fwww.ebi.ac.uk%2Fena%2Fdata%2Fview%2FGCA_000155495.1
# https%3A%2F%2Fwww.ncbi.nlm.nih.gov%2Fassembly%2FGCA_000155495.1
# https%3A%2F%2Fwww.signalingpathways.org%2Fdatasets%2Fdataset.jsf%3Fdoi%3D10.1621%2FvwN2g2HaX3
